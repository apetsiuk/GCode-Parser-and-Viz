# %% [markdown]
# # GCode Parser for PrusaSlicer
#
# - ;TYPE:Perimeter
# - ;TYPE:External perimeter
# - ;TYPE:Overhang perimeter
#
# - ;TYPE:Internal infill
# - ;TYPE:Solid infill
# - ;TYPE:Top solid infill
# - ;TYPE:Bridge infill
#
# - ;TYPE:Support material
# - ;TYPE:Support material interface
#
# - ;TYPE:Skirt/Brim
# - ;TYPE:Wipe tower
# - ;TYPE:Custom

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
line = ";LAYER_Z_HEIGHT=11.7"
line = line.rstrip()
layer_height = 0
bits = line.split(';',1)
print(bits[1][:15])

print('-----')
layer_height = float(bits[1][15:])
print('layer_height= ',layer_height)
print('-----')


print(line)
print(bits)

if(len(bits)>1):
    if (bits[1][:20] == "TYPE:Internal infill" or bits[1][:17] == "TYPE:Solid infill" or  bits[1][:21] == "TYPE:Top solid infill" or  bits[1][:18] == "TYPE:Bridge infill"):
        #print(bits[1][:14])
        print('fill')
    else:
        print('else')
# Out:
# LAYER_Z_HEIGHT=
# -----
# layer_height=  11.7
# -----
# ;LAYER_Z_HEIGHT=11.7
# ['', 'LAYER_Z_HEIGHT=11.7']
# else

# %%
class Segment:
    def __init__(self,move_type,coords,layer_index,shell,fill,support,other):
        self.type = move_type
        self.coords = coords
        self.layer_index = layer_index
        self.shell = shell
        self.fill = fill
        self.support = support
        self.other = other
        self.style = None

# %%
class Parser:

    def __init__(self):
        self.relative = {"X":0.0,"Y":0.0,"F":0.0,"E":0.0, "z_height":0.0}
        self.isRelative = False
        self.segments = []
        self.layer_number = 0
        self.z_height = 0.0
        self.layers = []
        self.shell = 0
        self.fill = 0
        self.support = 0
        self.other = 0

    def parseFile(self,path):
        with open(path, 'r') as f:
            self.lineNb = 0
            for line in f:
                self.lineNb += 1
                self.line = line.rstrip()
                self.parseLine()

    def parseLine(self):
        bits = self.line.split(';',1)
        if(len(bits)>1):
            if (bits[1][:12] == 'LAYER_CHANGE'):
                self.layer_number += 1
                #self.z_height += 0.3

        if(len(bits)>1):
            if (bits[1][:15] == 'LAYER_Z_HEIGHT='):
                self.z_height = float(bits[1][15:])

        if(len(bits)>1):
            if (bits[1][:20] == "TYPE:Internal infill" or
                  bits[1][:17] == "TYPE:Solid infill" or
                  bits[1][:21] == "TYPE:Top solid infill" or
                  bits[1][:18] == "TYPE:Bridge infill"):
                self.shell = 0
                self.fill = 1
                self.support = 0
                self.other = 0
            elif (bits[1][:14] == "TYPE:Perimeter" or
                bits[1][:23] == "TYPE:External perimeter" or
                bits[1][:23] == "TYPE:Overhang perimeter"):
                self.shell = 1
                self.fill = 0
                self.support = 0
                self.other = 0

            elif (bits[1][:21] == "TYPE:Support material" or
                  bits[1][:31] == "TYPE:Support material interface"):
                self.shell = 0
                self.fill = 0
                self.support = 1
                self.other = 0
            '''else:
                self.shell = 0
                self.fill = 0
                self.support = 0
                self.other = 1'''

        command = bits[0].strip()
        comm = command.split(None, 1)
        code = comm[0] if (len(comm)>0) else None # G
        args = comm[1] if (len(comm)>1) else None # XYEF

        if code:
            if hasattr(self, "parse_"+code):
                getattr(self, "parse_"+code)(args)
                #print("code= ", code, ": args= ", args)
            return code,args

    def parseArgs(self, args):
        dic = {}
        if args:
            bits = args.split()
            for bit in bits:
                letter = bit[0]
                try:
                    coord = float(bit[1:])
                except ValueError:
                    coord = 1
                dic[letter] = coord
        return dic

    def parse_G0(self, args, move_type="G0"):
        self.do_G0_G1(self.parseArgs(args), move_type)

    def parse_G1(self, args, move_type="G1"):
        self.do_G0_G1(self.parseArgs(args), move_type)

    def do_G0_G1(self,args,move_type):
        coords = dict(self.relative)
        for axis in args.keys():
            if axis in coords:
                if self.isRelative:
                    coords[axis] += args[axis]
                else:
                    coords[axis] = args[axis]
        # build segment
        absolute = {"X": coords["X"],"Y": coords["Y"],"z_height": self.z_height}
        if "E" not in args : #"E" in coords:
            absolute["E"] = 0
        else:
            absolute["E"] = args["E"]

        seg = Segment(move_type,absolute,self.layer_number,self.shell,self.fill,self.support,self.other)

        if (seg.coords['X'] != self.relative['X'] or
            seg.coords['Y'] != self.relative['Y']):
            self.segments.append(seg)
        self.relative = coords
        return self.relative

    def classifySegments(self):
        coords = {"X":0.0,"Y":0.0,"Z":0.0,"F":0.0,"E":0.0}
        current_layer = 0
        layer = []

        for i, seg in enumerate(self.segments):
            # default style is travel (move, no extrusion)
            style = "travel"

            # some horizontal movement, and positive extruder movement: extrusion
            if (((seg.coords["X"] != coords["X"])
                    or (seg.coords["Y"] != coords["Y"])
                    or (seg.coords["z_height"] != coords["Z"])) and (seg.coords["E"]>0)): #!= coords["E"]
                style = "extrude"

            if i==len(self.segments)-1:
                layer.append(seg)
                current_layer += 1
                seg.style = style
                seg.layer_index = current_layer
                self.layers.append(layer)
                print('**Segment classification complete**')
                break

            if (self.segments[i].layer_index != current_layer):
                self.layers.append(layer)
                layer = []
                current_layer+=1

            # set style and layer in segment
            seg.style = style
            coords = seg.coords
            layer.append(seg)

# %%
parser = Parser()
parser.parseFile('/content/drive/MyDrive/Colab Notebooks/cyberpunk_robot_with_support_0.4n_0.3mm_PLA_MK3SMMU2S_6h4m.gcode')

parser.classifySegments()
print(len(parser.segments))
print(len(parser.layers))

print(parser.layer_number)
print(parser.z_height)
# Out:
# **Segment classification complete**
# 513310
# 769
# 768
# 80.0

# %%
# just for ref

LN = 4 # layer number
sn = 46 # segment number
print(len(parser.layers[LN])) # segments in the layer
print(parser.layers[LN][sn]) # one segment
print(parser.layers[LN][sn].coords)
print(parser.layers[LN][sn].coords['X'])
print(parser.layers[LN][sn].style)
print(parser.layers[LN][sn].type)
print(parser.layers[LN][sn].shell)
print(parser.layers[LN][sn].fill)
print(parser.layers[LN][sn].support)
print(parser.layers[LN][sn].other)
print(parser.layers[LN][sn].layer_index)
# Out:
# 827
# <__main__.Segment object at 0x7fbd8c169780>
# {'X': 138.32, 'Y': 82.931, 'z_height': 0.5, 'E': 0.01342}
# 138.32
# extrude
# G1
# 1
# 0
# 0
# 0
# 4

# %%
LN = 534 # layers start from 1

fig = plt.figure(figsize=(12,6), dpi=80)
plt.subplot(121)
for i in range(1,len(parser.layers[LN])):
    if(parser.layers[LN][i].style == 'extrude'):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],c='r')
    else:
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],c='b')

plt.subplot(122)
for i in range(len(parser.layers[LN])):
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].shell == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].fill == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='purple',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].support == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='lime',linewidth=2,linestyle='-')


plt.grid()
plt.tight_layout()
plt.show()

print(i)
# blue - travel
# red - extrude
# lime - shell
# Out:
# 1782

# %%
LN = 535 # layers start from 1

fig = plt.figure(figsize=(12,6), dpi=80)
plt.subplot(121)
for i in range(1,len(parser.layers[LN])):
    if(parser.layers[LN][i].style == 'extrude'):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],c='r')
    else:
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],c='b')

plt.subplot(122)
for i in range(len(parser.layers[LN])):
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].shell == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].fill == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='purple',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].support == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='lime',linewidth=2,linestyle='-')


plt.grid()
plt.tight_layout()
plt.show()

print(i)
# blue - travel
# red - extrude
# lime - shell
# Out:
# 694

# %%
LN = 534 # layers start from 1

fig = plt.figure(figsize=(12,6), dpi=80)
plt.subplot(121)
for i in range(1,len(parser.layers[LN])):
    if(parser.layers[LN][i].style == 'extrude'):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],c='r')
    else:
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],c='b')

for i in range(1,len(parser.layers[LN+1])):
    if(parser.layers[LN+1][i].style == 'extrude'):
        plt.plot([parser.layers[LN+1][i].coords['X'],parser.layers[LN+1][i-1].coords['X']],
             [parser.layers[LN+1][i].coords['Y'],parser.layers[LN+1][i-1].coords['Y']],c='r')
    else:
        plt.plot([parser.layers[LN+1][i].coords['X'],parser.layers[LN+1][i-1].coords['X']],
             [parser.layers[LN+1][i].coords['Y'],parser.layers[LN+1][i-1].coords['Y']],c='b')

plt.subplot(122)
for i in range(len(parser.layers[LN])):
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].shell == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].fill == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='purple',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].support == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='lime',linewidth=2,linestyle='-')

for i in range(len(parser.layers[LN+1])):
    if(parser.layers[LN+1][i].style == 'extrude' and parser.layers[LN+1][i].shell == 1):
        plt.plot([parser.layers[LN+1][i].coords['X'],parser.layers[LN+1][i-1].coords['X']],
             [parser.layers[LN+1][i].coords['Y'],parser.layers[LN+1][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
    if(parser.layers[LN+1][i].style == 'extrude' and parser.layers[LN+1][i].fill == 1):
        plt.plot([parser.layers[LN+1][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN+1][i].coords['Y'],parser.layers[LN+1][i-1].coords['Y']],
                 c='purple',linewidth=2,linestyle='-')
    if(parser.layers[LN+1][i].style == 'extrude' and parser.layers[LN+1][i].support == 1):
        plt.plot([parser.layers[LN+1][i].coords['X'],parser.layers[LN+1][i-1].coords['X']],
             [parser.layers[LN+1][i].coords['Y'],parser.layers[LN+1][i-1].coords['Y']],
                 c='lime',linewidth=2,linestyle='-')


plt.grid()
plt.tight_layout()
plt.show()

print(i)
# blue - travel
# red - extrude
# lime - shell
# Out:
# 694

# %%
fig = plt.figure(figsize=(14,14), dpi=80)
for i in range(1,len(parser.layers[LN])):
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].shell == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].fill == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='purple',linewidth=2,linestyle='-')
    if(parser.layers[LN][i].style == 'extrude' and parser.layers[LN][i].support == 1):
        plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='lime',linewidth=2,linestyle='-')
plt.grid()
plt.show()

# %%
len(parser.layers[LN])
# Out:
# 1783

# %%
fig = plt.figure(figsize=(14,14), dpi=80)
for i in range(1,len(parser.layers[LN])):
    plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
    plt.text(parser.layers[LN][i].coords['X'], parser.layers[LN][i].coords['Y'], i)
plt.show()

# %%
LN = 1
fig = plt.figure(figsize=(14,14), dpi=80)
for i in range(1,len(parser.layers[LN])):
  if(parser.layers[LN][i].style == 'extrude'):
    if(parser.layers[LN][i].shell == 1):
      plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
      plt.text(parser.layers[LN][i].coords['X'], parser.layers[LN][i].coords['Y'], i)
    elif(parser.layers[LN][i].fill == 1):
      plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='blue',linewidth=2,linestyle='-')
      plt.text(parser.layers[LN][i].coords['X'], parser.layers[LN][i].coords['Y'], i)
plt.show()

# %%
for i in range(1,10):
    plt.plot([parser.layers[LN][i].coords['X'],parser.layers[LN][i-1].coords['X']],
             [parser.layers[LN][i].coords['Y'],parser.layers[LN][i-1].coords['Y']],
                 c='orange',linewidth=2,linestyle='-')
    plt.text(parser.layers[LN][i-1].coords['X'], parser.layers[LN][i-1].coords['Y'], i)

# %%
print(parser.layers[LN][-1].type)
print(parser.layers[LN][2].coords)
print(parser.layers[LN][2].layer_index)
print(parser.layers[LN][2].shell)
print(parser.layers[LN][2].fill)
print(parser.layers[LN][2].support)
print(parser.layers[LN][2].other)
print(parser.layers[LN][2].style)
# Out:
# G1
# {'X': 116.948, 'Y': 68.285, 'z_height': 0.2, 'E': 1.10174}
# 1
# 0
# 0
# 0
# 0
# extrude

# %%
LN = 4
print(len(parser.layers[LN]))

for i in range(len(parser.layers[LN])):
  line_type = ""
  if(parser.layers[LN][i].shell == 1):
    line_type = "shell"
  elif(parser.layers[LN][i].fill == 1):
    line_type = "fill"
  else:
    line_type = "else"

  print(i,':',parser.layers[LN][i].layer_index,
        parser.layers[LN][i].style,
        parser.layers[LN][i].type,
        parser.layers[LN][i].coords,
        line_type)
# Out:
# 827
# 0 : 4 travel G1 {'X': 132.7, 'Y': 79.868, 'z_height': 0.5, 'E': -0.02217} else
# 1 : 4 travel G1 {'X': 132.7, 'Y': 77.9, 'z_height': 0.5, 'E': -0.45442} else
# 2 : 4 travel G1 {'X': 131.299, 'Y': 77.9, 'z_height': 0.5, 'E': -0.32341} else
# 3 : 4 travel G1 {'X': 136.134, 'Y': 71.83, 'z_height': 0.5, 'E': 0} else
# 4 : 4 extrude G1 {'X': 144.777, 'Y': 78.715, 'z_height': 0.5, 'E': 0.49013} else
# 5 : 4 extrude G1 {'X': 145.18, 'Y': 79.124, 'z_height': 0.5, 'E': 0.02547} else
# 6 : 4 extrude G1 {'X': 145.539, 'Y': 79.733, 'z_height': 0.5, 'E': 0.03136} else
# 7 : 4 extrude G1 {'X': 145.744, 'Y': 80.396, 'z_height': 0.5, 'E': 0.03078} else
# 8 : 4 extrude G1 {'X': 153.747, 'Y': 132.45, 'z_height': 0.5, 'E': 2.33597} else
# 9 : 4 extrude G1 {'X': 153.729, 'Y': 133.347, 'z_height': 0.5, 'E': 0.03979} else
# 10 : 4 extrude G1 {'X': 153.163, 'Y': 134.559, 'z_height': 0.5, 'E': 0.05933} else
# 11 : 4 extrude G1 {'X': 150.693, 'Y': 137.362, 'z_height': 0.5, 'E': 0.16571} else
# 12 : 4 extrude G1 {'X': 149.939, 'Y': 137.933, 'z_height': 0.5, 'E': 0.04195} else
# 13 : 4 extrude G1 {'X': 138.993, 'Y': 143.197, 'z_height': 0.5, 'E': 0.53873} else
# 14 : 4 extrude G1 {'X': 138.299, 'Y': 143.407, 'z_height': 0.5, 'E': 0.03216} else
# 15 : 4 extrude G1 {'X': 121.754, 'Y': 145.747, 'z_height': 0.5, 'E': 0.74115} else
# 16 : 4 extrude G1 {'X': 113.748, 'Y': 145.744, 'z_height': 0.5, 'E': 0.3551} else
# 17 : 4 extrude G1 {'X': 100.171, 'Y': 145.112, 'z_height': 0.5, 'E': 0.60286} else
# 18 : 4 extrude G1 {'X': 98.429, 'Y': 144.227, 'z_height': 0.5, 'E': 0.08667} else
# 19 : 4 extrude G1 {'X': 96.968, 'Y': 142.397, 'z_height': 0.5, 'E': 0.10386} else
# 20 : 4 extrude G1 {'X': 86.096, 'Y': 126.168, 'z_height': 0.5, 'E': 0.86643} else
# 21 : 4 extrude G1 {'X': 85.694, 'Y': 124.845, 'z_height': 0.5, 'E': 0.06133} else
# 22 : 4 extrude G1 {'X': 85.694, 'Y': 88.447, 'z_height': 0.5, 'E': 1.61443} else
# 23 : 4 extrude G1 {'X': 86.085, 'Y': 87.14, 'z_height': 0.5, 'E': 0.06051} else
# 24 : 4 extrude G1 {'X': 86.845, 'Y': 86.41, 'z_height': 0.5, 'E': 0.04674} else
# 25 : 4 extrude G1 {'X': 116.948, 'Y': 68.285, 'z_height': 0.5, 'E': 1.55856} else
# 26 : 4 extrude G1 {'X': 118.174, 'Y': 67.944, 'z_height': 0.5, 'E': 0.05644} else
# 27 : 4 extrude G1 {'X': 128.701, 'Y': 67.944, 'z_height': 0.5, 'E': 0.46692} else
# 28 : 4 extrude G1 {'X': 129.764, 'Y': 68.195, 'z_height': 0.5, 'E': 0.04845} else
# 29 : 4 extrude G1 {'X': 134.813, 'Y': 70.778, 'z_height': 0.5, 'E': 0.25155} else
# 30 : 4 extrude G1 {'X': 136.087, 'Y': 71.793, 'z_height': 0.5, 'E': 0.07225} else
# 31 : 4 travel G1 {'X': 138.797, 'Y': 73.952, 'z_height': 0.5, 'E': -0.8} else
# 32 : 4 travel G1 {'X': 91.707, 'Y': 89.267, 'z_height': 0.5, 'E': 0} else
# 33 : 4 extrude G1 {'X': 94.905, 'Y': 88.823, 'z_height': 0.5, 'E': 0.17542} shell
# 34 : 4 extrude G1 {'X': 104.218, 'Y': 87.445, 'z_height': 0.5, 'E': 0.51151} shell
# 35 : 4 extrude G1 {'X': 120.878, 'Y': 84.881, 'z_height': 0.5, 'E': 0.91584} shell
# 36 : 4 extrude G1 {'X': 123.126, 'Y': 84.63, 'z_height': 0.5, 'E': 0.1229} shell
# 37 : 4 extrude G1 {'X': 126.776, 'Y': 84.145, 'z_height': 0.5, 'E': 0.20006} shell
# 38 : 4 extrude G1 {'X': 126.855, 'Y': 84.142, 'z_height': 0.5, 'E': 0.0043} shell
# 39 : 4 extrude G1 {'X': 128.634, 'Y': 84.068, 'z_height': 0.5, 'E': 0.09674} shell
# 40 : 4 extrude G1 {'X': 130.211, 'Y': 83.914, 'z_height': 0.5, 'E': 0.08609} shell
# 41 : 4 extrude G1 {'X': 132.756, 'Y': 83.662, 'z_height': 0.5, 'E': 0.13895} shell
# 42 : 4 extrude G1 {'X': 133.803, 'Y': 83.746, 'z_height': 0.5, 'E': 0.05707} shell
# 43 : 4 extrude G1 {'X': 134.027, 'Y': 83.745, 'z_height': 0.5, 'E': 0.01217} shell
# 44 : 4 extrude G1 {'X': 137.869, 'Y': 83.174, 'z_height': 0.5, 'E': 0.21104} shell
# 45 : 4 extrude G1 {'X': 138.127, 'Y': 83.085, 'z_height': 0.5, 'E': 0.01483} shell
# 46 : 4 extrude G1 {'X': 138.32, 'Y': 82.931, 'z_height': 0.5, 'E': 0.01342} shell
# 47 : 4 extrude G1 {'X': 140.23, 'Y': 82.389, 'z_height': 0.5, 'E': 0.10787} shell
# 48 : 4 extrude G1 {'X': 140.312, 'Y': 82.366, 'z_height': 0.5, 'E': 0.00463} shell
# 49 : 4 extrude G1 {'X': 140.65, 'Y': 82.172, 'z_height': 0.5, 'E': 0.02117} shell
# 50 : 4 extrude G1 {'X': 141.451, 'Y': 81.714, 'z_height': 0.5, 'E': 0.05013} shell
# 51 : 4 extrude G1 {'X': 141.865, 'Y': 81.531, 'z_height': 0.5, 'E': 0.02459} shell
# 52 : 4 extrude G1 {'X': 142.684, 'Y': 81.41, 'z_height': 0.5, 'E': 0.04498} shell
# 53 : 4 extrude G1 {'X': 143.129, 'Y': 84.608, 'z_height': 0.5, 'E': 0.17543} shell
# 54 : 4 extrude G1 {'X': 144.512, 'Y': 93.961, 'z_height': 0.5, 'E': 0.5137} shell
# 55 : 4 extrude G1 {'X': 149.237, 'Y': 124.684, 'z_height': 0.5, 'E': 1.68889} shell
# 56 : 4 extrude G1 {'X': 149.841, 'Y': 128.45, 'z_height': 0.5, 'E': 0.20723} shell
# 57 : 4 extrude G1 {'X': 150.193, 'Y': 130.52, 'z_height': 0.5, 'E': 0.11408} shell
# 58 : 4 extrude G1 {'X': 150.265, 'Y': 131.074, 'z_height': 0.5, 'E': 0.03035} shell
# 59 : 4 extrude G1 {'X': 150.461, 'Y': 132.121, 'z_height': 0.5, 'E': 0.05787} shell
# 60 : 4 extrude G1 {'X': 149.784, 'Y': 131.921, 'z_height': 0.5, 'E': 0.03835} shell
# 61 : 4 extrude G1 {'X': 149.43, 'Y': 131.907, 'z_height': 0.5, 'E': 0.01925} shell
# 62 : 4 extrude G1 {'X': 149.063, 'Y': 131.892, 'z_height': 0.5, 'E': 0.01996} shell
# 63 : 4 extrude G1 {'X': 147.524, 'Y': 131.829, 'z_height': 0.5, 'E': 0.08369} shell
# 64 : 4 extrude G1 {'X': 146.67, 'Y': 131.815, 'z_height': 0.5, 'E': 0.04641} shell
# 65 : 4 extrude G1 {'X': 145.933, 'Y': 131.849, 'z_height': 0.5, 'E': 0.04009} shell
# 66 : 4 extrude G1 {'X': 145.047, 'Y': 131.889, 'z_height': 0.5, 'E': 0.04819} shell
# 67 : 4 extrude G1 {'X': 142.507, 'Y': 132.004, 'z_height': 0.5, 'E': 0.13815} shell
# 68 : 4 extrude G1 {'X': 140.91, 'Y': 132.17, 'z_height': 0.5, 'E': 0.08724} shell
# 69 : 4 extrude G1 {'X': 136.638, 'Y': 132.563, 'z_height': 0.5, 'E': 0.23309} shell
# 70 : 4 extrude G1 {'X': 134.411, 'Y': 132.91, 'z_height': 0.5, 'E': 0.12246} shell
# 71 : 4 extrude G1 {'X': 130.755, 'Y': 133.428, 'z_height': 0.5, 'E': 0.20062} shell
# 72 : 4 extrude G1 {'X': 124.894, 'Y': 134.384, 'z_height': 0.5, 'E': 0.32265} shell
# 73 : 4 extrude G1 {'X': 122.539, 'Y': 134.713, 'z_height': 0.5, 'E': 0.1292} shell
# 74 : 4 extrude G1 {'X': 116.758, 'Y': 135.58, 'z_height': 0.5, 'E': 0.31761} shell
# 75 : 4 extrude G1 {'X': 113.253, 'Y': 136.153, 'z_height': 0.5, 'E': 0.19296} shell
# 76 : 4 extrude G1 {'X': 108.175, 'Y': 137.23, 'z_height': 0.5, 'E': 0.28204} shell
# 77 : 4 extrude G1 {'X': 107.067, 'Y': 137.664, 'z_height': 0.5, 'E': 0.06465} shell
# 78 : 4 extrude G1 {'X': 104.144, 'Y': 138.41, 'z_height': 0.5, 'E': 0.16391} shell
# 79 : 4 extrude G1 {'X': 103.869, 'Y': 138.544, 'z_height': 0.5, 'E': 0.01662} shell
# 80 : 4 extrude G1 {'X': 103.585, 'Y': 138.811, 'z_height': 0.5, 'E': 0.02118} shell
# 81 : 4 extrude G1 {'X': 102.166, 'Y': 139.3, 'z_height': 0.5, 'E': 0.08155} shell
# 82 : 4 extrude G1 {'X': 101.954, 'Y': 139.373, 'z_height': 0.5, 'E': 0.01218} shell
# 83 : 4 extrude G1 {'X': 101.651, 'Y': 139.567, 'z_height': 0.5, 'E': 0.01955} shell
# 84 : 4 extrude G1 {'X': 101.59, 'Y': 139.596, 'z_height': 0.5, 'E': 0.00367} shell
# 85 : 4 extrude G1 {'X': 100.859, 'Y': 139.947, 'z_height': 0.5, 'E': 0.04406} shell
# 86 : 4 extrude G1 {'X': 100.4, 'Y': 140.119, 'z_height': 0.5, 'E': 0.02663} shell
# 87 : 4 extrude G1 {'X': 99.562, 'Y': 140.249, 'z_height': 0.5, 'E': 0.04608} shell
# 88 : 4 extrude G1 {'X': 97.862, 'Y': 128.547, 'z_height': 0.5, 'E': 0.64248} shell
# 89 : 4 extrude G1 {'X': 95.179, 'Y': 111.083, 'z_height': 0.5, 'E': 0.96} shell
# 90 : 4 extrude G1 {'X': 94.925, 'Y': 108.874, 'z_height': 0.5, 'E': 0.12081} shell
# 91 : 4 extrude G1 {'X': 94.609, 'Y': 106.546, 'z_height': 0.5, 'E': 0.12765} shell
# 92 : 4 extrude G1 {'X': 94.44, 'Y': 105.302, 'z_height': 0.5, 'E': 0.06821} shell
# 93 : 4 extrude G1 {'X': 94.342, 'Y': 103.354, 'z_height': 0.5, 'E': 0.10597} shell
# 94 : 4 extrude G1 {'X': 93.955, 'Y': 99.653, 'z_height': 0.5, 'E': 0.20218} shell
# 95 : 4 extrude G1 {'X': 94.031, 'Y': 98.62, 'z_height': 0.5, 'E': 0.05628} shell
# 96 : 4 extrude G1 {'X': 94.025, 'Y': 98.455, 'z_height': 0.5, 'E': 0.00897} shell
# 97 : 4 extrude G1 {'X': 93.472, 'Y': 94.724, 'z_height': 0.5, 'E': 0.20493} shell
# 98 : 4 extrude G1 {'X': 93.447, 'Y': 94.612, 'z_height': 0.5, 'E': 0.00624} shell
# 99 : 4 extrude G1 {'X': 93.225, 'Y': 94.214, 'z_height': 0.5, 'E': 0.02476} shell
# 100 : 4 extrude G1 {'X': 92.654, 'Y': 92.028, 'z_height': 0.5, 'E': 0.12276} shell
# 101 : 4 extrude G1 {'X': 92.589, 'Y': 91.896, 'z_height': 0.5, 'E': 0.00799} shell
# 102 : 4 extrude G1 {'X': 92.488, 'Y': 91.671, 'z_height': 0.5, 'E': 0.0134} shell
# 103 : 4 extrude G1 {'X': 92.005, 'Y': 90.595, 'z_height': 0.5, 'E': 0.06408} shell
# 104 : 4 extrude G1 {'X': 91.831, 'Y': 90.108, 'z_height': 0.5, 'E': 0.0281} shell
# 105 : 4 extrude G1 {'X': 91.715, 'Y': 89.327, 'z_height': 0.5, 'E': 0.0429} shell
# 106 : 4 travel G1 {'X': 91.162, 'Y': 88.853, 'z_height': 0.5, 'E': 0} shell
# 107 : 4 extrude G1 {'X': 94.838, 'Y': 88.342, 'z_height': 0.5, 'E': 0.24794} shell
# 108 : 4 extrude G1 {'X': 95.63, 'Y': 88.225, 'z_height': 0.5, 'E': 0.05348} shell
# 109 : 4 extrude G1 {'X': 103.309, 'Y': 87.089, 'z_height': 0.5, 'E': 0.51858} shell
# 110 : 4 extrude G1 {'X': 104.147, 'Y': 86.965, 'z_height': 0.5, 'E': 0.05659} shell
# 111 : 4 extrude G1 {'X': 104.984, 'Y': 86.836, 'z_height': 0.5, 'E': 0.05658} shell
# 112 : 4 extrude G1 {'X': 118.36, 'Y': 84.777, 'z_height': 0.5, 'E': 0.90411} shell
# 113 : 4 extrude G1 {'X': 119.249, 'Y': 84.64, 'z_height': 0.5, 'E': 0.06009} shell
# 114 : 4 extrude G1 {'X': 120.814, 'Y': 84.399, 'z_height': 0.5, 'E': 0.10578} shell
# 115 : 4 extrude G1 {'X': 123.056, 'Y': 84.149, 'z_height': 0.5, 'E': 0.15071} shell
# 116 : 4 extrude G1 {'X': 124.154, 'Y': 84.004, 'z_height': 0.5, 'E': 0.07399} shell
# 117 : 4 extrude G1 {'X': 126.734, 'Y': 83.661, 'z_height': 0.5, 'E': 0.17387} shell
# 118 : 4 extrude G1 {'X': 128.629, 'Y': 83.582, 'z_height': 0.5, 'E': 0.12671} shell
# 119 : 4 extrude G1 {'X': 130.061, 'Y': 83.441, 'z_height': 0.5, 'E': 0.09613} shell
# 120 : 4 extrude G1 {'X': 130.911, 'Y': 83.357, 'z_height': 0.5, 'E': 0.05706} shell
# 121 : 4 extrude G1 {'X': 132.752, 'Y': 83.175, 'z_height': 0.5, 'E': 0.12359} shell
# 122 : 4 extrude G1 {'X': 133.956, 'Y': 83.264, 'z_height': 0.5, 'E': 0.08065} shell
# 123 : 4 extrude G1 {'X': 137.841, 'Y': 82.683, 'z_height': 0.5, 'E': 0.26243} shell
# 124 : 4 extrude G1 {'X': 138.06, 'Y': 82.5, 'z_height': 0.5, 'E': 0.01907} shell
# 125 : 4 extrude G1 {'X': 140.179, 'Y': 81.898, 'z_height': 0.5, 'E': 0.14716} shell
# 126 : 4 extrude G1 {'X': 140.768, 'Y': 81.545, 'z_height': 0.5, 'E': 0.04587} shell
# 127 : 4 extrude G1 {'X': 141.142, 'Y': 81.332, 'z_height': 0.5, 'E': 0.02875} shell
# 128 : 4 extrude G1 {'X': 141.211, 'Y': 81.292, 'z_height': 0.5, 'E': 0.00533} shell
# 129 : 4 extrude G1 {'X': 141.732, 'Y': 81.06, 'z_height': 0.5, 'E': 0.0381} shell
# 130 : 4 extrude G1 {'X': 143.098, 'Y': 80.86, 'z_height': 0.5, 'E': 0.09223} shell
# 131 : 4 extrude G1 {'X': 143.61, 'Y': 84.541, 'z_height': 0.5, 'E': 0.24828} shell
# 132 : 4 extrude G1 {'X': 143.727, 'Y': 85.333, 'z_height': 0.5, 'E': 0.05348} shell
# 133 : 4 extrude G1 {'X': 144.868, 'Y': 93.05, 'z_height': 0.5, 'E': 0.52114} shell
# 134 : 4 extrude G1 {'X': 144.993, 'Y': 93.89, 'z_height': 0.5, 'E': 0.05673} shell
# 135 : 4 extrude G1 {'X': 145.122, 'Y': 94.729, 'z_height': 0.5, 'E': 0.05671} shell
# 136 : 4 extrude G1 {'X': 149.591, 'Y': 123.793, 'z_height': 0.5, 'E': 1.96445} shell
# 137 : 4 extrude G1 {'X': 149.717, 'Y': 124.61, 'z_height': 0.5, 'E': 0.05523} shell
# 138 : 4 extrude G1 {'X': 150.319, 'Y': 128.366, 'z_height': 0.5, 'E': 0.25412} shell
# 139 : 4 extrude G1 {'X': 150.677, 'Y': 130.474, 'z_height': 0.5, 'E': 0.14284} shell
# 140 : 4 extrude G1 {'X': 150.742, 'Y': 130.985, 'z_height': 0.5, 'E': 0.03441} shell
# 141 : 4 extrude G1 {'X': 151.074, 'Y': 132.758, 'z_height': 0.5, 'E': 0.1205} shell
# 142 : 4 extrude G1 {'X': 150.426, 'Y': 132.611, 'z_height': 0.5, 'E': 0.04439} shell
# 143 : 4 extrude G1 {'X': 150.111, 'Y': 132.539, 'z_height': 0.5, 'E': 0.02159} shell
# 144 : 4 extrude G1 {'X': 149.822, 'Y': 132.429, 'z_height': 0.5, 'E': 0.02066} shell
# 145 : 4 extrude G1 {'X': 149.765, 'Y': 132.407, 'z_height': 0.5, 'E': 0.00408} shell
# 146 : 4 extrude G1 {'X': 147.505, 'Y': 132.314, 'z_height': 0.5, 'E': 0.15111} shell
# 147 : 4 extrude G1 {'X': 146.692, 'Y': 132.3, 'z_height': 0.5, 'E': 0.05432} shell
# 148 : 4 extrude G1 {'X': 146.549, 'Y': 132.307, 'z_height': 0.5, 'E': 0.00956} shell
# 149 : 4 extrude G1 {'X': 144.435, 'Y': 132.402, 'z_height': 0.5, 'E': 0.14137} shell
# 150 : 4 extrude G1 {'X': 142.558, 'Y': 132.487, 'z_height': 0.5, 'E': 0.12552} shell
# 151 : 4 extrude G1 {'X': 140.958, 'Y': 132.654, 'z_height': 0.5, 'E': 0.10747} shell
# 152 : 4 extrude G1 {'X': 136.682, 'Y': 133.046, 'z_height': 0.5, 'E': 0.28686} shell
# 153 : 4 extrude G1 {'X': 134.483, 'Y': 133.39, 'z_height': 0.5, 'E': 0.14869} shell
# 154 : 4 extrude G1 {'X': 130.823, 'Y': 133.909, 'z_height': 0.5, 'E': 0.24695} shell
# 155 : 4 extrude G1 {'X': 128.51, 'Y': 134.299, 'z_height': 0.5, 'E': 0.1567} shell
# 156 : 4 extrude G1 {'X': 124.966, 'Y': 134.864, 'z_height': 0.5, 'E': 0.23975} shell
# 157 : 4 extrude G1 {'X': 122.614, 'Y': 135.193, 'z_height': 0.5, 'E': 0.15866} shell
# 158 : 4 extrude G1 {'X': 116.839, 'Y': 136.059, 'z_height': 0.5, 'E': 0.39011} shell
# 159 : 4 extrude G1 {'X': 113.353, 'Y': 136.628, 'z_height': 0.5, 'E': 0.23597} shell
# 160 : 4 extrude G1 {'X': 108.276, 'Y': 137.705, 'z_height': 0.5, 'E': 0.34672} shell
# 161 : 4 extrude G1 {'X': 107.218, 'Y': 138.127, 'z_height': 0.5, 'E': 0.0761} shell
# 162 : 4 extrude G1 {'X': 104.217, 'Y': 138.898, 'z_height': 0.5, 'E': 0.20699} shell
# 163 : 4 extrude G1 {'X': 103.844, 'Y': 139.235, 'z_height': 0.5, 'E': 0.03358} shell
# 164 : 4 extrude G1 {'X': 102.113, 'Y': 139.832, 'z_height': 0.5, 'E': 0.12232} shell
# 165 : 4 extrude G1 {'X': 101.927, 'Y': 139.973, 'z_height': 0.5, 'E': 0.01559} shell
# 166 : 4 extrude G1 {'X': 101.493, 'Y': 140.179, 'z_height': 0.5, 'E': 0.03209} shell
# 167 : 4 extrude G1 {'X': 101.174, 'Y': 140.329, 'z_height': 0.5, 'E': 0.02355} shell
# 168 : 4 extrude G1 {'X': 100.933, 'Y': 140.442, 'z_height': 0.5, 'E': 0.01778} shell
# 169 : 4 extrude G1 {'X': 100.4, 'Y': 140.611, 'z_height': 0.5, 'E': 0.03735} shell
# 170 : 4 extrude G1 {'X': 99.148, 'Y': 140.787, 'z_height': 0.5, 'E': 0.08446} shell
# 171 : 4 extrude G1 {'X': 98.666, 'Y': 137.375, 'z_height': 0.5, 'E': 0.2302} shell
# 172 : 4 extrude G1 {'X': 98.557, 'Y': 136.635, 'z_height': 0.5, 'E': 0.04997} shell
# 173 : 4 extrude G1 {'X': 97.505, 'Y': 129.46, 'z_height': 0.5, 'E': 0.48445} shell
# 174 : 4 extrude G1 {'X': 97.382, 'Y': 128.618, 'z_height': 0.5, 'E': 0.05685} shell
# 175 : 4 extrude G1 {'X': 97.252, 'Y': 127.777, 'z_height': 0.5, 'E': 0.05685} shell
# 176 : 4 extrude G1 {'X': 95.104, 'Y': 113.793, 'z_height': 0.5, 'E': 0.94516} shell
# 177 : 4 extrude G1 {'X': 94.967, 'Y': 112.903, 'z_height': 0.5, 'E': 0.06016} shell
# 178 : 4 extrude G1 {'X': 94.697, 'Y': 111.147, 'z_height': 0.5, 'E': 0.11869} shell
# 179 : 4 extrude G1 {'X': 94.373, 'Y': 108.422, 'z_height': 0.5, 'E': 0.18333} shell
# 180 : 4 extrude G1 {'X': 93.956, 'Y': 105.346, 'z_height': 0.5, 'E': 0.20737} shell
# 181 : 4 extrude G1 {'X': 93.877, 'Y': 103.571, 'z_height': 0.5, 'E': 0.1187} shell
# 182 : 4 extrude G1 {'X': 93.468, 'Y': 99.661, 'z_height': 0.5, 'E': 0.26263} shell
# 183 : 4 extrude G1 {'X': 93.544, 'Y': 98.526, 'z_height': 0.5, 'E': 0.07599} shell
# 184 : 4 extrude G1 {'X': 92.992, 'Y': 94.795, 'z_height': 0.5, 'E': 0.25196} shell
# 185 : 4 extrude G1 {'X': 92.774, 'Y': 94.411, 'z_height': 0.5, 'E': 0.0295} shell
# 186 : 4 extrude G1 {'X': 92.184, 'Y': 92.151, 'z_height': 0.5, 'E': 0.15604} shell
# 187 : 4 extrude G1 {'X': 92.09, 'Y': 91.989, 'z_height': 0.5, 'E': 0.01251} shell
# 188 : 4 extrude G1 {'X': 91.74, 'Y': 91.197, 'z_height': 0.5, 'E': 0.05785} shell
# 189 : 4 extrude G1 {'X': 91.584, 'Y': 90.843, 'z_height': 0.5, 'E': 0.02584} shell
# 190 : 4 extrude G1 {'X': 91.554, 'Y': 90.775, 'z_height': 0.5, 'E': 0.00497} shell
# 191 : 4 extrude G1 {'X': 91.358, 'Y': 90.227, 'z_height': 0.5, 'E': 0.03888} shell
# 192 : 4 extrude G1 {'X': 91.163, 'Y': 88.912, 'z_height': 0.5, 'E': 0.08881} shell
# 193 : 4 travel G1 {'X': 91.536, 'Y': 88.995, 'z_height': 0.5, 'E': 0} shell
# 194 : 4 travel G1 {'X': 94.587, 'Y': 88.381, 'z_height': 0.5, 'E': -0.8} shell
# 195 : 4 travel G1 {'X': 92.635, 'Y': 89.959, 'z_height': 0.5, 'E': 0} shell
# 196 : 4 extrude G1 {'X': 92.691, 'Y': 91.19, 'z_height': 0.5, 'E': 0.06413} fill
# 197 : 4 extrude G1 {'X': 93.02, 'Y': 91.918, 'z_height': 0.5, 'E': 0.04158} fill
# 198 : 4 extrude G1 {'X': 93.168, 'Y': 92.485, 'z_height': 0.5, 'E': 0.0305} fill
# 199 : 4 extrude G1 {'X': 93.062, 'Y': 90.166, 'z_height': 0.5, 'E': 0.12081} fill
# 200 : 4 extrude G1 {'X': 93.484, 'Y': 90.255, 'z_height': 0.5, 'E': 0.02245} fill
# 201 : 4 extrude G1 {'X': 93.663, 'Y': 94.197, 'z_height': 0.5, 'E': 0.20537} fill
# 202 : 4 extrude G1 {'X': 93.737, 'Y': 94.316, 'z_height': 0.5, 'E': 0.00729} fill
# 203 : 4 extrude G1 {'X': 93.812, 'Y': 94.499, 'z_height': 0.5, 'E': 0.01029} fill
# 204 : 4 extrude G1 {'X': 93.849, 'Y': 94.662, 'z_height': 0.5, 'E': 0.0087} fill
# 205 : 4 extrude G1 {'X': 94.215, 'Y': 97.148, 'z_height': 0.5, 'E': 0.13077} fill
# 206 : 4 extrude G1 {'X': 93.907, 'Y': 90.375, 'z_height': 0.5, 'E': 0.35285} fill
# 207 : 4 extrude G1 {'X': 94.153, 'Y': 90.5, 'z_height': 0.5, 'E': 0.01436} fill
# 208 : 4 extrude G1 {'X': 94.336, 'Y': 90.626, 'z_height': 0.5, 'E': 0.01156} fill
# 209 : 4 extrude G1 {'X': 95.076, 'Y': 106.909, 'z_height': 0.5, 'E': 0.8483} fill
# 210 : 4 extrude G1 {'X': 95.32, 'Y': 106.803, 'z_height': 0.5, 'E': 0.01385} fill
# 211 : 4 extrude G1 {'X': 95.484, 'Y': 106.694, 'z_height': 0.5, 'E': 0.01025} fill
# 212 : 4 extrude G1 {'X': 94.782, 'Y': 91.238, 'z_height': 0.5, 'E': 0.80521} fill
# 213 : 4 extrude G1 {'X': 95.273, 'Y': 92.856, 'z_height': 0.5, 'E': 0.088} fill
# 214 : 4 extrude G1 {'X': 95.883, 'Y': 106.293, 'z_height': 0.5, 'E': 0.70003} fill
# 215 : 4 extrude G1 {'X': 96.025, 'Y': 106.092, 'z_height': 0.5, 'E': 0.01281} fill
# 216 : 4 extrude G1 {'X': 96.162, 'Y': 105.773, 'z_height': 0.5, 'E': 0.01807} fill
# 217 : 4 extrude G1 {'X': 96.213, 'Y': 105.558, 'z_height': 0.5, 'E': 0.0115} fill
# 218 : 4 extrude G1 {'X': 96.224, 'Y': 105.252, 'z_height': 0.5, 'E': 0.01594} fill
# 219 : 4 extrude G1 {'X': 96.156, 'Y': 104.434, 'z_height': 0.5, 'E': 0.04272} fill
# 220 : 4 extrude G1 {'X': 96.11, 'Y': 104.267, 'z_height': 0.5, 'E': 0.00901} fill
# 221 : 4 extrude G1 {'X': 96.007, 'Y': 104.029, 'z_height': 0.5, 'E': 0.0135} fill
# 222 : 4 extrude G1 {'X': 96.182, 'Y': 103.679, 'z_height': 0.5, 'E': 0.02037} fill
# 223 : 4 extrude G1 {'X': 95.739, 'Y': 93.912, 'z_height': 0.5, 'E': 0.50883} fill
# 224 : 4 extrude G1 {'X': 95.866, 'Y': 94.122, 'z_height': 0.5, 'E': 0.01277} fill
# 225 : 4 extrude G1 {'X': 95.968, 'Y': 94.358, 'z_height': 0.5, 'E': 0.01338} fill
# 226 : 4 extrude G1 {'X': 96.029, 'Y': 94.596, 'z_height': 0.5, 'E': 0.01279} fill
# 227 : 4 extrude G1 {'X': 96.087, 'Y': 95.012, 'z_height': 0.5, 'E': 0.02186} fill
# 228 : 4 extrude G1 {'X': 96.09, 'Y': 95.234, 'z_height': 0.5, 'E': 0.01155} fill
# 229 : 4 extrude G1 {'X': 96.028, 'Y': 96.081, 'z_height': 0.5, 'E': 0.0442} fill
# 230 : 4 extrude G1 {'X': 96.343, 'Y': 98.023, 'z_height': 0.5, 'E': 0.10239} fill
# 231 : 4 extrude G1 {'X': 96.565, 'Y': 102.914, 'z_height': 0.5, 'E': 0.25481} fill
# 232 : 4 extrude G1 {'X': 96.819, 'Y': 102.392, 'z_height': 0.5, 'E': 0.03021} fill
# 233 : 4 extrude G1 {'X': 96.886, 'Y': 102.182, 'z_height': 0.5, 'E': 0.01147} fill
# 234 : 4 extrude G1 {'X': 96.923, 'Y': 101.984, 'z_height': 0.5, 'E': 0.01048} fill
# 235 : 4 extrude G1 {'X': 96.931, 'Y': 101.769, 'z_height': 0.5, 'E': 0.0112} fill
# 236 : 4 extrude G1 {'X': 96.85, 'Y': 99.986, 'z_height': 0.5, 'E': 0.09289} fill
# 237 : 4 travel G1 {'X': 96.931, 'Y': 101.769, 'z_height': 0.5, 'E': -0.41212} fill
# 238 : 4 travel G1 {'X': 96.923, 'Y': 101.984, 'z_height': 0.5, 'E': -0.04968} fill
# 239 : 4 travel G1 {'X': 96.886, 'Y': 102.182, 'z_height': 0.5, 'E': -0.04651} fill
# 240 : 4 travel G1 {'X': 96.819, 'Y': 102.392, 'z_height': 0.5, 'E': -0.0509} fill
# 241 : 4 travel G1 {'X': 96.565, 'Y': 102.914, 'z_height': 0.5, 'E': -0.13404} fill
# 242 : 4 travel G1 {'X': 96.544, 'Y': 102.452, 'z_height': 0.5, 'E': -0.10675} fill
# 243 : 4 travel G1 {'X': 100.285, 'Y': 139.289, 'z_height': 0.5, 'E': 0} fill
# 244 : 4 extrude G1 {'X': 101.708, 'Y': 139.076, 'z_height': 0.5, 'E': 0.07756} fill
# 245 : 4 extrude G1 {'X': 101.818, 'Y': 139.017, 'z_height': 0.5, 'E': 0.00673} fill
# 246 : 4 extrude G1 {'X': 103.383, 'Y': 138.477, 'z_height': 0.5, 'E': 0.08924} fill
# 247 : 4 extrude G1 {'X': 103.498, 'Y': 138.37, 'z_height': 0.5, 'E': 0.00847} fill
# 248 : 4 extrude G1 {'X': 100.516, 'Y': 138.818, 'z_height': 0.5, 'E': 0.16254} fill
# 249 : 4 extrude G1 {'X': 100.573, 'Y': 138.574, 'z_height': 0.5, 'E': 0.01351} fill
# 250 : 4 extrude G1 {'X': 100.672, 'Y': 138.357, 'z_height': 0.5, 'E': 0.01286} fill
# 251 : 4 extrude G1 {'X': 107.293, 'Y': 137.364, 'z_height': 0.5, 'E': 0.36087} fill
# 252 : 4 travel G1 {'X': 103.867, 'Y': 137.878, 'z_height': 0.5, 'E': -0.8} fill
# 253 : 4 travel G1 {'X': 148.22, 'Y': 131.662, 'z_height': 0.5, 'E': 0} fill
# 254 : 4 extrude G1 {'X': 149.939, 'Y': 131.404, 'z_height': 0.5, 'E': 0.09369} fill
# 255 : 4 extrude G1 {'X': 149.869, 'Y': 130.978, 'z_height': 0.5, 'E': 0.02327} fill
# 256 : 4 extrude G1 {'X': 145.115, 'Y': 131.691, 'z_height': 0.5, 'E': 0.25911} fill
# 257 : 4 travel G1 {'X': 148.541, 'Y': 131.177, 'z_height': 0.5, 'E': -0.8} fill
# 258 : 4 travel G1 {'X': 149.995, 'Y': 130.522, 'z_height': 0.5, 'E': 0} fill
# 259 : 4 extrude G1 {'X': 142.716, 'Y': 131.614, 'z_height': 0.5, 'E': 0.39674} fill
# 260 : 4 extrude G1 {'X': 136.598, 'Y': 132.184, 'z_height': 0.5, 'E': 0.3312} fill
# 261 : 4 extrude G1 {'X': 134.355, 'Y': 132.533, 'z_height': 0.5, 'E': 0.12235} fill
# 262 : 4 extrude G1 {'X': 130.7, 'Y': 133.051, 'z_height': 0.5, 'E': 0.19898} fill
# 263 : 4 extrude G1 {'X': 124.837, 'Y': 134.007, 'z_height': 0.5, 'E': 0.3202} fill
# 264 : 4 extrude G1 {'X': 122.484, 'Y': 134.336, 'z_height': 0.5, 'E': 0.12806} fill
# 265 : 4 extrude G1 {'X': 116.697, 'Y': 135.204, 'z_height': 0.5, 'E': 0.31542} fill
# 266 : 4 extrude G1 {'X': 113.177, 'Y': 135.779, 'z_height': 0.5, 'E': 0.19225} fill
# 267 : 4 extrude G1 {'X': 108.949, 'Y': 136.679, 'z_height': 0.5, 'E': 0.233} fill
# 268 : 4 extrude G1 {'X': 100.889, 'Y': 137.888, 'z_height': 0.5, 'E': 0.4393} fill
# 269 : 4 extrude G1 {'X': 100.962, 'Y': 137.604, 'z_height': 0.5, 'E': 0.01581} fill
# 270 : 4 extrude G1 {'X': 100.966, 'Y': 137.439, 'z_height': 0.5, 'E': 0.0089} fill
# 271 : 4 extrude G1 {'X': 149.676, 'Y': 130.133, 'z_height': 0.5, 'E': 2.65489} fill
# 272 : 4 extrude G1 {'X': 149.16, 'Y': 129.773, 'z_height': 0.5, 'E': 0.03391} fill
# 273 : 4 extrude G1 {'X': 100.979, 'Y': 137.0, 'z_height': 0.5, 'E': 2.62606} fill
# 274 : 4 extrude G1 {'X': 100.992, 'Y': 136.561, 'z_height': 0.5, 'E': 0.02367} fill
# 275 : 4 extrude G1 {'X': 148.506, 'Y': 129.434, 'z_height': 0.5, 'E': 2.58971} fill
# 276 : 4 extrude G1 {'X': 148.166, 'Y': 129.38, 'z_height': 0.5, 'E': 0.01856} fill
# 277 : 4 extrude G1 {'X': 146.923, 'Y': 129.353, 'z_height': 0.5, 'E': 0.06701} fill
# 278 : 4 extrude G1 {'X': 146.73, 'Y': 129.264, 'z_height': 0.5, 'E': 0.01146} fill
# 279 : 4 extrude G1 {'X': 101.048, 'Y': 136.116, 'z_height': 0.5, 'E': 2.48986} fill
# 280 : 4 extrude G1 {'X': 101.138, 'Y': 135.84, 'z_height': 0.5, 'E': 0.01565} fill
# 281 : 4 extrude G1 {'X': 101.24, 'Y': 135.65, 'z_height': 0.5, 'E': 0.01162} fill
# 282 : 4 extrude G1 {'X': 146.022, 'Y': 128.933, 'z_height': 0.5, 'E': 2.4408} fill
# 283 : 4 extrude G1 {'X': 145.314, 'Y': 128.602, 'z_height': 0.5, 'E': 0.04213} fill
# 284 : 4 extrude G1 {'X': 101.752, 'Y': 135.136, 'z_height': 0.5, 'E': 2.37431} fill
# 285 : 4 extrude G1 {'X': 102.536, 'Y': 134.582, 'z_height': 0.5, 'E': 0.05174} fill
# 286 : 4 extrude G1 {'X': 144.605, 'Y': 128.271, 'z_height': 0.5, 'E': 2.29294} fill
# 287 : 4 extrude G1 {'X': 143.897, 'Y': 127.941, 'z_height': 0.5, 'E': 0.0421} fill
# 288 : 4 extrude G1 {'X': 104.22, 'Y': 133.892, 'z_height': 0.5, 'E': 2.16256} fill
# 289 : 4 extrude G1 {'X': 104.925, 'Y': 133.617, 'z_height': 0.5, 'E': 0.04079} fill
# 290 : 4 extrude G1 {'X': 105.435, 'Y': 133.273, 'z_height': 0.5, 'E': 0.03316} fill
# 291 : 4 extrude G1 {'X': 143.189, 'Y': 127.61, 'z_height': 0.5, 'E': 2.05775} fill
# 292 : 4 extrude G1 {'X': 142.481, 'Y': 127.279, 'z_height': 0.5, 'E': 0.04213} fill
# 293 : 4 extrude G1 {'X': 106.268, 'Y': 132.711, 'z_height': 0.5, 'E': 1.97376} fill
# 294 : 4 extrude G1 {'X': 106.552, 'Y': 132.549, 'z_height': 0.5, 'E': 0.01762} fill
# 295 : 4 extrude G1 {'X': 106.843, 'Y': 132.452, 'z_height': 0.5, 'E': 0.01653} fill
# 296 : 4 extrude G1 {'X': 110.842, 'Y': 131.629, 'z_height': 0.5, 'E': 0.22007} fill
# 297 : 4 extrude G1 {'X': 111.143, 'Y': 131.543, 'z_height': 0.5, 'E': 0.01687} fill
# 298 : 4 extrude G1 {'X': 113.697, 'Y': 131.16, 'z_height': 0.5, 'E': 0.1392} fill
# 299 : 4 extrude G1 {'X': 122.163, 'Y': 130.088, 'z_height': 0.5, 'E': 0.45997} fill
# 300 : 4 extrude G1 {'X': 127.613, 'Y': 129.072, 'z_height': 0.5, 'E': 0.29882} fill
# 301 : 4 extrude G1 {'X': 141.772, 'Y': 126.948, 'z_height': 0.5, 'E': 0.77173} fill
# 302 : 4 extrude G1 {'X': 141.306, 'Y': 126.745, 'z_height': 0.5, 'E': 0.0274} fill
# 303 : 4 extrude G1 {'X': 141.055, 'Y': 126.683, 'z_height': 0.5, 'E': 0.01394} fill
# 304 : 4 extrude G1 {'X': 140.86, 'Y': 126.661, 'z_height': 0.5, 'E': 0.01058} fill
# 305 : 4 extrude G1 {'X': 139.426, 'Y': 126.863, 'z_height': 0.5, 'E': 0.07806} fill
# 306 : 4 travel G1 {'X': 140.86, 'Y': 126.661, 'z_height': 0.5, 'E': -0.33438} fill
# 307 : 4 travel G1 {'X': 141.055, 'Y': 126.683, 'z_height': 0.5, 'E': -0.04531} fill
# 308 : 4 travel G1 {'X': 141.306, 'Y': 126.745, 'z_height': 0.5, 'E': -0.0597} fill
# 309 : 4 travel G1 {'X': 141.772, 'Y': 126.948, 'z_height': 0.5, 'E': -0.11737} fill
# 310 : 4 travel G1 {'X': 140.73, 'Y': 127.104, 'z_height': 0.5, 'E': -0.24324} fill
# 311 : 4 travel G1 {'X': 140.172, 'Y': 82.608, 'z_height': 0.5, 'E': 0} fill
# 312 : 4 extrude G1 {'X': 141.905, 'Y': 82.35, 'z_height': 0.5, 'E': 0.0935} fill
# 313 : 4 extrude G1 {'X': 141.907, 'Y': 82.783, 'z_height': 0.5, 'E': 0.02311} fill
# 314 : 4 extrude G1 {'X': 128.558, 'Y': 84.766, 'z_height': 0.5, 'E': 0.7202} fill
# 315 : 4 extrude G1 {'X': 128.699, 'Y': 84.983, 'z_height': 0.5, 'E': 0.01381} fill
# 316 : 4 extrude G1 {'X': 128.867, 'Y': 85.152, 'z_height': 0.5, 'E': 0.01272} fill
# 317 : 4 extrude G1 {'X': 141.788, 'Y': 83.233, 'z_height': 0.5, 'E': 0.6971} fill
# 318 : 4 extrude G1 {'X': 141.671, 'Y': 83.45, 'z_height': 0.5, 'E': 0.01316} fill
# 319 : 4 extrude G1 {'X': 141.47, 'Y': 83.713, 'z_height': 0.5, 'E': 0.01766} fill
# 320 : 4 extrude G1 {'X': 129.312, 'Y': 85.519, 'z_height': 0.5, 'E': 0.65594} fill
# 321 : 4 extrude G1 {'X': 129.621, 'Y': 85.648, 'z_height': 0.5, 'E': 0.01787} fill
# 322 : 4 extrude G1 {'X': 129.841, 'Y': 85.697, 'z_height': 0.5, 'E': 0.01203} fill
# 323 : 4 extrude G1 {'X': 130.953, 'Y': 85.708, 'z_height': 0.5, 'E': 0.05935} fill
# 324 : 4 extrude G1 {'X': 141.091, 'Y': 84.202, 'z_height': 0.5, 'E': 0.54696} fill
# 325 : 4 extrude G1 {'X': 140.874, 'Y': 84.479, 'z_height': 0.5, 'E': 0.01878} fill
# 326 : 4 extrude G1 {'X': 140.669, 'Y': 84.697, 'z_height': 0.5, 'E': 0.01597} fill
# 327 : 4 extrude G1 {'X': 133.785, 'Y': 85.72, 'z_height': 0.5, 'E': 0.3714} fill
# 328 : 4 extrude G1 {'X': 136.568, 'Y': 85.739, 'z_height': 0.5, 'E': 0.14852} fill
# 329 : 4 extrude G1 {'X': 140.188, 'Y': 85.201, 'z_height': 0.5, 'E': 0.19531} fill
# 330 : 4 extrude G1 {'X': 139.976, 'Y': 85.411, 'z_height': 0.5, 'E': 0.01592} fill
# 331 : 4 extrude G1 {'X': 139.786, 'Y': 85.555, 'z_height': 0.5, 'E': 0.01272} fill
# 332 : 4 extrude G1 {'X': 139.601, 'Y': 85.659, 'z_height': 0.5, 'E': 0.01133} fill
# 333 : 4 extrude G1 {'X': 139.359, 'Y': 85.747, 'z_height': 0.5, 'E': 0.01374} fill
# 334 : 4 extrude G1 {'X': 137.642, 'Y': 86.012, 'z_height': 0.5, 'E': 0.09271} fill
# 335 : 4 travel G1 {'X': 139.359, 'Y': 85.747, 'z_height': 0.5, 'E': -0.40115} fill
# 336 : 4 travel G1 {'X': 139.601, 'Y': 85.659, 'z_height': 0.5, 'E': -0.05946} fill
# 337 : 4 travel G1 {'X': 139.786, 'Y': 85.555, 'z_height': 0.5, 'E': -0.049} fill
# 338 : 4 travel G1 {'X': 139.976, 'Y': 85.411, 'z_height': 0.5, 'E': -0.05505} fill
# 339 : 4 travel G1 {'X': 140.188, 'Y': 85.201, 'z_height': 0.5, 'E': -0.0689} fill
# 340 : 4 travel G1 {'X': 139.475, 'Y': 85.307, 'z_height': 0.5, 'E': -0.16644} fill
# 341 : 4 travel G1 {'X': 142.301, 'Y': 81.921, 'z_height': 0.5, 'E': 0} fill
# 342 : 4 extrude G1 {'X': 142.39, 'Y': 82.596, 'z_height': 0.5, 'E': 0.04751} fill
# 343 : 4 extrude G1 {'X': 142.53, 'Y': 83.147, 'z_height': 0.5, 'E': 0.03089} fill
# 344 : 4 extrude G1 {'X': 141.95, 'Y': 83.75, 'z_height': 0.5, 'E': 0.04546} fill
# 345 : 4 extrude G1 {'X': 141.818, 'Y': 83.904, 'z_height': 0.5, 'E': 0.01021} fill
# 346 : 4 extrude G1 {'X': 141.149, 'Y': 84.663, 'z_height': 0.5, 'E': 0.0469} fill
# 347 : 4 extrude G1 {'X': 140.29, 'Y': 85.545, 'z_height': 0.5, 'E': 0.05221} fill
# 348 : 4 extrude G1 {'X': 139.851, 'Y': 85.92, 'z_height': 0.5, 'E': 0.02448} fill
# 349 : 4 extrude G1 {'X': 139.765, 'Y': 85.912, 'z_height': 0.5, 'E': 0.00366} fill
# 350 : 4 extrude G1 {'X': 139.422, 'Y': 85.981, 'z_height': 0.5, 'E': 0.01484} fill
# 351 : 4 travel G1 {'X': 139.765, 'Y': 85.912, 'z_height': 0.5, 'E': -0.08079} fill
# 352 : 4 travel G1 {'X': 139.851, 'Y': 85.92, 'z_height': 0.5, 'E': -0.01994} fill
# 353 : 4 travel G1 {'X': 140.29, 'Y': 85.545, 'z_height': 0.5, 'E': -0.13331} fill
# 354 : 4 travel G1 {'X': 140.295, 'Y': 85.541, 'z_height': 0.5, 'E': -0.00148} fill
# 355 : 4 travel G1 {'X': 141.141, 'Y': 84.672, 'z_height': 0.5, 'E': -0.28004} fill
# 356 : 4 travel G1 {'X': 141.149, 'Y': 84.663, 'z_height': 0.5, 'E': -0.00278} fill
# 357 : 4 travel G1 {'X': 141.818, 'Y': 83.904, 'z_height': 0.5, 'E': -0.23362} fill
# 358 : 4 travel G1 {'X': 141.95, 'Y': 83.75, 'z_height': 0.5, 'E': -0.04683} fill
# 359 : 4 travel G1 {'X': 141.953, 'Y': 83.746, 'z_height': 0.5, 'E': -0.00121} fill
# 360 : 4 travel G1 {'X': 95.183, 'Y': 89.178, 'z_height': 0.5, 'E': 0} fill
# 361 : 4 extrude G1 {'X': 98.122, 'Y': 88.743, 'z_height': 0.5, 'E': 0.16142} fill
# 362 : 4 extrude G1 {'X': 95.325, 'Y': 91.54, 'z_height': 0.5, 'E': 0.21492} fill
# 363 : 4 extrude G1 {'X': 95.196, 'Y': 91.13, 'z_height': 0.5, 'E': 0.02335} fill
# 364 : 4 extrude G1 {'X': 94.916, 'Y': 90.636, 'z_height': 0.5, 'E': 0.03085} fill
# 365 : 4 extrude G1 {'X': 94.554, 'Y': 90.259, 'z_height': 0.5, 'E': 0.0284} fill
# 366 : 4 extrude G1 {'X': 94.12, 'Y': 90.006, 'z_height': 0.5, 'E': 0.02729} fill
# 367 : 4 extrude G1 {'X': 93.743, 'Y': 89.875, 'z_height': 0.5, 'E': 0.02168} fill
# 368 : 4 extrude G1 {'X': 93.484, 'Y': 89.841, 'z_height': 0.5, 'E': 0.01419} fill
# 369 : 4 extrude G1 {'X': 93.224, 'Y': 89.807, 'z_height': 0.5, 'E': 0.01313} fill
# 370 : 4 extrude G1 {'X': 92.965, 'Y': 89.773, 'z_height': 0.5, 'E': 0.01197} fill
# 371 : 4 extrude G1 {'X': 92.465, 'Y': 89.802, 'z_height': 0.5, 'E': 0.02083} fill
# 372 : 4 extrude G1 {'X': 92.131, 'Y': 89.874, 'z_height': 0.5, 'E': 0.01336} fill
# 373 : 4 extrude G1 {'X': 92.083, 'Y': 89.549, 'z_height': 0.5, 'E': 0.01285} fill
# 374 : 4 extrude G1 {'X': 92.438, 'Y': 89.497, 'z_height': 0.5, 'E': 0.01403} fill
# 375 : 4 extrude G1 {'X': 93.016, 'Y': 89.44, 'z_height': 0.5, 'E': 0.02563} fill
# 376 : 4 extrude G1 {'X': 93.388, 'Y': 89.409, 'z_height': 0.5, 'E': 0.01838} fill
# 377 : 4 extrude G1 {'X': 93.759, 'Y': 89.378, 'z_height': 0.5, 'E': 0.02023} fill
# 378 : 4 extrude G1 {'X': 94.967, 'Y': 89.21, 'z_height': 0.5, 'E': 0.06627} fill
# 379 : 4 travel G1 {'X': 93.759, 'Y': 89.378, 'z_height': 0.5, 'E': -0.28162} fill
# 380 : 4 travel G1 {'X': 93.388, 'Y': 89.409, 'z_height': 0.5, 'E': -0.08596} fill
# 381 : 4 travel G1 {'X': 93.016, 'Y': 89.44, 'z_height': 0.5, 'E': -0.08619} fill
# 382 : 4 travel G1 {'X': 92.438, 'Y': 89.497, 'z_height': 0.5, 'E': -0.13411} fill
# 383 : 4 travel G1 {'X': 92.083, 'Y': 89.549, 'z_height': 0.5, 'E': -0.08285} fill
# 384 : 4 travel G1 {'X': 92.131, 'Y': 89.874, 'z_height': 0.5, 'E': -0.07586} fill
# 385 : 4 travel G1 {'X': 92.357, 'Y': 89.825, 'z_height': 0.5, 'E': -0.05341} fill
# 386 : 4 travel G1 {'X': 96.728, 'Y': 89.521, 'z_height': 0.5, 'E': 0} fill
# 387 : 4 extrude G1 {'X': 95.49, 'Y': 90.759, 'z_height': 0.5, 'E': 0.09513} fill
# 388 : 4 extrude G1 {'X': 95.339, 'Y': 90.481, 'z_height': 0.5, 'E': 0.01719} fill
# 389 : 4 extrude G1 {'X': 94.909, 'Y': 89.989, 'z_height': 0.5, 'E': 0.0355} fill
# 390 : 4 extrude G1 {'X': 94.488, 'Y': 89.716, 'z_height': 0.5, 'E': 0.02726} fill
# 391 : 4 extrude G1 {'X': 96.882, 'Y': 89.367, 'z_height': 0.5, 'E': 0.13145} fill
# 392 : 4 travel G1 {'X': 95.027, 'Y': 89.641, 'z_height': 0.5, 'E': -0.43297} fill
# 393 : 4 travel G1 {'X': 94.488, 'Y': 89.716, 'z_height': 0.5, 'E': -0.12566} fill
# 394 : 4 travel G1 {'X': 94.909, 'Y': 89.989, 'z_height': 0.5, 'E': -0.11586} fill
# 395 : 4 travel G1 {'X': 95.267, 'Y': 90.398, 'z_height': 0.5, 'E': -0.12551} fill
# 396 : 4 travel G1 {'X': 98.845, 'Y': 88.636, 'z_height': 0.5, 'E': 0} fill
# 397 : 4 extrude G1 {'X': 95.467, 'Y': 92.014, 'z_height': 0.5, 'E': 0.25956} fill
# 398 : 4 extrude G1 {'X': 95.608, 'Y': 92.49, 'z_height': 0.5, 'E': 0.02697} fill
# 399 : 4 extrude G1 {'X': 99.568, 'Y': 88.529, 'z_height': 0.5, 'E': 0.30432} fill
# 400 : 4 extrude G1 {'X': 100.291, 'Y': 88.422, 'z_height': 0.5, 'E': 0.03971} fill
# 401 : 4 extrude G1 {'X': 95.748, 'Y': 92.965, 'z_height': 0.5, 'E': 0.34908} fill
# 402 : 4 extrude G1 {'X': 95.921, 'Y': 93.409, 'z_height': 0.5, 'E': 0.02589} fill
# 403 : 4 extrude G1 {'X': 101.014, 'Y': 88.316, 'z_height': 0.5, 'E': 0.39134} fill
# 404 : 4 extrude G1 {'X': 101.737, 'Y': 88.209, 'z_height': 0.5, 'E': 0.03971} fill
# 405 : 4 extrude G1 {'X': 96.161, 'Y': 93.784, 'z_height': 0.5, 'E': 0.42841} fill
# 406 : 4 extrude G1 {'X': 96.363, 'Y': 94.199, 'z_height': 0.5, 'E': 0.02508} fill
# 407 : 4 extrude G1 {'X': 102.46, 'Y': 88.102, 'z_height': 0.5, 'E': 0.46848} fill
# 408 : 4 extrude G1 {'X': 103.183, 'Y': 87.995, 'z_height': 0.5, 'E': 0.03971} fill
# 409 : 4 extrude G1 {'X': 96.475, 'Y': 94.703, 'z_height': 0.5, 'E': 0.51543} fill
# 410 : 4 extrude G1 {'X': 96.512, 'Y': 95.281, 'z_height': 0.5, 'E': 0.03147} fill
# 411 : 4 extrude G1 {'X': 103.906, 'Y': 87.888, 'z_height': 0.5, 'E': 0.5681} fill
# 412 : 4 extrude G1 {'X': 104.631, 'Y': 87.778, 'z_height': 0.5, 'E': 0.03984} fill
# 413 : 4 extrude G1 {'X': 96.464, 'Y': 95.946, 'z_height': 0.5, 'E': 0.62758} fill
# 414 : 4 extrude G1 {'X': 96.526, 'Y': 96.499, 'z_height': 0.5, 'E': 0.03023} fill
# 415 : 4 extrude G1 {'X': 105.36, 'Y': 87.666, 'z_height': 0.5, 'E': 0.67875} fill
# 416 : 4 extrude G1 {'X': 106.088, 'Y': 87.554, 'z_height': 0.5, 'E': 0.04002} fill
# 417 : 4 extrude G1 {'X': 96.612, 'Y': 97.029, 'z_height': 0.5, 'E': 0.72808} fill
# 418 : 4 extrude G1 {'X': 96.698, 'Y': 97.56, 'z_height': 0.5, 'E': 0.02923} fill
# 419 : 4 extrude G1 {'X': 106.816, 'Y': 87.442, 'z_height': 0.5, 'E': 0.77745} fill
# 420 : 4 extrude G1 {'X': 107.544, 'Y': 87.33, 'z_height': 0.5, 'E': 0.04002} fill
# 421 : 4 extrude G1 {'X': 96.784, 'Y': 98.09, 'z_height': 0.5, 'E': 0.82678} fill
# 422 : 4 extrude G1 {'X': 96.87, 'Y': 98.62, 'z_height': 0.5, 'E': 0.02917} fill
# 423 : 4 extrude G1 {'X': 108.272, 'Y': 87.218, 'z_height': 0.5, 'E': 0.87611} fill
# 424 : 4 extrude G1 {'X': 109.0, 'Y': 87.106, 'z_height': 0.5, 'E': 0.04002} fill
# 425 : 4 extrude G1 {'X': 96.956, 'Y': 99.15, 'z_height': 0.5, 'E': 0.92544} fill
# 426 : 4 extrude G1 {'X': 97.042, 'Y': 99.68, 'z_height': 0.5, 'E': 0.02917} fill
# 427 : 4 extrude G1 {'X': 109.728, 'Y': 86.994, 'z_height': 0.5, 'E': 0.97477} fill
# 428 : 4 extrude G1 {'X': 110.456, 'Y': 86.882, 'z_height': 0.5, 'E': 0.04002} fill
# 429 : 4 extrude G1 {'X': 97.128, 'Y': 100.21, 'z_height': 0.5, 'E': 1.0241} fill
# 430 : 4 extrude G1 {'X': 97.214, 'Y': 100.74, 'z_height': 0.5, 'E': 0.02917} fill
# 431 : 4 extrude G1 {'X': 111.185, 'Y': 86.77, 'z_height': 0.5, 'E': 1.07347} fill
# 432 : 4 extrude G1 {'X': 111.913, 'Y': 86.657, 'z_height': 0.5, 'E': 0.04003} fill
# 433 : 4 extrude G1 {'X': 97.3, 'Y': 101.27, 'z_height': 0.5, 'E': 1.12284} fill
# 434 : 4 extrude G1 {'X': 97.356, 'Y': 101.83, 'z_height': 0.5, 'E': 0.03058} fill
# 435 : 4 extrude G1 {'X': 112.641, 'Y': 86.545, 'z_height': 0.5, 'E': 1.17447} fill
# 436 : 4 extrude G1 {'X': 113.369, 'Y': 86.433, 'z_height': 0.5, 'E': 0.04002} fill
# 437 : 4 extrude G1 {'X': 97.186, 'Y': 102.616, 'z_height': 0.5, 'E': 1.24347} fill
# 438 : 4 extrude G1 {'X': 97.096, 'Y': 102.765, 'z_height': 0.5, 'E': 0.00946} fill
# 439 : 4 extrude G1 {'X': 97.006, 'Y': 102.913, 'z_height': 0.5, 'E': 0.00838} fill
# 440 : 4 extrude G1 {'X': 96.934, 'Y': 102.894, 'z_height': 0.5, 'E': 0.00316} fill
# 441 : 4 extrude G1 {'X': 96.953, 'Y': 102.965, 'z_height': 0.5, 'E': 0.00312} fill
# 442 : 4 extrude G1 {'X': 96.995, 'Y': 102.954, 'z_height': 0.5, 'E': 0.00184} fill
# 443 : 4 travel G1 {'X': 96.953, 'Y': 102.965, 'z_height': 0.5, 'E': -0.01003} fill
# 444 : 4 travel G1 {'X': 96.934, 'Y': 102.894, 'z_height': 0.5, 'E': -0.01697} fill
# 445 : 4 travel G1 {'X': 97.006, 'Y': 102.913, 'z_height': 0.5, 'E': -0.01719} fill
# 446 : 4 travel G1 {'X': 97.096, 'Y': 102.765, 'z_height': 0.5, 'E': -0.04} fill
# 447 : 4 travel G1 {'X': 97.186, 'Y': 102.616, 'z_height': 0.5, 'E': -0.04019} fill
# 448 : 4 travel G1 {'X': 99.255, 'Y': 100.547, 'z_height': 0.5, 'E': -0.67562} fill
# 449 : 4 travel G1 {'X': 96.362, 'Y': 104.072, 'z_height': 0.5, 'E': 0} fill
# 450 : 4 extrude G1 {'X': 96.321, 'Y': 104.083, 'z_height': 0.5, 'E': 0.0018} fill
# 451 : 4 extrude G1 {'X': 96.302, 'Y': 104.012, 'z_height': 0.5, 'E': 0.00312} fill
# 452 : 4 extrude G1 {'X': 96.373, 'Y': 104.031, 'z_height': 0.5, 'E': 0.00312} fill
# 453 : 4 extrude G1 {'X': 96.474, 'Y': 103.937, 'z_height': 0.5, 'E': 0.00667} fill
# 454 : 4 extrude G1 {'X': 114.097, 'Y': 86.321, 'z_height': 0.5, 'E': 1.35385} fill
# 455 : 4 extrude G1 {'X': 114.825, 'Y': 86.209, 'z_height': 0.5, 'E': 0.04002} fill
# 456 : 4 extrude G1 {'X': 96.589, 'Y': 104.446, 'z_height': 0.5, 'E': 1.40126} fill
# 457 : 4 extrude G1 {'X': 96.634, 'Y': 105.016, 'z_height': 0.5, 'E': 0.03107} fill
# 458 : 4 extrude G1 {'X': 115.553, 'Y': 86.097, 'z_height': 0.5, 'E': 1.4537} fill
# 459 : 4 extrude G1 {'X': 116.282, 'Y': 85.985, 'z_height': 0.5, 'E': 0.04007} fill
# 460 : 4 extrude G1 {'X': 96.63, 'Y': 105.636, 'z_height': 0.5, 'E': 1.50999} fill
# 461 : 4 extrude G1 {'X': 96.557, 'Y': 105.785, 'z_height': 0.5, 'E': 0.00901} fill
# 462 : 4 extrude G1 {'X': 96.484, 'Y': 105.933, 'z_height': 0.5, 'E': 0.00798} fill
# 463 : 4 extrude G1 {'X': 96.413, 'Y': 105.914, 'z_height': 0.5, 'E': 0.00312} fill
# 464 : 4 extrude G1 {'X': 96.432, 'Y': 105.985, 'z_height': 0.5, 'E': 0.00312} fill
# 465 : 4 extrude G1 {'X': 96.473, 'Y': 105.974, 'z_height': 0.5, 'E': 0.0018} fill
# 466 : 4 travel G1 {'X': 96.432, 'Y': 105.985, 'z_height': 0.5, 'E': -0.0098} fill
# 467 : 4 travel G1 {'X': 96.413, 'Y': 105.914, 'z_height': 0.5, 'E': -0.01697} fill
# 468 : 4 travel G1 {'X': 96.484, 'Y': 105.933, 'z_height': 0.5, 'E': -0.01697} fill
# 469 : 4 travel G1 {'X': 96.557, 'Y': 105.785, 'z_height': 0.5, 'E': -0.0381} fill
# 470 : 4 travel G1 {'X': 96.63, 'Y': 105.636, 'z_height': 0.5, 'E': -0.03831} fill
# 471 : 4 travel G1 {'X': 98.712, 'Y': 103.554, 'z_height': 0.5, 'E': -0.67985} fill
# 472 : 4 travel G1 {'X': 95.096, 'Y': 107.27, 'z_height': 0.5, 'E': 0} fill
# 473 : 4 extrude G1 {'X': 95.025, 'Y': 107.251, 'z_height': 0.5, 'E': 0.00312} fill
# 474 : 4 extrude G1 {'X': 95.044, 'Y': 107.322, 'z_height': 0.5, 'E': 0.00312} fill
# 475 : 4 extrude G1 {'X': 95.085, 'Y': 107.311, 'z_height': 0.5, 'E': 0.0018} fill
# 476 : 4 extrude G1 {'X': 95.124, 'Y': 107.515, 'z_height': 0.5, 'E': 0.01005} fill
# 477 : 4 extrude G1 {'X': 95.164, 'Y': 107.719, 'z_height': 0.5, 'E': 0.01129} fill
# 478 : 4 extrude G1 {'X': 117.01, 'Y': 85.873, 'z_height': 0.5, 'E': 1.67861} fill
# 479 : 4 extrude G1 {'X': 117.738, 'Y': 85.761, 'z_height': 0.5, 'E': 0.04002} fill
# 480 : 4 extrude G1 {'X': 95.237, 'Y': 108.261, 'z_height': 0.5, 'E': 1.7289} fill
# 481 : 4 extrude G1 {'X': 95.311, 'Y': 108.804, 'z_height': 0.5, 'E': 0.02978} fill
# 482 : 4 extrude G1 {'X': 118.466, 'Y': 85.649, 'z_height': 0.5, 'E': 1.77919} fill
# 483 : 4 extrude G1 {'X': 119.194, 'Y': 85.537, 'z_height': 0.5, 'E': 0.04002} fill
# 484 : 4 extrude G1 {'X': 95.375, 'Y': 109.356, 'z_height': 0.5, 'E': 1.83021} fill
# 485 : 4 extrude G1 {'X': 95.438, 'Y': 109.908, 'z_height': 0.5, 'E': 0.03019} fill
# 486 : 4 extrude G1 {'X': 119.922, 'Y': 85.425, 'z_height': 0.5, 'E': 1.88127} fill
# 487 : 4 extrude G1 {'X': 120.65, 'Y': 85.313, 'z_height': 0.5, 'E': 0.04002} fill
# 488 : 4 extrude G1 {'X': 95.502, 'Y': 110.461, 'z_height': 0.5, 'E': 1.93233} fill
# 489 : 4 extrude G1 {'X': 95.566, 'Y': 111.013, 'z_height': 0.5, 'E': 0.03019} fill
# 490 : 4 extrude G1 {'X': 121.357, 'Y': 85.222, 'z_height': 0.5, 'E': 1.98173} fill
# 491 : 4 extrude G1 {'X': 122.05, 'Y': 85.144, 'z_height': 0.5, 'E': 0.03789} fill
# 492 : 4 extrude G1 {'X': 95.647, 'Y': 111.548, 'z_height': 0.5, 'E': 2.0288} fill
# 493 : 4 extrude G1 {'X': 95.729, 'Y': 112.082, 'z_height': 0.5, 'E': 0.02935} fill
# 494 : 4 extrude G1 {'X': 122.744, 'Y': 85.067, 'z_height': 0.5, 'E': 2.07578} fill
# 495 : 4 extrude G1 {'X': 123.444, 'Y': 84.983, 'z_height': 0.5, 'E': 0.03831} fill
# 496 : 4 extrude G1 {'X': 95.811, 'Y': 112.616, 'z_height': 0.5, 'E': 2.12327} fill
# 497 : 4 extrude G1 {'X': 95.893, 'Y': 113.15, 'z_height': 0.5, 'E': 0.02935} fill
# 498 : 4 extrude G1 {'X': 124.154, 'Y': 84.889, 'z_height': 0.5, 'E': 2.17152} fill
# 499 : 4 extrude G1 {'X': 124.865, 'Y': 84.794, 'z_height': 0.5, 'E': 0.03897} fill
# 500 : 4 extrude G1 {'X': 95.975, 'Y': 113.684, 'z_height': 0.5, 'E': 2.21986} fill
# 501 : 4 extrude G1 {'X': 96.057, 'Y': 114.218, 'z_height': 0.5, 'E': 0.02935} fill
# 502 : 4 extrude G1 {'X': 125.575, 'Y': 84.7, 'z_height': 0.5, 'E': 2.26811} fill
# 503 : 4 extrude G1 {'X': 126.286, 'Y': 84.606, 'z_height': 0.5, 'E': 0.03897} fill
# 504 : 4 extrude G1 {'X': 96.139, 'Y': 114.752, 'z_height': 0.5, 'E': 2.3164} fill
# 505 : 4 extrude G1 {'X': 96.221, 'Y': 115.286, 'z_height': 0.5, 'E': 0.02935} fill
# 506 : 4 extrude G1 {'X': 126.978, 'Y': 84.529, 'z_height': 0.5, 'E': 2.36331} fill
# 507 : 4 extrude G1 {'X': 127.622, 'Y': 84.502, 'z_height': 0.5, 'E': 0.03502} fill
# 508 : 4 extrude G1 {'X': 96.303, 'Y': 115.82, 'z_height': 0.5, 'E': 2.40646} fill
# 509 : 4 extrude G1 {'X': 96.385, 'Y': 116.354, 'z_height': 0.5, 'E': 0.02935} fill
# 510 : 4 extrude G1 {'X': 128.056, 'Y': 84.684, 'z_height': 0.5, 'E': 2.4335} fill
# 511 : 4 extrude G1 {'X': 128.09, 'Y': 84.541, 'z_height': 0.5, 'E': 0.00799} fill
# 512 : 4 extrude G1 {'X': 128.124, 'Y': 84.398, 'z_height': 0.5, 'E': 0.00711} fill
# 513 : 4 extrude G1 {'X': 128.083, 'Y': 84.409, 'z_height': 0.5, 'E': 0.0018} fill
# 514 : 4 extrude G1 {'X': 128.064, 'Y': 84.338, 'z_height': 0.5, 'E': 0.00312} fill
# 515 : 4 extrude G1 {'X': 128.135, 'Y': 84.357, 'z_height': 0.5, 'E': 0.00312} fill
# 516 : 4 extrude G1 {'X': 128.258, 'Y': 85.097, 'z_height': 0.5, 'E': 0.04076} fill
# 517 : 4 extrude G1 {'X': 96.467, 'Y': 116.888, 'z_height': 0.5, 'E': 2.44276} fill
# 518 : 4 extrude G1 {'X': 96.55, 'Y': 117.422, 'z_height': 0.5, 'E': 0.02936} fill
# 519 : 4 extrude G1 {'X': 128.542, 'Y': 85.43, 'z_height': 0.5, 'E': 2.45821} fill
# 520 : 4 extrude G1 {'X': 128.86, 'Y': 85.728, 'z_height': 0.5, 'E': 0.02368} fill
# 521 : 4 extrude G1 {'X': 96.632, 'Y': 117.956, 'z_height': 0.5, 'E': 2.47634} fill
# 522 : 4 extrude G1 {'X': 96.714, 'Y': 118.49, 'z_height': 0.5, 'E': 0.02935} fill
# 523 : 4 extrude G1 {'X': 129.247, 'Y': 85.956, 'z_height': 0.5, 'E': 2.49982} fill
# 524 : 4 extrude G1 {'X': 129.714, 'Y': 86.106, 'z_height': 0.5, 'E': 0.02665} fill
# 525 : 4 extrude G1 {'X': 96.796, 'Y': 119.024, 'z_height': 0.5, 'E': 2.52936} fill
# 526 : 4 extrude G1 {'X': 96.878, 'Y': 119.558, 'z_height': 0.5, 'E': 0.02935} fill
# 527 : 4 extrude G1 {'X': 130.306, 'Y': 86.13, 'z_height': 0.5, 'E': 2.56855} fill
# 528 : 4 extrude G1 {'X': 130.92, 'Y': 86.132, 'z_height': 0.5, 'E': 0.03336} fill
# 529 : 4 extrude G1 {'X': 96.96, 'Y': 120.092, 'z_height': 0.5, 'E': 2.60942} fill
# 530 : 4 extrude G1 {'X': 97.042, 'Y': 120.626, 'z_height': 0.5, 'E': 0.02935} fill
# 531 : 4 extrude G1 {'X': 131.533, 'Y': 86.135, 'z_height': 0.5, 'E': 2.65023} fill
# 532 : 4 extrude G1 {'X': 132.147, 'Y': 86.137, 'z_height': 0.5, 'E': 0.03336} fill
# 533 : 4 extrude G1 {'X': 97.124, 'Y': 121.16, 'z_height': 0.5, 'E': 2.6911} fill
# 534 : 4 extrude G1 {'X': 97.206, 'Y': 121.694, 'z_height': 0.5, 'E': 0.02935} fill
# 535 : 4 extrude G1 {'X': 132.76, 'Y': 86.14, 'z_height': 0.5, 'E': 2.7319} fill
# 536 : 4 extrude G1 {'X': 133.374, 'Y': 86.143, 'z_height': 0.5, 'E': 0.03336} fill
# 537 : 4 extrude G1 {'X': 97.288, 'Y': 122.228, 'z_height': 0.5, 'E': 2.77274} fill
# 538 : 4 extrude G1 {'X': 97.37, 'Y': 122.762, 'z_height': 0.5, 'E': 0.02935} fill
# 539 : 4 extrude G1 {'X': 133.987, 'Y': 86.145, 'z_height': 0.5, 'E': 2.81358} fill
# 540 : 4 extrude G1 {'X': 134.601, 'Y': 86.148, 'z_height': 0.5, 'E': 0.03336} fill
# 541 : 4 extrude G1 {'X': 97.452, 'Y': 123.296, 'z_height': 0.5, 'E': 2.85442} fill
# 542 : 4 extrude G1 {'X': 97.534, 'Y': 123.83, 'z_height': 0.5, 'E': 0.02935} fill
# 543 : 4 extrude G1 {'X': 135.214, 'Y': 86.15, 'z_height': 0.5, 'E': 2.89526} fill
# 544 : 4 extrude G1 {'X': 135.828, 'Y': 86.153, 'z_height': 0.5, 'E': 0.03336} fill
# 545 : 4 extrude G1 {'X': 97.616, 'Y': 124.364, 'z_height': 0.5, 'E': 2.9361} fill
# 546 : 4 extrude G1 {'X': 97.698, 'Y': 124.898, 'z_height': 0.5, 'E': 0.02935} fill
# 547 : 4 extrude G1 {'X': 136.441, 'Y': 86.155, 'z_height': 0.5, 'E': 2.97694} fill
# 548 : 4 extrude G1 {'X': 137.012, 'Y': 86.2, 'z_height': 0.5, 'E': 0.03112} fill
# 549 : 4 extrude G1 {'X': 97.78, 'Y': 125.432, 'z_height': 0.5, 'E': 3.01452} fill
# 550 : 4 extrude G1 {'X': 97.862, 'Y': 125.966, 'z_height': 0.5, 'E': 0.02935} fill
# 551 : 4 extrude G1 {'X': 137.582, 'Y': 86.246, 'z_height': 0.5, 'E': 3.05201} fill
# 552 : 4 extrude G1 {'X': 138.153, 'Y': 86.292, 'z_height': 0.5, 'E': 0.03112} fill
# 553 : 4 extrude G1 {'X': 97.944, 'Y': 126.5, 'z_height': 0.5, 'E': 3.08955} fill
# 554 : 4 extrude G1 {'X': 98.026, 'Y': 127.034, 'z_height': 0.5, 'E': 0.02935} fill
# 555 : 4 extrude G1 {'X': 138.782, 'Y': 86.279, 'z_height': 0.5, 'E': 3.13158} fill
# 556 : 4 extrude G1 {'X': 139.543, 'Y': 86.134, 'z_height': 0.5, 'E': 0.04209} fill
# 557 : 4 extrude G1 {'X': 98.108, 'Y': 127.568, 'z_height': 0.5, 'E': 3.18375} fill
# 558 : 4 extrude G1 {'X': 98.19, 'Y': 128.102, 'z_height': 0.5, 'E': 0.02935} fill
# 559 : 4 extrude G1 {'X': 142.605, 'Y': 83.688, 'z_height': 0.5, 'E': 3.41273} fill
# 560 : 4 extrude G1 {'X': 142.897, 'Y': 84.061, 'z_height': 0.5, 'E': 0.02574} fill
# 561 : 4 extrude G1 {'X': 142.826, 'Y': 84.042, 'z_height': 0.5, 'E': 0.00312} fill
# 562 : 4 extrude G1 {'X': 142.845, 'Y': 84.113, 'z_height': 0.5, 'E': 0.00312} fill
# 563 : 4 extrude G1 {'X': 142.886, 'Y': 84.102, 'z_height': 0.5, 'E': 0.0018} fill
# 564 : 4 extrude G1 {'X': 142.783, 'Y': 84.165, 'z_height': 0.5, 'E': 0.00584} fill
# 565 : 4 extrude G1 {'X': 142.68, 'Y': 84.229, 'z_height': 0.5, 'E': 0.00659} fill
# 566 : 4 extrude G1 {'X': 98.206, 'Y': 128.71, 'z_height': 0.5, 'E': 3.41757} fill
# 567 : 4 extrude G1 {'X': 98.14, 'Y': 128.783, 'z_height': 0.5, 'E': 0.00491} fill
# 568 : 4 extrude G1 {'X': 98.064, 'Y': 128.762, 'z_height': 0.5, 'E': 0.00359} fill
# 569 : 4 extrude G1 {'X': 98.084, 'Y': 128.839, 'z_height': 0.5, 'E': 0.00362} fill
# 570 : 4 extrude G1 {'X': 98.128, 'Y': 128.827, 'z_height': 0.5, 'E': 0.00207} fill
# 571 : 4 extrude G1 {'X': 98.35, 'Y': 129.175, 'z_height': 0.5, 'E': 0.02243} fill
# 572 : 4 extrude G1 {'X': 142.756, 'Y': 84.769, 'z_height': 0.5, 'E': 3.41208} fill
# 573 : 4 extrude G1 {'X': 142.835, 'Y': 85.306, 'z_height': 0.5, 'E': 0.02949} fill
# 574 : 4 extrude G1 {'X': 98.428, 'Y': 129.713, 'z_height': 0.5, 'E': 3.41215} fill
# 575 : 4 extrude G1 {'X': 98.506, 'Y': 130.251, 'z_height': 0.5, 'E': 0.02954} fill
# 576 : 4 extrude G1 {'X': 142.915, 'Y': 85.842, 'z_height': 0.5, 'E': 3.41231} fill
# 577 : 4 extrude G1 {'X': 142.994, 'Y': 86.379, 'z_height': 0.5, 'E': 0.02949} fill
# 578 : 4 extrude G1 {'X': 98.584, 'Y': 130.789, 'z_height': 0.5, 'E': 3.41238} fill
# 579 : 4 extrude G1 {'X': 98.662, 'Y': 131.327, 'z_height': 0.5, 'E': 0.02954} fill
# 580 : 4 extrude G1 {'X': 143.074, 'Y': 86.916, 'z_height': 0.5, 'E': 3.4125} fill
# ...
# 636 : 4 extrude G1 {'X': 100.559, 'Y': 136.823, 'z_height': 0.5, 'E': 0.04806} fill
# 637 : 4 travel G1 {'X': 99.933, 'Y': 137.448, 'z_height': 0.5, 'E': -0.20425} fill
# 638 : 4 travel G1 {'X': 99.863, 'Y': 137.496, 'z_height': 0.5, 'E': -0.0196} fill
# 639 : 4 travel G1 {'X': 99.625, 'Y': 137.448, 'z_height': 0.5, 'E': -0.05606} fill
# 640 : 4 travel G1 {'X': 99.54, 'Y': 137.363, 'z_height': 0.5, 'E': -0.02776} fill
# 641 : 4 travel G1 {'X': 99.741, 'Y': 138.747, 'z_height': 0.5, 'E': -0.32292} fill
# 642 : 4 travel G1 {'X': 99.749, 'Y': 138.921, 'z_height': 0.5, 'E': -0.04022} fill
# 643 : 4 travel G1 {'X': 99.758, 'Y': 139.096, 'z_height': 0.5, 'E': -0.04046} fill
# 644 : 4 travel G1 {'X': 99.766, 'Y': 139.271, 'z_height': 0.5, 'E': -0.04045} fill
# 645 : 4 travel G1 {'X': 99.796, 'Y': 139.478, 'z_height': 0.5, 'E': -0.04828} fill
# 646 : 4 travel G1 {'X': 103.495, 'Y': 133.844, 'z_height': 0.5, 'E': 0} fill
# 647 : 4 extrude G1 {'X': 103.454, 'Y': 133.855, 'z_height': 0.5, 'E': 0.0018} fill
# 648 : 4 extrude G1 {'X': 103.435, 'Y': 133.784, 'z_height': 0.5, 'E': 0.00312} fill
# 649 : 4 extrude G1 {'X': 103.506, 'Y': 133.803, 'z_height': 0.5, 'E': 0.00312} fill
# 650 : 4 extrude G1 {'X': 103.638, 'Y': 133.707, 'z_height': 0.5, 'E': 0.00789} fill
# 651 : 4 extrude G1 {'X': 103.77, 'Y': 133.612, 'z_height': 0.5, 'E': 0.00884} fill
# 652 : 4 extrude G1 {'X': 144.026, 'Y': 93.355, 'z_height': 0.5, 'E': 3.09324} fill
# 653 : 4 extrude G1 {'X': 144.106, 'Y': 93.892, 'z_height': 0.5, 'E': 0.0295} fill
# 654 : 4 extrude G1 {'X': 104.828, 'Y': 133.17, 'z_height': 0.5, 'E': 3.01805} fill
# 655 : 4 extrude G1 {'X': 104.696, 'Y': 133.273, 'z_height': 0.5, 'E': 0.0091} fill
# 656 : 4 extrude G1 {'X': 104.564, 'Y': 133.377, 'z_height': 0.5, 'E': 0.00813} fill
# 657 : 4 extrude G1 {'X': 104.493, 'Y': 133.358, 'z_height': 0.5, 'E': 0.00312} fill
# 658 : 4 extrude G1 {'X': 104.512, 'Y': 133.429, 'z_height': 0.5, 'E': 0.00312} fill
# 659 : 4 extrude G1 {'X': 104.553, 'Y': 133.418, 'z_height': 0.5, 'E': 0.0018} fill
# 660 : 4 travel G1 {'X': 104.512, 'Y': 133.429, 'z_height': 0.5, 'E': -0.0098} fill
# 661 : 4 travel G1 {'X': 104.493, 'Y': 133.358, 'z_height': 0.5, 'E': -0.01697} fill
# 662 : 4 travel G1 {'X': 104.564, 'Y': 133.377, 'z_height': 0.5, 'E': -0.01697} fill
# 663 : 4 travel G1 {'X': 104.696, 'Y': 133.273, 'z_height': 0.5, 'E': -0.0388} fill
# 664 : 4 travel G1 {'X': 104.828, 'Y': 133.17, 'z_height': 0.5, 'E': -0.03866} fill
# 665 : 4 travel G1 {'X': 106.907, 'Y': 131.091, 'z_height': 0.5, 'E': -0.6788} fill
# 666 : 4 travel G1 {'X': 106.652, 'Y': 132.246, 'z_height': 0.5, 'E': 0} fill
# 667 : 4 extrude G1 {'X': 106.366, 'Y': 132.34, 'z_height': 0.5, 'E': 0.01277} fill
# 668 : 4 extrude G1 {'X': 106.195, 'Y': 132.329, 'z_height': 0.5, 'E': 0.00727} fill
# 669 : 4 extrude G1 {'X': 106.349, 'Y': 132.22, 'z_height': 0.5, 'E': 0.00913} fill
# 670 : 4 extrude G1 {'X': 106.503, 'Y': 132.111, 'z_height': 0.5, 'E': 0.01025} fill
# 671 : 4 extrude G1 {'X': 144.187, 'Y': 94.427, 'z_height': 0.5, 'E': 2.89557} fill
# 672 : 4 extrude G1 {'X': 144.269, 'Y': 94.961, 'z_height': 0.5, 'E': 0.02935} fill
# 673 : 4 extrude G1 {'X': 107.308, 'Y': 131.922, 'z_height': 0.5, 'E': 2.84002} fill
# 674 : 4 extrude G1 {'X': 108.083, 'Y': 131.763, 'z_height': 0.5, 'E': 0.04298} fill
# 675 : 4 extrude G1 {'X': 144.351, 'Y': 95.495, 'z_height': 0.5, 'E': 2.78677} fill
# 676 : 4 extrude G1 {'X': 144.434, 'Y': 96.029, 'z_height': 0.5, 'E': 0.02936} fill
# 677 : 4 extrude G1 {'X': 108.859, 'Y': 131.603, 'z_height': 0.5, 'E': 2.73348} fill
# 678 : 4 extrude G1 {'X': 109.634, 'Y': 131.444, 'z_height': 0.5, 'E': 0.04298} fill
# 679 : 4 extrude G1 {'X': 144.516, 'Y': 96.562, 'z_height': 0.5, 'E': 2.68027} fill
# 680 : 4 extrude G1 {'X': 144.598, 'Y': 97.096, 'z_height': 0.5, 'E': 0.02935} fill
# 681 : 4 extrude G1 {'X': 110.409, 'Y': 131.285, 'z_height': 0.5, 'E': 2.62702} fill
# 682 : 4 extrude G1 {'X': 111.237, 'Y': 131.074, 'z_height': 0.5, 'E': 0.04643} fill
# 683 : 4 extrude G1 {'X': 144.68, 'Y': 97.63, 'z_height': 0.5, 'E': 2.56974} fill
# 684 : 4 extrude G1 {'X': 144.762, 'Y': 98.164, 'z_height': 0.5, 'E': 0.02935} fill
# 685 : 4 extrude G1 {'X': 111.983, 'Y': 130.944, 'z_height': 0.5, 'E': 2.51872} fill
# 686 : 4 extrude G1 {'X': 112.686, 'Y': 130.857, 'z_height': 0.5, 'E': 0.03849} fill
# 687 : 4 extrude G1 {'X': 144.844, 'Y': 98.698, 'z_height': 0.5, 'E': 2.471} fill
# 688 : 4 extrude G1 {'X': 144.926, 'Y': 99.232, 'z_height': 0.5, 'E': 0.02935} fill
# 689 : 4 extrude G1 {'X': 113.389, 'Y': 130.77, 'z_height': 0.5, 'E': 2.42328} fill
# 690 : 4 extrude G1 {'X': 114.092, 'Y': 130.683, 'z_height': 0.5, 'E': 0.03849} fill
# 691 : 4 extrude G1 {'X': 145.008, 'Y': 99.766, 'z_height': 0.5, 'E': 2.37557} fill
# 692 : 4 extrude G1 {'X': 145.091, 'Y': 100.3, 'z_height': 0.5, 'E': 0.02936} fill
# 693 : 4 extrude G1 {'X': 114.795, 'Y': 130.596, 'z_height': 0.5, 'E': 2.32789} fill
# 694 : 4 extrude G1 {'X': 115.498, 'Y': 130.509, 'z_height': 0.5, 'E': 0.03849} fill
# 695 : 4 extrude G1 {'X': 145.173, 'Y': 100.834, 'z_height': 0.5, 'E': 2.28017} fill
# 696 : 4 extrude G1 {'X': 145.255, 'Y': 101.368, 'z_height': 0.5, 'E': 0.02935} fill
# 697 : 4 extrude G1 {'X': 116.201, 'Y': 130.422, 'z_height': 0.5, 'E': 2.23246} fill
# 698 : 4 extrude G1 {'X': 116.928, 'Y': 130.311, 'z_height': 0.5, 'E': 0.03996} fill
# 699 : 4 extrude G1 {'X': 145.337, 'Y': 101.902, 'z_height': 0.5, 'E': 2.1829} fill
# 700 : 4 extrude G1 {'X': 145.419, 'Y': 102.436, 'z_height': 0.5, 'E': 0.02935} fill
# 701 : 4 extrude G1 {'X': 117.631, 'Y': 130.224, 'z_height': 0.5, 'E': 2.13518} fill
# 702 : 4 extrude G1 {'X': 118.333, 'Y': 130.138, 'z_height': 0.5, 'E': 0.03843} fill
# 703 : 4 extrude G1 {'X': 145.501, 'Y': 102.97, 'z_height': 0.5, 'E': 2.08754} fill
# 704 : 4 extrude G1 {'X': 145.583, 'Y': 103.504, 'z_height': 0.5, 'E': 0.02935} fill
# 705 : 4 extrude G1 {'X': 119.035, 'Y': 130.051, 'z_height': 0.5, 'E': 2.03986} fill
# 706 : 4 extrude G1 {'X': 119.738, 'Y': 129.965, 'z_height': 0.5, 'E': 0.03848} fill
# 707 : 4 extrude G1 {'X': 145.665, 'Y': 104.038, 'z_height': 0.5, 'E': 1.99218} fill
# 708 : 4 extrude G1 {'X': 145.747, 'Y': 104.572, 'z_height': 0.5, 'E': 0.02935} fill
# 709 : 4 extrude G1 {'X': 120.44, 'Y': 129.879, 'z_height': 0.5, 'E': 1.94454} fill
# 710 : 4 extrude G1 {'X': 121.143, 'Y': 129.792, 'z_height': 0.5, 'E': 0.03849} fill
# 711 : 4 extrude G1 {'X': 145.83, 'Y': 105.106, 'z_height': 0.5, 'E': 1.89687} fill
# 712 : 4 extrude G1 {'X': 145.912, 'Y': 105.64, 'z_height': 0.5, 'E': 0.02935} fill
# 713 : 4 extrude G1 {'X': 121.848, 'Y': 129.703, 'z_height': 0.5, 'E': 1.849} fill
# 714 : 4 extrude G1 {'X': 122.591, 'Y': 129.576, 'z_height': 0.5, 'E': 0.04095} fill
# 715 : 4 extrude G1 {'X': 145.994, 'Y': 106.173, 'z_height': 0.5, 'E': 1.79824} fill
# 716 : 4 extrude G1 {'X': 146.076, 'Y': 106.707, 'z_height': 0.5, 'E': 0.02935} fill
# 717 : 4 extrude G1 {'X': 123.348, 'Y': 129.435, 'z_height': 0.5, 'E': 1.74638} fill
# 718 : 4 extrude G1 {'X': 124.106, 'Y': 129.294, 'z_height': 0.5, 'E': 0.04189} fill
# 719 : 4 extrude G1 {'X': 146.158, 'Y': 107.241, 'z_height': 0.5, 'E': 1.69447} fill
# 720 : 4 extrude G1 {'X': 146.24, 'Y': 107.775, 'z_height': 0.5, 'E': 0.02935} fill
# 721 : 4 extrude G1 {'X': 124.863, 'Y': 129.153, 'z_height': 0.5, 'E': 1.64261} fill
# 722 : 4 extrude G1 {'X': 125.62, 'Y': 129.011, 'z_height': 0.5, 'E': 0.04185} fill
# 723 : 4 extrude G1 {'X': 146.322, 'Y': 108.309, 'z_height': 0.5, 'E': 1.5907} fill
# 724 : 4 extrude G1 {'X': 146.404, 'Y': 108.843, 'z_height': 0.5, 'E': 0.02935} fill
# 725 : 4 extrude G1 {'X': 126.377, 'Y': 128.87, 'z_height': 0.5, 'E': 1.53884} fill
# 726 : 4 extrude G1 {'X': 127.127, 'Y': 128.737, 'z_height': 0.5, 'E': 0.04139} fill
# 727 : 4 extrude G1 {'X': 146.486, 'Y': 109.377, 'z_height': 0.5, 'E': 1.48755} fill
# 728 : 4 extrude G1 {'X': 146.569, 'Y': 109.911, 'z_height': 0.5, 'E': 0.02936} fill
# 729 : 4 extrude G1 {'X': 127.901, 'Y': 128.579, 'z_height': 0.5, 'E': 1.43442} fill
# 730 : 4 extrude G1 {'X': 128.677, 'Y': 128.418, 'z_height': 0.5, 'E': 0.04306} fill
# 731 : 4 extrude G1 {'X': 146.651, 'Y': 110.445, 'z_height': 0.5, 'E': 1.38105} fill
# 732 : 4 extrude G1 {'X': 146.733, 'Y': 110.979, 'z_height': 0.5, 'E': 0.02935} fill
# 733 : 4 extrude G1 {'X': 129.454, 'Y': 128.258, 'z_height': 0.5, 'E': 1.32769} fill
# 734 : 4 extrude G1 {'X': 130.231, 'Y': 128.097, 'z_height': 0.5, 'E': 0.04311} fill
# 735 : 4 extrude G1 {'X': 146.815, 'Y': 111.513, 'z_height': 0.5, 'E': 1.27428} fill
# 736 : 4 extrude G1 {'X': 146.897, 'Y': 112.047, 'z_height': 0.5, 'E': 0.02935} fill
# 737 : 4 extrude G1 {'X': 131.008, 'Y': 127.936, 'z_height': 0.5, 'E': 1.22088} fill
# 738 : 4 extrude G1 {'X': 131.77, 'Y': 127.79, 'z_height': 0.5, 'E': 0.04215} fill
# 739 : 4 extrude G1 {'X': 146.979, 'Y': 112.581, 'z_height': 0.5, 'E': 1.16863} fill
# 740 : 4 extrude G1 {'X': 147.061, 'Y': 113.115, 'z_height': 0.5, 'E': 0.02935} fill
# 741 : 4 extrude G1 {'X': 132.472, 'Y': 127.704, 'z_height': 0.5, 'E': 1.12099} fill
# 742 : 4 extrude G1 {'X': 133.211, 'Y': 127.581, 'z_height': 0.5, 'E': 0.0407} fill
# 743 : 4 extrude G1 {'X': 147.143, 'Y': 113.649, 'z_height': 0.5, 'E': 1.07051} fill
# 744 : 4 extrude G1 {'X': 147.225, 'Y': 114.183, 'z_height': 0.5, 'E': 0.02935} fill
# 745 : 4 extrude G1 {'X': 133.95, 'Y': 127.458, 'z_height': 0.5, 'E': 1.02003} fill
# 746 : 4 extrude G1 {'X': 134.689, 'Y': 127.336, 'z_height': 0.5, 'E': 0.0407} fill
# 747 : 4 extrude G1 {'X': 147.308, 'Y': 114.717, 'z_height': 0.5, 'E': 0.96962} fill
# 748 : 4 extrude G1 {'X': 147.39, 'Y': 115.251, 'z_height': 0.5, 'E': 0.02935} fill
# 749 : 4 extrude G1 {'X': 135.427, 'Y': 127.213, 'z_height': 0.5, 'E': 0.91918} fill
# 750 : 4 extrude G1 {'X': 136.166, 'Y': 127.09, 'z_height': 0.5, 'E': 0.0407} fill
# 751 : 4 extrude G1 {'X': 147.472, 'Y': 115.784, 'z_height': 0.5, 'E': 0.86873} fill
# 752 : 4 extrude G1 {'X': 147.554, 'Y': 116.318, 'z_height': 0.5, 'E': 0.02935} fill
# 753 : 4 extrude G1 {'X': 136.823, 'Y': 127.05, 'z_height': 0.5, 'E': 0.82459} fill
# 754 : 4 extrude G1 {'X': 137.425, 'Y': 127.063, 'z_height': 0.5, 'E': 0.03272} fill
# 755 : 4 extrude G1 {'X': 147.636, 'Y': 116.852, 'z_height': 0.5, 'E': 0.78459} fill
# 756 : 4 extrude G1 {'X': 147.718, 'Y': 117.386, 'z_height': 0.5, 'E': 0.02935} fill
# 757 : 4 extrude G1 {'X': 138.028, 'Y': 127.076, 'z_height': 0.5, 'E': 0.74456} fill
# 758 : 4 extrude G1 {'X': 138.65, 'Y': 127.019, 'z_height': 0.5, 'E': 0.03394} fill
# 759 : 4 extrude G1 {'X': 138.609, 'Y': 127.03, 'z_height': 0.5, 'E': 0.0018} fill
# 760 : 4 extrude G1 {'X': 138.59, 'Y': 126.959, 'z_height': 0.5, 'E': 0.00312} fill
# 761 : 4 extrude G1 {'X': 138.661, 'Y': 126.978, 'z_height': 0.5, 'E': 0.00312} fill
# 762 : 4 extrude G1 {'X': 138.795, 'Y': 126.885, 'z_height': 0.5, 'E': 0.00789} fill
# 763 : 4 extrude G1 {'X': 138.928, 'Y': 126.792, 'z_height': 0.5, 'E': 0.00882} fill
# 764 : 4 extrude G1 {'X': 147.8, 'Y': 117.92, 'z_height': 0.5, 'E': 0.68171} fill
# 765 : 4 extrude G1 {'X': 147.882, 'Y': 118.454, 'z_height': 0.5, 'E': 0.02935} fill
# 766 : 4 extrude G1 {'X': 139.903, 'Y': 126.434, 'z_height': 0.5, 'E': 0.61313} fill
# 767 : 4 extrude G1 {'X': 139.75, 'Y': 126.533, 'z_height': 0.5, 'E': 0.0099} fill
# 768 : 4 extrude G1 {'X': 139.597, 'Y': 126.631, 'z_height': 0.5, 'E': 0.00879} fill
# 769 : 4 extrude G1 {'X': 139.763, 'Y': 126.65, 'z_height': 0.5, 'E': 0.00709} fill
# 770 : 4 extrude G1 {'X': 139.976, 'Y': 126.585, 'z_height': 0.5, 'E': 0.00944} fill
# 771 : 4 extrude G1 {'X': 140.713, 'Y': 126.24, 'z_height': 0.5, 'E': 0.04421} fill
# 772 : 4 extrude G1 {'X': 147.965, 'Y': 118.988, 'z_height': 0.5, 'E': 0.55723} fill
# 773 : 4 extrude G1 {'X': 148.047, 'Y': 119.522, 'z_height': 0.5, 'E': 0.02935} fill
# 774 : 4 extrude G1 {'X': 141.272, 'Y': 126.297, 'z_height': 0.5, 'E': 0.52058} fill
# 775 : 4 extrude G1 {'X': 141.727, 'Y': 126.458, 'z_height': 0.5, 'E': 0.02622} fill
# 776 : 4 extrude G1 {'X': 148.129, 'Y': 120.056, 'z_height': 0.5, 'E': 0.49192} fill
# 777 : 4 extrude G1 {'X': 148.211, 'Y': 120.59, 'z_height': 0.5, 'E': 0.02935} fill
# 778 : 4 extrude G1 {'X': 142.146, 'Y': 126.654, 'z_height': 0.5, 'E': 0.46599} fill
# 779 : 4 extrude G1 {'X': 142.566, 'Y': 126.85, 'z_height': 0.5, 'E': 0.02518} fill
# 780 : 4 extrude G1 {'X': 148.293, 'Y': 121.124, 'z_height': 0.5, 'E': 0.44001} fill
# 781 : 4 extrude G1 {'X': 148.375, 'Y': 121.658, 'z_height': 0.5, 'E': 0.02935} fill
# 782 : 4 extrude G1 {'X': 142.986, 'Y': 127.047, 'z_height': 0.5, 'E': 0.41408} fill
# 783 : 4 extrude G1 {'X': 143.406, 'Y': 127.243, 'z_height': 0.5, 'E': 0.02518} fill
# 784 : 4 extrude G1 {'X': 148.457, 'Y': 122.192, 'z_height': 0.5, 'E': 0.38811} fill
# 785 : 4 extrude G1 {'X': 148.539, 'Y': 122.726, 'z_height': 0.5, 'E': 0.02935} fill
# 786 : 4 extrude G1 {'X': 143.826, 'Y': 127.439, 'z_height': 0.5, 'E': 0.36214} fill
# 787 : 4 extrude G1 {'X': 144.246, 'Y': 127.635, 'z_height': 0.5, 'E': 0.02518} fill
# 788 : 4 extrude G1 {'X': 148.621, 'Y': 123.26, 'z_height': 0.5, 'E': 0.33617} fill
# 789 : 4 extrude G1 {'X': 148.704, 'Y': 123.794, 'z_height': 0.5, 'E': 0.02936} fill
# 790 : 4 extrude G1 {'X': 144.666, 'Y': 127.831, 'z_height': 0.5, 'E': 0.31023} fill
# 791 : 4 extrude G1 {'X': 145.086, 'Y': 128.027, 'z_height': 0.5, 'E': 0.02518} fill
# 792 : 4 extrude G1 {'X': 148.786, 'Y': 124.328, 'z_height': 0.5, 'E': 0.28426} fill
# 793 : 4 extrude G1 {'X': 148.868, 'Y': 124.861, 'z_height': 0.5, 'E': 0.0293} fill
# 794 : 4 extrude G1 {'X': 145.506, 'Y': 128.223, 'z_height': 0.5, 'E': 0.25833} fill
# 795 : 4 extrude G1 {'X': 145.926, 'Y': 128.419, 'z_height': 0.5, 'E': 0.02518} fill
# 796 : 4 extrude G1 {'X': 148.953, 'Y': 125.392, 'z_height': 0.5, 'E': 0.23259} fill
# 797 : 4 extrude G1 {'X': 149.039, 'Y': 125.923, 'z_height': 0.5, 'E': 0.02923} fill
# 798 : 4 extrude G1 {'X': 146.346, 'Y': 128.615, 'z_height': 0.5, 'E': 0.20689} fill
# 799 : 4 extrude G1 {'X': 147.021, 'Y': 128.931, 'z_height': 0.5, 'E': 0.04049} fill
# 800 : 4 extrude G1 {'X': 148.175, 'Y': 128.955, 'z_height': 0.5, 'E': 0.06271} fill
# 801 : 4 extrude G1 {'X': 148.695, 'Y': 129.048, 'z_height': 0.5, 'E': 0.0287} fill
# 802 : 4 extrude G1 {'X': 149.184, 'Y': 129.277, 'z_height': 0.5, 'E': 0.02934} fill
# 803 : 4 extrude G1 {'X': 149.637, 'Y': 129.59, 'z_height': 0.5, 'E': 0.02992} fill
# 804 : 4 extrude G1 {'X': 149.073, 'Y': 126.138, 'z_height': 0.5, 'E': 0.19004} fill
# 805 : 4 extrude G1 {'X': 148.743, 'Y': 126.834, 'z_height': 0.5, 'E': 0.04185} fill
# 806 : 4 extrude G1 {'X': 147.094, 'Y': 128.484, 'z_height': 0.5, 'E': 0.12674} fill
# 807 : 4 extrude G1 {'X': 148.184, 'Y': 128.519, 'z_height': 0.5, 'E': 0.05925} fill
# 808 : 4 extrude G1 {'X': 148.714, 'Y': 128.602, 'z_height': 0.5, 'E': 0.02915} fill
# 809 : 4 extrude G1 {'X': 149.049, 'Y': 128.731, 'z_height': 0.5, 'E': 0.0195} fill
# 810 : 4 extrude G1 {'X': 148.778, 'Y': 127.049, 'z_height': 0.5, 'E': 0.09257} fill
# 811 : 4 extrude G1 {'X': 148.483, 'Y': 127.638, 'z_height': 0.5, 'E': 0.03579} fill
# 812 : 4 extrude G1 {'X': 147.99, 'Y': 128.131, 'z_height': 0.5, 'E': 0.02892} fill
# 813 : 4 extrude G1 {'X': 148.571, 'Y': 128.188, 'z_height': 0.5, 'E': 0.02422} fill
# 814 : 4 extrude G1 {'X': 148.518, 'Y': 127.853, 'z_height': 0.5, 'E': 0.01407} fill
# 815 : 4 travel G1 {'X': 148.571, 'Y': 128.188, 'z_height': 0.5, 'E': -0.07831} fill
# 816 : 4 travel G1 {'X': 147.99, 'Y': 128.131, 'z_height': 0.5, 'E': -0.1348} fill
# 817 : 4 travel G1 {'X': 148.483, 'Y': 127.638, 'z_height': 0.5, 'E': -0.16099} fill
# 818 : 4 travel G1 {'X': 148.778, 'Y': 127.049, 'z_height': 0.5, 'E': -0.15211} fill
# 819 : 4 travel G1 {'X': 148.914, 'Y': 127.9, 'z_height': 0.5, 'E': -0.19899} fill
# 820 : 4 travel G1 {'X': 148.966, 'Y': 128.22, 'z_height': 0.5, 'E': -0.0748} fill
# 821 : 4 travel G1 {'X': 95.615, 'Y': 90.069, 'z_height': 0.5, 'E': 0} fill
# 822 : 4 extrude G1 {'X': 95.557, 'Y': 90.085, 'z_height': 0.5, 'E': 0.00364} fill
# 823 : 4 extrude G1 {'X': 95.514, 'Y': 90.042, 'z_height': 0.5, 'E': 0.00368} fill
# 824 : 4 extrude G1 {'X': 95.529, 'Y': 89.983, 'z_height': 0.5, 'E': 0.00368} fill
# 825 : 4 extrude G1 {'X': 95.588, 'Y': 89.968, 'z_height': 0.5, 'E': 0.00368} fill
# 826 : 4 extrude G1 {'X': 95.631, 'Y': 90.01, 'z_height': 0.5, 'E': 0.00363} fill

# %%
def segments_to_meshdata(segments):#edges only on extrusion
    segs = segments
    verts=[]
    edges=[]
    props = []

    del_offset=0 #to travel segs in a row, one gets deleted, need to keep track of index for edges
    for i in range(len(segs)):
        print(segs[i].coords)
        #props.append(0)
        if i>=len(segs)-1:
            if segs[i].style == 'extrude':
                verts.append([segs[i].coords['X'],segs[i].coords['Y'],segs[i].coords['z_height'] ])
            break


        #start of extrusion for first time
        if segs[i].style == 'travel' and segs[i+1].style == 'extrude':
            verts.append([segs[i].coords['X'],segs[i].coords['Y'],segs[i].coords['z_height'] ])
            verts.append([segs[i+1].coords['X'],segs[i+1].coords['Y'],segs[i+1].coords['z_height'] ])
            edges.append([i-del_offset,(i-del_offset)+1])

            if segs[i+1].fill == 1:
                props.append('fill')
            elif segs[i+1].shell == 1:
                props.append('shell')
            elif segs[i+1].support == 1:
                props.append('support')
            else:
                props.append('NA')



        #mitte, current and next are extrusion, only add next, current is already in vert list
        if segs[i].style == 'extrude' and segs[i+1].style == 'extrude':
            verts.append([segs[i+1].coords['X'],segs[i+1].coords['Y'],segs[i+1].coords['z_height'] ])
            edges.append([i-del_offset,(i-del_offset)+1])

            if segs[i+1].fill == 1:
                props.append('fill')
            elif segs[i+1].shell == 1:
                props.append('shell')
            elif segs[i+1].support == 1:
                props.append('support')
            else:
                props.append('NA')



        if segs[i].style == 'travel' and segs[i+1].style == 'travel':
            del_offset+=1

    return verts, edges, props

# %%
verts, edges, props = segments_to_meshdata(parser.layers[4]) # LN = 80 => LAYER:79 in gcode

# props (properties) and edges have to have the same length

print(np.shape(verts))
print(np.shape(edges))
print(np.shape(props))
# Out:
# {'X': 132.7, 'Y': 79.868, 'z_height': 0.5, 'E': -0.02217}
# {'X': 132.7, 'Y': 77.9, 'z_height': 0.5, 'E': -0.45442}
# {'X': 131.299, 'Y': 77.9, 'z_height': 0.5, 'E': -0.32341}
# {'X': 136.134, 'Y': 71.83, 'z_height': 0.5, 'E': 0}
# {'X': 144.777, 'Y': 78.715, 'z_height': 0.5, 'E': 0.49013}
# {'X': 145.18, 'Y': 79.124, 'z_height': 0.5, 'E': 0.02547}
# {'X': 145.539, 'Y': 79.733, 'z_height': 0.5, 'E': 0.03136}
# {'X': 145.744, 'Y': 80.396, 'z_height': 0.5, 'E': 0.03078}
# {'X': 153.747, 'Y': 132.45, 'z_height': 0.5, 'E': 2.33597}
# {'X': 153.729, 'Y': 133.347, 'z_height': 0.5, 'E': 0.03979}
# {'X': 153.163, 'Y': 134.559, 'z_height': 0.5, 'E': 0.05933}
# {'X': 150.693, 'Y': 137.362, 'z_height': 0.5, 'E': 0.16571}
# {'X': 149.939, 'Y': 137.933, 'z_height': 0.5, 'E': 0.04195}
# {'X': 138.993, 'Y': 143.197, 'z_height': 0.5, 'E': 0.53873}
# {'X': 138.299, 'Y': 143.407, 'z_height': 0.5, 'E': 0.03216}
# {'X': 121.754, 'Y': 145.747, 'z_height': 0.5, 'E': 0.74115}
# {'X': 113.748, 'Y': 145.744, 'z_height': 0.5, 'E': 0.3551}
# {'X': 100.171, 'Y': 145.112, 'z_height': 0.5, 'E': 0.60286}
# {'X': 98.429, 'Y': 144.227, 'z_height': 0.5, 'E': 0.08667}
# {'X': 96.968, 'Y': 142.397, 'z_height': 0.5, 'E': 0.10386}
# {'X': 86.096, 'Y': 126.168, 'z_height': 0.5, 'E': 0.86643}
# {'X': 85.694, 'Y': 124.845, 'z_height': 0.5, 'E': 0.06133}
# {'X': 85.694, 'Y': 88.447, 'z_height': 0.5, 'E': 1.61443}
# {'X': 86.085, 'Y': 87.14, 'z_height': 0.5, 'E': 0.06051}
# {'X': 86.845, 'Y': 86.41, 'z_height': 0.5, 'E': 0.04674}
# {'X': 116.948, 'Y': 68.285, 'z_height': 0.5, 'E': 1.55856}
# {'X': 118.174, 'Y': 67.944, 'z_height': 0.5, 'E': 0.05644}
# {'X': 128.701, 'Y': 67.944, 'z_height': 0.5, 'E': 0.46692}
# {'X': 129.764, 'Y': 68.195, 'z_height': 0.5, 'E': 0.04845}
# {'X': 134.813, 'Y': 70.778, 'z_height': 0.5, 'E': 0.25155}
# {'X': 136.087, 'Y': 71.793, 'z_height': 0.5, 'E': 0.07225}
# {'X': 138.797, 'Y': 73.952, 'z_height': 0.5, 'E': -0.8}
# {'X': 91.707, 'Y': 89.267, 'z_height': 0.5, 'E': 0}
# {'X': 94.905, 'Y': 88.823, 'z_height': 0.5, 'E': 0.17542}
# {'X': 104.218, 'Y': 87.445, 'z_height': 0.5, 'E': 0.51151}
# {'X': 120.878, 'Y': 84.881, 'z_height': 0.5, 'E': 0.91584}
# {'X': 123.126, 'Y': 84.63, 'z_height': 0.5, 'E': 0.1229}
# {'X': 126.776, 'Y': 84.145, 'z_height': 0.5, 'E': 0.20006}
# {'X': 126.855, 'Y': 84.142, 'z_height': 0.5, 'E': 0.0043}
# {'X': 128.634, 'Y': 84.068, 'z_height': 0.5, 'E': 0.09674}
# {'X': 130.211, 'Y': 83.914, 'z_height': 0.5, 'E': 0.08609}
# {'X': 132.756, 'Y': 83.662, 'z_height': 0.5, 'E': 0.13895}
# {'X': 133.803, 'Y': 83.746, 'z_height': 0.5, 'E': 0.05707}
# {'X': 134.027, 'Y': 83.745, 'z_height': 0.5, 'E': 0.01217}
# {'X': 137.869, 'Y': 83.174, 'z_height': 0.5, 'E': 0.21104}
# {'X': 138.127, 'Y': 83.085, 'z_height': 0.5, 'E': 0.01483}
# {'X': 138.32, 'Y': 82.931, 'z_height': 0.5, 'E': 0.01342}
# {'X': 140.23, 'Y': 82.389, 'z_height': 0.5, 'E': 0.10787}
# {'X': 140.312, 'Y': 82.366, 'z_height': 0.5, 'E': 0.00463}
# {'X': 140.65, 'Y': 82.172, 'z_height': 0.5, 'E': 0.02117}
# {'X': 141.451, 'Y': 81.714, 'z_height': 0.5, 'E': 0.05013}
# {'X': 141.865, 'Y': 81.531, 'z_height': 0.5, 'E': 0.02459}
# {'X': 142.684, 'Y': 81.41, 'z_height': 0.5, 'E': 0.04498}
# {'X': 143.129, 'Y': 84.608, 'z_height': 0.5, 'E': 0.17543}
# {'X': 144.512, 'Y': 93.961, 'z_height': 0.5, 'E': 0.5137}
# {'X': 149.237, 'Y': 124.684, 'z_height': 0.5, 'E': 1.68889}
# {'X': 149.841, 'Y': 128.45, 'z_height': 0.5, 'E': 0.20723}
# {'X': 150.193, 'Y': 130.52, 'z_height': 0.5, 'E': 0.11408}
# {'X': 150.265, 'Y': 131.074, 'z_height': 0.5, 'E': 0.03035}
# {'X': 150.461, 'Y': 132.121, 'z_height': 0.5, 'E': 0.05787}
# {'X': 149.784, 'Y': 131.921, 'z_height': 0.5, 'E': 0.03835}
# {'X': 149.43, 'Y': 131.907, 'z_height': 0.5, 'E': 0.01925}
# {'X': 149.063, 'Y': 131.892, 'z_height': 0.5, 'E': 0.01996}
# {'X': 147.524, 'Y': 131.829, 'z_height': 0.5, 'E': 0.08369}
# {'X': 146.67, 'Y': 131.815, 'z_height': 0.5, 'E': 0.04641}
# {'X': 145.933, 'Y': 131.849, 'z_height': 0.5, 'E': 0.04009}
# {'X': 145.047, 'Y': 131.889, 'z_height': 0.5, 'E': 0.04819}
# {'X': 142.507, 'Y': 132.004, 'z_height': 0.5, 'E': 0.13815}
# {'X': 140.91, 'Y': 132.17, 'z_height': 0.5, 'E': 0.08724}
# {'X': 136.638, 'Y': 132.563, 'z_height': 0.5, 'E': 0.23309}
# {'X': 134.411, 'Y': 132.91, 'z_height': 0.5, 'E': 0.12246}
# {'X': 130.755, 'Y': 133.428, 'z_height': 0.5, 'E': 0.20062}
# {'X': 124.894, 'Y': 134.384, 'z_height': 0.5, 'E': 0.32265}
# {'X': 122.539, 'Y': 134.713, 'z_height': 0.5, 'E': 0.1292}
# {'X': 116.758, 'Y': 135.58, 'z_height': 0.5, 'E': 0.31761}
# {'X': 113.253, 'Y': 136.153, 'z_height': 0.5, 'E': 0.19296}
# {'X': 108.175, 'Y': 137.23, 'z_height': 0.5, 'E': 0.28204}
# {'X': 107.067, 'Y': 137.664, 'z_height': 0.5, 'E': 0.06465}
# {'X': 104.144, 'Y': 138.41, 'z_height': 0.5, 'E': 0.16391}
# {'X': 103.869, 'Y': 138.544, 'z_height': 0.5, 'E': 0.01662}
# {'X': 103.585, 'Y': 138.811, 'z_height': 0.5, 'E': 0.02118}
# {'X': 102.166, 'Y': 139.3, 'z_height': 0.5, 'E': 0.08155}
# {'X': 101.954, 'Y': 139.373, 'z_height': 0.5, 'E': 0.01218}
# {'X': 101.651, 'Y': 139.567, 'z_height': 0.5, 'E': 0.01955}
# {'X': 101.59, 'Y': 139.596, 'z_height': 0.5, 'E': 0.00367}
# {'X': 100.859, 'Y': 139.947, 'z_height': 0.5, 'E': 0.04406}
# {'X': 100.4, 'Y': 140.119, 'z_height': 0.5, 'E': 0.02663}
# {'X': 99.562, 'Y': 140.249, 'z_height': 0.5, 'E': 0.04608}
# {'X': 97.862, 'Y': 128.547, 'z_height': 0.5, 'E': 0.64248}
# {'X': 95.179, 'Y': 111.083, 'z_height': 0.5, 'E': 0.96}
# {'X': 94.925, 'Y': 108.874, 'z_height': 0.5, 'E': 0.12081}
# {'X': 94.609, 'Y': 106.546, 'z_height': 0.5, 'E': 0.12765}
# {'X': 94.44, 'Y': 105.302, 'z_height': 0.5, 'E': 0.06821}
# {'X': 94.342, 'Y': 103.354, 'z_height': 0.5, 'E': 0.10597}
# {'X': 93.955, 'Y': 99.653, 'z_height': 0.5, 'E': 0.20218}
# {'X': 94.031, 'Y': 98.62, 'z_height': 0.5, 'E': 0.05628}
# {'X': 94.025, 'Y': 98.455, 'z_height': 0.5, 'E': 0.00897}
# {'X': 93.472, 'Y': 94.724, 'z_height': 0.5, 'E': 0.20493}
# {'X': 93.447, 'Y': 94.612, 'z_height': 0.5, 'E': 0.00624}
# {'X': 93.225, 'Y': 94.214, 'z_height': 0.5, 'E': 0.02476}
# {'X': 92.654, 'Y': 92.028, 'z_height': 0.5, 'E': 0.12276}
# {'X': 92.589, 'Y': 91.896, 'z_height': 0.5, 'E': 0.00799}
# {'X': 92.488, 'Y': 91.671, 'z_height': 0.5, 'E': 0.0134}
# {'X': 92.005, 'Y': 90.595, 'z_height': 0.5, 'E': 0.06408}
# {'X': 91.831, 'Y': 90.108, 'z_height': 0.5, 'E': 0.0281}
# {'X': 91.715, 'Y': 89.327, 'z_height': 0.5, 'E': 0.0429}
# {'X': 91.162, 'Y': 88.853, 'z_height': 0.5, 'E': 0}
# {'X': 94.838, 'Y': 88.342, 'z_height': 0.5, 'E': 0.24794}
# {'X': 95.63, 'Y': 88.225, 'z_height': 0.5, 'E': 0.05348}
# {'X': 103.309, 'Y': 87.089, 'z_height': 0.5, 'E': 0.51858}
# {'X': 104.147, 'Y': 86.965, 'z_height': 0.5, 'E': 0.05659}
# {'X': 104.984, 'Y': 86.836, 'z_height': 0.5, 'E': 0.05658}
# {'X': 118.36, 'Y': 84.777, 'z_height': 0.5, 'E': 0.90411}
# {'X': 119.249, 'Y': 84.64, 'z_height': 0.5, 'E': 0.06009}
# {'X': 120.814, 'Y': 84.399, 'z_height': 0.5, 'E': 0.10578}
# {'X': 123.056, 'Y': 84.149, 'z_height': 0.5, 'E': 0.15071}
# {'X': 124.154, 'Y': 84.004, 'z_height': 0.5, 'E': 0.07399}
# {'X': 126.734, 'Y': 83.661, 'z_height': 0.5, 'E': 0.17387}
# {'X': 128.629, 'Y': 83.582, 'z_height': 0.5, 'E': 0.12671}
# {'X': 130.061, 'Y': 83.441, 'z_height': 0.5, 'E': 0.09613}
# {'X': 130.911, 'Y': 83.357, 'z_height': 0.5, 'E': 0.05706}
# {'X': 132.752, 'Y': 83.175, 'z_height': 0.5, 'E': 0.12359}
# {'X': 133.956, 'Y': 83.264, 'z_height': 0.5, 'E': 0.08065}
# {'X': 137.841, 'Y': 82.683, 'z_height': 0.5, 'E': 0.26243}
# {'X': 138.06, 'Y': 82.5, 'z_height': 0.5, 'E': 0.01907}
# {'X': 140.179, 'Y': 81.898, 'z_height': 0.5, 'E': 0.14716}
# {'X': 140.768, 'Y': 81.545, 'z_height': 0.5, 'E': 0.04587}
# {'X': 141.142, 'Y': 81.332, 'z_height': 0.5, 'E': 0.02875}
# {'X': 141.211, 'Y': 81.292, 'z_height': 0.5, 'E': 0.00533}
# {'X': 141.732, 'Y': 81.06, 'z_height': 0.5, 'E': 0.0381}
# {'X': 143.098, 'Y': 80.86, 'z_height': 0.5, 'E': 0.09223}
# {'X': 143.61, 'Y': 84.541, 'z_height': 0.5, 'E': 0.24828}
# {'X': 143.727, 'Y': 85.333, 'z_height': 0.5, 'E': 0.05348}
# {'X': 144.868, 'Y': 93.05, 'z_height': 0.5, 'E': 0.52114}
# {'X': 144.993, 'Y': 93.89, 'z_height': 0.5, 'E': 0.05673}
# {'X': 145.122, 'Y': 94.729, 'z_height': 0.5, 'E': 0.05671}
# {'X': 149.591, 'Y': 123.793, 'z_height': 0.5, 'E': 1.96445}
# {'X': 149.717, 'Y': 124.61, 'z_height': 0.5, 'E': 0.05523}
# {'X': 150.319, 'Y': 128.366, 'z_height': 0.5, 'E': 0.25412}
# {'X': 150.677, 'Y': 130.474, 'z_height': 0.5, 'E': 0.14284}
# {'X': 150.742, 'Y': 130.985, 'z_height': 0.5, 'E': 0.03441}
# {'X': 151.074, 'Y': 132.758, 'z_height': 0.5, 'E': 0.1205}
# {'X': 150.426, 'Y': 132.611, 'z_height': 0.5, 'E': 0.04439}
# {'X': 150.111, 'Y': 132.539, 'z_height': 0.5, 'E': 0.02159}
# {'X': 149.822, 'Y': 132.429, 'z_height': 0.5, 'E': 0.02066}
# {'X': 149.765, 'Y': 132.407, 'z_height': 0.5, 'E': 0.00408}
# {'X': 147.505, 'Y': 132.314, 'z_height': 0.5, 'E': 0.15111}
# {'X': 146.692, 'Y': 132.3, 'z_height': 0.5, 'E': 0.05432}
# {'X': 146.549, 'Y': 132.307, 'z_height': 0.5, 'E': 0.00956}
# {'X': 144.435, 'Y': 132.402, 'z_height': 0.5, 'E': 0.14137}
# {'X': 142.558, 'Y': 132.487, 'z_height': 0.5, 'E': 0.12552}
# {'X': 140.958, 'Y': 132.654, 'z_height': 0.5, 'E': 0.10747}
# {'X': 136.682, 'Y': 133.046, 'z_height': 0.5, 'E': 0.28686}
# {'X': 134.483, 'Y': 133.39, 'z_height': 0.5, 'E': 0.14869}
# {'X': 130.823, 'Y': 133.909, 'z_height': 0.5, 'E': 0.24695}
# {'X': 128.51, 'Y': 134.299, 'z_height': 0.5, 'E': 0.1567}
# {'X': 124.966, 'Y': 134.864, 'z_height': 0.5, 'E': 0.23975}
# {'X': 122.614, 'Y': 135.193, 'z_height': 0.5, 'E': 0.15866}
# {'X': 116.839, 'Y': 136.059, 'z_height': 0.5, 'E': 0.39011}
# {'X': 113.353, 'Y': 136.628, 'z_height': 0.5, 'E': 0.23597}
# {'X': 108.276, 'Y': 137.705, 'z_height': 0.5, 'E': 0.34672}
# {'X': 107.218, 'Y': 138.127, 'z_height': 0.5, 'E': 0.0761}
# {'X': 104.217, 'Y': 138.898, 'z_height': 0.5, 'E': 0.20699}
# {'X': 103.844, 'Y': 139.235, 'z_height': 0.5, 'E': 0.03358}
# {'X': 102.113, 'Y': 139.832, 'z_height': 0.5, 'E': 0.12232}
# {'X': 101.927, 'Y': 139.973, 'z_height': 0.5, 'E': 0.01559}
# {'X': 101.493, 'Y': 140.179, 'z_height': 0.5, 'E': 0.03209}
# {'X': 101.174, 'Y': 140.329, 'z_height': 0.5, 'E': 0.02355}
# {'X': 100.933, 'Y': 140.442, 'z_height': 0.5, 'E': 0.01778}
# {'X': 100.4, 'Y': 140.611, 'z_height': 0.5, 'E': 0.03735}
# {'X': 99.148, 'Y': 140.787, 'z_height': 0.5, 'E': 0.08446}
# {'X': 98.666, 'Y': 137.375, 'z_height': 0.5, 'E': 0.2302}
# {'X': 98.557, 'Y': 136.635, 'z_height': 0.5, 'E': 0.04997}
# {'X': 97.505, 'Y': 129.46, 'z_height': 0.5, 'E': 0.48445}
# {'X': 97.382, 'Y': 128.618, 'z_height': 0.5, 'E': 0.05685}
# {'X': 97.252, 'Y': 127.777, 'z_height': 0.5, 'E': 0.05685}
# {'X': 95.104, 'Y': 113.793, 'z_height': 0.5, 'E': 0.94516}
# {'X': 94.967, 'Y': 112.903, 'z_height': 0.5, 'E': 0.06016}
# {'X': 94.697, 'Y': 111.147, 'z_height': 0.5, 'E': 0.11869}
# {'X': 94.373, 'Y': 108.422, 'z_height': 0.5, 'E': 0.18333}
# {'X': 93.956, 'Y': 105.346, 'z_height': 0.5, 'E': 0.20737}
# {'X': 93.877, 'Y': 103.571, 'z_height': 0.5, 'E': 0.1187}
# {'X': 93.468, 'Y': 99.661, 'z_height': 0.5, 'E': 0.26263}
# {'X': 93.544, 'Y': 98.526, 'z_height': 0.5, 'E': 0.07599}
# {'X': 92.992, 'Y': 94.795, 'z_height': 0.5, 'E': 0.25196}
# {'X': 92.774, 'Y': 94.411, 'z_height': 0.5, 'E': 0.0295}
# {'X': 92.184, 'Y': 92.151, 'z_height': 0.5, 'E': 0.15604}
# {'X': 92.09, 'Y': 91.989, 'z_height': 0.5, 'E': 0.01251}
# {'X': 91.74, 'Y': 91.197, 'z_height': 0.5, 'E': 0.05785}
# {'X': 91.584, 'Y': 90.843, 'z_height': 0.5, 'E': 0.02584}
# {'X': 91.554, 'Y': 90.775, 'z_height': 0.5, 'E': 0.00497}
# {'X': 91.358, 'Y': 90.227, 'z_height': 0.5, 'E': 0.03888}
# {'X': 91.163, 'Y': 88.912, 'z_height': 0.5, 'E': 0.08881}
# {'X': 91.536, 'Y': 88.995, 'z_height': 0.5, 'E': 0}
# {'X': 94.587, 'Y': 88.381, 'z_height': 0.5, 'E': -0.8}
# {'X': 92.635, 'Y': 89.959, 'z_height': 0.5, 'E': 0}
# {'X': 92.691, 'Y': 91.19, 'z_height': 0.5, 'E': 0.06413}
# {'X': 93.02, 'Y': 91.918, 'z_height': 0.5, 'E': 0.04158}
# {'X': 93.168, 'Y': 92.485, 'z_height': 0.5, 'E': 0.0305}
# {'X': 93.062, 'Y': 90.166, 'z_height': 0.5, 'E': 0.12081}
# {'X': 93.484, 'Y': 90.255, 'z_height': 0.5, 'E': 0.02245}
# {'X': 93.663, 'Y': 94.197, 'z_height': 0.5, 'E': 0.20537}
# {'X': 93.737, 'Y': 94.316, 'z_height': 0.5, 'E': 0.00729}
# {'X': 93.812, 'Y': 94.499, 'z_height': 0.5, 'E': 0.01029}
# {'X': 93.849, 'Y': 94.662, 'z_height': 0.5, 'E': 0.0087}
# {'X': 94.215, 'Y': 97.148, 'z_height': 0.5, 'E': 0.13077}
# {'X': 93.907, 'Y': 90.375, 'z_height': 0.5, 'E': 0.35285}
# {'X': 94.153, 'Y': 90.5, 'z_height': 0.5, 'E': 0.01436}
# {'X': 94.336, 'Y': 90.626, 'z_height': 0.5, 'E': 0.01156}
# {'X': 95.076, 'Y': 106.909, 'z_height': 0.5, 'E': 0.8483}
# {'X': 95.32, 'Y': 106.803, 'z_height': 0.5, 'E': 0.01385}
# {'X': 95.484, 'Y': 106.694, 'z_height': 0.5, 'E': 0.01025}
# {'X': 94.782, 'Y': 91.238, 'z_height': 0.5, 'E': 0.80521}
# {'X': 95.273, 'Y': 92.856, 'z_height': 0.5, 'E': 0.088}
# {'X': 95.883, 'Y': 106.293, 'z_height': 0.5, 'E': 0.70003}
# {'X': 96.025, 'Y': 106.092, 'z_height': 0.5, 'E': 0.01281}
# {'X': 96.162, 'Y': 105.773, 'z_height': 0.5, 'E': 0.01807}
# {'X': 96.213, 'Y': 105.558, 'z_height': 0.5, 'E': 0.0115}
# {'X': 96.224, 'Y': 105.252, 'z_height': 0.5, 'E': 0.01594}
# {'X': 96.156, 'Y': 104.434, 'z_height': 0.5, 'E': 0.04272}
# {'X': 96.11, 'Y': 104.267, 'z_height': 0.5, 'E': 0.00901}
# {'X': 96.007, 'Y': 104.029, 'z_height': 0.5, 'E': 0.0135}
# {'X': 96.182, 'Y': 103.679, 'z_height': 0.5, 'E': 0.02037}
# {'X': 95.739, 'Y': 93.912, 'z_height': 0.5, 'E': 0.50883}
# {'X': 95.866, 'Y': 94.122, 'z_height': 0.5, 'E': 0.01277}
# {'X': 95.968, 'Y': 94.358, 'z_height': 0.5, 'E': 0.01338}
# {'X': 96.029, 'Y': 94.596, 'z_height': 0.5, 'E': 0.01279}
# {'X': 96.087, 'Y': 95.012, 'z_height': 0.5, 'E': 0.02186}
# {'X': 96.09, 'Y': 95.234, 'z_height': 0.5, 'E': 0.01155}
# {'X': 96.028, 'Y': 96.081, 'z_height': 0.5, 'E': 0.0442}
# {'X': 96.343, 'Y': 98.023, 'z_height': 0.5, 'E': 0.10239}
# {'X': 96.565, 'Y': 102.914, 'z_height': 0.5, 'E': 0.25481}
# {'X': 96.819, 'Y': 102.392, 'z_height': 0.5, 'E': 0.03021}
# {'X': 96.886, 'Y': 102.182, 'z_height': 0.5, 'E': 0.01147}
# {'X': 96.923, 'Y': 101.984, 'z_height': 0.5, 'E': 0.01048}
# {'X': 96.931, 'Y': 101.769, 'z_height': 0.5, 'E': 0.0112}
# {'X': 96.85, 'Y': 99.986, 'z_height': 0.5, 'E': 0.09289}
# {'X': 96.931, 'Y': 101.769, 'z_height': 0.5, 'E': -0.41212}
# {'X': 96.923, 'Y': 101.984, 'z_height': 0.5, 'E': -0.04968}
# {'X': 96.886, 'Y': 102.182, 'z_height': 0.5, 'E': -0.04651}
# {'X': 96.819, 'Y': 102.392, 'z_height': 0.5, 'E': -0.0509}
# {'X': 96.565, 'Y': 102.914, 'z_height': 0.5, 'E': -0.13404}
# {'X': 96.544, 'Y': 102.452, 'z_height': 0.5, 'E': -0.10675}
# {'X': 100.285, 'Y': 139.289, 'z_height': 0.5, 'E': 0}
# {'X': 101.708, 'Y': 139.076, 'z_height': 0.5, 'E': 0.07756}
# {'X': 101.818, 'Y': 139.017, 'z_height': 0.5, 'E': 0.00673}
# {'X': 103.383, 'Y': 138.477, 'z_height': 0.5, 'E': 0.08924}
# {'X': 103.498, 'Y': 138.37, 'z_height': 0.5, 'E': 0.00847}
# {'X': 100.516, 'Y': 138.818, 'z_height': 0.5, 'E': 0.16254}
# {'X': 100.573, 'Y': 138.574, 'z_height': 0.5, 'E': 0.01351}
# {'X': 100.672, 'Y': 138.357, 'z_height': 0.5, 'E': 0.01286}
# {'X': 107.293, 'Y': 137.364, 'z_height': 0.5, 'E': 0.36087}
# {'X': 103.867, 'Y': 137.878, 'z_height': 0.5, 'E': -0.8}
# {'X': 148.22, 'Y': 131.662, 'z_height': 0.5, 'E': 0}
# {'X': 149.939, 'Y': 131.404, 'z_height': 0.5, 'E': 0.09369}
# {'X': 149.869, 'Y': 130.978, 'z_height': 0.5, 'E': 0.02327}
# {'X': 145.115, 'Y': 131.691, 'z_height': 0.5, 'E': 0.25911}
# {'X': 148.541, 'Y': 131.177, 'z_height': 0.5, 'E': -0.8}
# {'X': 149.995, 'Y': 130.522, 'z_height': 0.5, 'E': 0}
# {'X': 142.716, 'Y': 131.614, 'z_height': 0.5, 'E': 0.39674}
# {'X': 136.598, 'Y': 132.184, 'z_height': 0.5, 'E': 0.3312}
# {'X': 134.355, 'Y': 132.533, 'z_height': 0.5, 'E': 0.12235}
# {'X': 130.7, 'Y': 133.051, 'z_height': 0.5, 'E': 0.19898}
# {'X': 124.837, 'Y': 134.007, 'z_height': 0.5, 'E': 0.3202}
# {'X': 122.484, 'Y': 134.336, 'z_height': 0.5, 'E': 0.12806}
# {'X': 116.697, 'Y': 135.204, 'z_height': 0.5, 'E': 0.31542}
# {'X': 113.177, 'Y': 135.779, 'z_height': 0.5, 'E': 0.19225}
# {'X': 108.949, 'Y': 136.679, 'z_height': 0.5, 'E': 0.233}
# {'X': 100.889, 'Y': 137.888, 'z_height': 0.5, 'E': 0.4393}
# {'X': 100.962, 'Y': 137.604, 'z_height': 0.5, 'E': 0.01581}
# {'X': 100.966, 'Y': 137.439, 'z_height': 0.5, 'E': 0.0089}
# {'X': 149.676, 'Y': 130.133, 'z_height': 0.5, 'E': 2.65489}
# {'X': 149.16, 'Y': 129.773, 'z_height': 0.5, 'E': 0.03391}
# {'X': 100.979, 'Y': 137.0, 'z_height': 0.5, 'E': 2.62606}
# {'X': 100.992, 'Y': 136.561, 'z_height': 0.5, 'E': 0.02367}
# {'X': 148.506, 'Y': 129.434, 'z_height': 0.5, 'E': 2.58971}
# {'X': 148.166, 'Y': 129.38, 'z_height': 0.5, 'E': 0.01856}
# {'X': 146.923, 'Y': 129.353, 'z_height': 0.5, 'E': 0.06701}
# {'X': 146.73, 'Y': 129.264, 'z_height': 0.5, 'E': 0.01146}
# {'X': 101.048, 'Y': 136.116, 'z_height': 0.5, 'E': 2.48986}
# {'X': 101.138, 'Y': 135.84, 'z_height': 0.5, 'E': 0.01565}
# {'X': 101.24, 'Y': 135.65, 'z_height': 0.5, 'E': 0.01162}
# {'X': 146.022, 'Y': 128.933, 'z_height': 0.5, 'E': 2.4408}
# {'X': 145.314, 'Y': 128.602, 'z_height': 0.5, 'E': 0.04213}
# {'X': 101.752, 'Y': 135.136, 'z_height': 0.5, 'E': 2.37431}
# {'X': 102.536, 'Y': 134.582, 'z_height': 0.5, 'E': 0.05174}
# {'X': 144.605, 'Y': 128.271, 'z_height': 0.5, 'E': 2.29294}
# {'X': 143.897, 'Y': 127.941, 'z_height': 0.5, 'E': 0.0421}
# {'X': 104.22, 'Y': 133.892, 'z_height': 0.5, 'E': 2.16256}
# {'X': 104.925, 'Y': 133.617, 'z_height': 0.5, 'E': 0.04079}
# {'X': 105.435, 'Y': 133.273, 'z_height': 0.5, 'E': 0.03316}
# {'X': 143.189, 'Y': 127.61, 'z_height': 0.5, 'E': 2.05775}
# {'X': 142.481, 'Y': 127.279, 'z_height': 0.5, 'E': 0.04213}
# {'X': 106.268, 'Y': 132.711, 'z_height': 0.5, 'E': 1.97376}
# {'X': 106.552, 'Y': 132.549, 'z_height': 0.5, 'E': 0.01762}
# {'X': 106.843, 'Y': 132.452, 'z_height': 0.5, 'E': 0.01653}
# {'X': 110.842, 'Y': 131.629, 'z_height': 0.5, 'E': 0.22007}
# {'X': 111.143, 'Y': 131.543, 'z_height': 0.5, 'E': 0.01687}
# {'X': 113.697, 'Y': 131.16, 'z_height': 0.5, 'E': 0.1392}
# {'X': 122.163, 'Y': 130.088, 'z_height': 0.5, 'E': 0.45997}
# {'X': 127.613, 'Y': 129.072, 'z_height': 0.5, 'E': 0.29882}
# {'X': 141.772, 'Y': 126.948, 'z_height': 0.5, 'E': 0.77173}
# {'X': 141.306, 'Y': 126.745, 'z_height': 0.5, 'E': 0.0274}
# {'X': 141.055, 'Y': 126.683, 'z_height': 0.5, 'E': 0.01394}
# {'X': 140.86, 'Y': 126.661, 'z_height': 0.5, 'E': 0.01058}
# {'X': 139.426, 'Y': 126.863, 'z_height': 0.5, 'E': 0.07806}
# {'X': 140.86, 'Y': 126.661, 'z_height': 0.5, 'E': -0.33438}
# {'X': 141.055, 'Y': 126.683, 'z_height': 0.5, 'E': -0.04531}
# {'X': 141.306, 'Y': 126.745, 'z_height': 0.5, 'E': -0.0597}
# {'X': 141.772, 'Y': 126.948, 'z_height': 0.5, 'E': -0.11737}
# {'X': 140.73, 'Y': 127.104, 'z_height': 0.5, 'E': -0.24324}
# {'X': 140.172, 'Y': 82.608, 'z_height': 0.5, 'E': 0}
# {'X': 141.905, 'Y': 82.35, 'z_height': 0.5, 'E': 0.0935}
# {'X': 141.907, 'Y': 82.783, 'z_height': 0.5, 'E': 0.02311}
# {'X': 128.558, 'Y': 84.766, 'z_height': 0.5, 'E': 0.7202}
# {'X': 128.699, 'Y': 84.983, 'z_height': 0.5, 'E': 0.01381}
# {'X': 128.867, 'Y': 85.152, 'z_height': 0.5, 'E': 0.01272}
# {'X': 141.788, 'Y': 83.233, 'z_height': 0.5, 'E': 0.6971}
# {'X': 141.671, 'Y': 83.45, 'z_height': 0.5, 'E': 0.01316}
# {'X': 141.47, 'Y': 83.713, 'z_height': 0.5, 'E': 0.01766}
# {'X': 129.312, 'Y': 85.519, 'z_height': 0.5, 'E': 0.65594}
# {'X': 129.621, 'Y': 85.648, 'z_height': 0.5, 'E': 0.01787}
# {'X': 129.841, 'Y': 85.697, 'z_height': 0.5, 'E': 0.01203}
# {'X': 130.953, 'Y': 85.708, 'z_height': 0.5, 'E': 0.05935}
# {'X': 141.091, 'Y': 84.202, 'z_height': 0.5, 'E': 0.54696}
# {'X': 140.874, 'Y': 84.479, 'z_height': 0.5, 'E': 0.01878}
# {'X': 140.669, 'Y': 84.697, 'z_height': 0.5, 'E': 0.01597}
# {'X': 133.785, 'Y': 85.72, 'z_height': 0.5, 'E': 0.3714}
# {'X': 136.568, 'Y': 85.739, 'z_height': 0.5, 'E': 0.14852}
# {'X': 140.188, 'Y': 85.201, 'z_height': 0.5, 'E': 0.19531}
# {'X': 139.976, 'Y': 85.411, 'z_height': 0.5, 'E': 0.01592}
# {'X': 139.786, 'Y': 85.555, 'z_height': 0.5, 'E': 0.01272}
# {'X': 139.601, 'Y': 85.659, 'z_height': 0.5, 'E': 0.01133}
# {'X': 139.359, 'Y': 85.747, 'z_height': 0.5, 'E': 0.01374}
# {'X': 137.642, 'Y': 86.012, 'z_height': 0.5, 'E': 0.09271}
# {'X': 139.359, 'Y': 85.747, 'z_height': 0.5, 'E': -0.40115}
# {'X': 139.601, 'Y': 85.659, 'z_height': 0.5, 'E': -0.05946}
# {'X': 139.786, 'Y': 85.555, 'z_height': 0.5, 'E': -0.049}
# {'X': 139.976, 'Y': 85.411, 'z_height': 0.5, 'E': -0.05505}
# {'X': 140.188, 'Y': 85.201, 'z_height': 0.5, 'E': -0.0689}
# {'X': 139.475, 'Y': 85.307, 'z_height': 0.5, 'E': -0.16644}
# {'X': 142.301, 'Y': 81.921, 'z_height': 0.5, 'E': 0}
# {'X': 142.39, 'Y': 82.596, 'z_height': 0.5, 'E': 0.04751}
# {'X': 142.53, 'Y': 83.147, 'z_height': 0.5, 'E': 0.03089}
# {'X': 141.95, 'Y': 83.75, 'z_height': 0.5, 'E': 0.04546}
# {'X': 141.818, 'Y': 83.904, 'z_height': 0.5, 'E': 0.01021}
# {'X': 141.149, 'Y': 84.663, 'z_height': 0.5, 'E': 0.0469}
# {'X': 140.29, 'Y': 85.545, 'z_height': 0.5, 'E': 0.05221}
# {'X': 139.851, 'Y': 85.92, 'z_height': 0.5, 'E': 0.02448}
# {'X': 139.765, 'Y': 85.912, 'z_height': 0.5, 'E': 0.00366}
# {'X': 139.422, 'Y': 85.981, 'z_height': 0.5, 'E': 0.01484}
# {'X': 139.765, 'Y': 85.912, 'z_height': 0.5, 'E': -0.08079}
# {'X': 139.851, 'Y': 85.92, 'z_height': 0.5, 'E': -0.01994}
# {'X': 140.29, 'Y': 85.545, 'z_height': 0.5, 'E': -0.13331}
# {'X': 140.295, 'Y': 85.541, 'z_height': 0.5, 'E': -0.00148}
# {'X': 141.141, 'Y': 84.672, 'z_height': 0.5, 'E': -0.28004}
# {'X': 141.149, 'Y': 84.663, 'z_height': 0.5, 'E': -0.00278}
# {'X': 141.818, 'Y': 83.904, 'z_height': 0.5, 'E': -0.23362}
# {'X': 141.95, 'Y': 83.75, 'z_height': 0.5, 'E': -0.04683}
# {'X': 141.953, 'Y': 83.746, 'z_height': 0.5, 'E': -0.00121}
# {'X': 95.183, 'Y': 89.178, 'z_height': 0.5, 'E': 0}
# {'X': 98.122, 'Y': 88.743, 'z_height': 0.5, 'E': 0.16142}
# {'X': 95.325, 'Y': 91.54, 'z_height': 0.5, 'E': 0.21492}
# {'X': 95.196, 'Y': 91.13, 'z_height': 0.5, 'E': 0.02335}
# {'X': 94.916, 'Y': 90.636, 'z_height': 0.5, 'E': 0.03085}
# {'X': 94.554, 'Y': 90.259, 'z_height': 0.5, 'E': 0.0284}
# {'X': 94.12, 'Y': 90.006, 'z_height': 0.5, 'E': 0.02729}
# {'X': 93.743, 'Y': 89.875, 'z_height': 0.5, 'E': 0.02168}
# {'X': 93.484, 'Y': 89.841, 'z_height': 0.5, 'E': 0.01419}
# {'X': 93.224, 'Y': 89.807, 'z_height': 0.5, 'E': 0.01313}
# {'X': 92.965, 'Y': 89.773, 'z_height': 0.5, 'E': 0.01197}
# {'X': 92.465, 'Y': 89.802, 'z_height': 0.5, 'E': 0.02083}
# {'X': 92.131, 'Y': 89.874, 'z_height': 0.5, 'E': 0.01336}
# {'X': 92.083, 'Y': 89.549, 'z_height': 0.5, 'E': 0.01285}
# {'X': 92.438, 'Y': 89.497, 'z_height': 0.5, 'E': 0.01403}
# {'X': 93.016, 'Y': 89.44, 'z_height': 0.5, 'E': 0.02563}
# {'X': 93.388, 'Y': 89.409, 'z_height': 0.5, 'E': 0.01838}
# {'X': 93.759, 'Y': 89.378, 'z_height': 0.5, 'E': 0.02023}
# {'X': 94.967, 'Y': 89.21, 'z_height': 0.5, 'E': 0.06627}
# {'X': 93.759, 'Y': 89.378, 'z_height': 0.5, 'E': -0.28162}
# {'X': 93.388, 'Y': 89.409, 'z_height': 0.5, 'E': -0.08596}
# {'X': 93.016, 'Y': 89.44, 'z_height': 0.5, 'E': -0.08619}
# {'X': 92.438, 'Y': 89.497, 'z_height': 0.5, 'E': -0.13411}
# {'X': 92.083, 'Y': 89.549, 'z_height': 0.5, 'E': -0.08285}
# {'X': 92.131, 'Y': 89.874, 'z_height': 0.5, 'E': -0.07586}
# {'X': 92.357, 'Y': 89.825, 'z_height': 0.5, 'E': -0.05341}
# {'X': 96.728, 'Y': 89.521, 'z_height': 0.5, 'E': 0}
# {'X': 95.49, 'Y': 90.759, 'z_height': 0.5, 'E': 0.09513}
# {'X': 95.339, 'Y': 90.481, 'z_height': 0.5, 'E': 0.01719}
# {'X': 94.909, 'Y': 89.989, 'z_height': 0.5, 'E': 0.0355}
# {'X': 94.488, 'Y': 89.716, 'z_height': 0.5, 'E': 0.02726}
# {'X': 96.882, 'Y': 89.367, 'z_height': 0.5, 'E': 0.13145}
# {'X': 95.027, 'Y': 89.641, 'z_height': 0.5, 'E': -0.43297}
# {'X': 94.488, 'Y': 89.716, 'z_height': 0.5, 'E': -0.12566}
# {'X': 94.909, 'Y': 89.989, 'z_height': 0.5, 'E': -0.11586}
# {'X': 95.267, 'Y': 90.398, 'z_height': 0.5, 'E': -0.12551}
# {'X': 98.845, 'Y': 88.636, 'z_height': 0.5, 'E': 0}
# {'X': 95.467, 'Y': 92.014, 'z_height': 0.5, 'E': 0.25956}
# {'X': 95.608, 'Y': 92.49, 'z_height': 0.5, 'E': 0.02697}
# {'X': 99.568, 'Y': 88.529, 'z_height': 0.5, 'E': 0.30432}
# {'X': 100.291, 'Y': 88.422, 'z_height': 0.5, 'E': 0.03971}
# {'X': 95.748, 'Y': 92.965, 'z_height': 0.5, 'E': 0.34908}
# {'X': 95.921, 'Y': 93.409, 'z_height': 0.5, 'E': 0.02589}
# {'X': 101.014, 'Y': 88.316, 'z_height': 0.5, 'E': 0.39134}
# {'X': 101.737, 'Y': 88.209, 'z_height': 0.5, 'E': 0.03971}
# {'X': 96.161, 'Y': 93.784, 'z_height': 0.5, 'E': 0.42841}
# {'X': 96.363, 'Y': 94.199, 'z_height': 0.5, 'E': 0.02508}
# {'X': 102.46, 'Y': 88.102, 'z_height': 0.5, 'E': 0.46848}
# {'X': 103.183, 'Y': 87.995, 'z_height': 0.5, 'E': 0.03971}
# {'X': 96.475, 'Y': 94.703, 'z_height': 0.5, 'E': 0.51543}
# {'X': 96.512, 'Y': 95.281, 'z_height': 0.5, 'E': 0.03147}
# {'X': 103.906, 'Y': 87.888, 'z_height': 0.5, 'E': 0.5681}
# {'X': 104.631, 'Y': 87.778, 'z_height': 0.5, 'E': 0.03984}
# {'X': 96.464, 'Y': 95.946, 'z_height': 0.5, 'E': 0.62758}
# {'X': 96.526, 'Y': 96.499, 'z_height': 0.5, 'E': 0.03023}
# {'X': 105.36, 'Y': 87.666, 'z_height': 0.5, 'E': 0.67875}
# {'X': 106.088, 'Y': 87.554, 'z_height': 0.5, 'E': 0.04002}
# {'X': 96.612, 'Y': 97.029, 'z_height': 0.5, 'E': 0.72808}
# {'X': 96.698, 'Y': 97.56, 'z_height': 0.5, 'E': 0.02923}
# {'X': 106.816, 'Y': 87.442, 'z_height': 0.5, 'E': 0.77745}
# {'X': 107.544, 'Y': 87.33, 'z_height': 0.5, 'E': 0.04002}
# {'X': 96.784, 'Y': 98.09, 'z_height': 0.5, 'E': 0.82678}
# {'X': 96.87, 'Y': 98.62, 'z_height': 0.5, 'E': 0.02917}
# {'X': 108.272, 'Y': 87.218, 'z_height': 0.5, 'E': 0.87611}
# {'X': 109.0, 'Y': 87.106, 'z_height': 0.5, 'E': 0.04002}
# {'X': 96.956, 'Y': 99.15, 'z_height': 0.5, 'E': 0.92544}
# {'X': 97.042, 'Y': 99.68, 'z_height': 0.5, 'E': 0.02917}
# {'X': 109.728, 'Y': 86.994, 'z_height': 0.5, 'E': 0.97477}
# {'X': 110.456, 'Y': 86.882, 'z_height': 0.5, 'E': 0.04002}
# {'X': 97.128, 'Y': 100.21, 'z_height': 0.5, 'E': 1.0241}
# {'X': 97.214, 'Y': 100.74, 'z_height': 0.5, 'E': 0.02917}
# {'X': 111.185, 'Y': 86.77, 'z_height': 0.5, 'E': 1.07347}
# {'X': 111.913, 'Y': 86.657, 'z_height': 0.5, 'E': 0.04003}
# {'X': 97.3, 'Y': 101.27, 'z_height': 0.5, 'E': 1.12284}
# {'X': 97.356, 'Y': 101.83, 'z_height': 0.5, 'E': 0.03058}
# {'X': 112.641, 'Y': 86.545, 'z_height': 0.5, 'E': 1.17447}
# {'X': 113.369, 'Y': 86.433, 'z_height': 0.5, 'E': 0.04002}
# {'X': 97.186, 'Y': 102.616, 'z_height': 0.5, 'E': 1.24347}
# {'X': 97.096, 'Y': 102.765, 'z_height': 0.5, 'E': 0.00946}
# {'X': 97.006, 'Y': 102.913, 'z_height': 0.5, 'E': 0.00838}
# {'X': 96.934, 'Y': 102.894, 'z_height': 0.5, 'E': 0.00316}
# {'X': 96.953, 'Y': 102.965, 'z_height': 0.5, 'E': 0.00312}
# {'X': 96.995, 'Y': 102.954, 'z_height': 0.5, 'E': 0.00184}
# {'X': 96.953, 'Y': 102.965, 'z_height': 0.5, 'E': -0.01003}
# {'X': 96.934, 'Y': 102.894, 'z_height': 0.5, 'E': -0.01697}
# {'X': 97.006, 'Y': 102.913, 'z_height': 0.5, 'E': -0.01719}
# {'X': 97.096, 'Y': 102.765, 'z_height': 0.5, 'E': -0.04}
# {'X': 97.186, 'Y': 102.616, 'z_height': 0.5, 'E': -0.04019}
# {'X': 99.255, 'Y': 100.547, 'z_height': 0.5, 'E': -0.67562}
# {'X': 96.362, 'Y': 104.072, 'z_height': 0.5, 'E': 0}
# {'X': 96.321, 'Y': 104.083, 'z_height': 0.5, 'E': 0.0018}
# {'X': 96.302, 'Y': 104.012, 'z_height': 0.5, 'E': 0.00312}
# {'X': 96.373, 'Y': 104.031, 'z_height': 0.5, 'E': 0.00312}
# {'X': 96.474, 'Y': 103.937, 'z_height': 0.5, 'E': 0.00667}
# {'X': 114.097, 'Y': 86.321, 'z_height': 0.5, 'E': 1.35385}
# {'X': 114.825, 'Y': 86.209, 'z_height': 0.5, 'E': 0.04002}
# {'X': 96.589, 'Y': 104.446, 'z_height': 0.5, 'E': 1.40126}
# {'X': 96.634, 'Y': 105.016, 'z_height': 0.5, 'E': 0.03107}
# {'X': 115.553, 'Y': 86.097, 'z_height': 0.5, 'E': 1.4537}
# {'X': 116.282, 'Y': 85.985, 'z_height': 0.5, 'E': 0.04007}
# {'X': 96.63, 'Y': 105.636, 'z_height': 0.5, 'E': 1.50999}
# {'X': 96.557, 'Y': 105.785, 'z_height': 0.5, 'E': 0.00901}
# {'X': 96.484, 'Y': 105.933, 'z_height': 0.5, 'E': 0.00798}
# {'X': 96.413, 'Y': 105.914, 'z_height': 0.5, 'E': 0.00312}
# {'X': 96.432, 'Y': 105.985, 'z_height': 0.5, 'E': 0.00312}
# {'X': 96.473, 'Y': 105.974, 'z_height': 0.5, 'E': 0.0018}
# {'X': 96.432, 'Y': 105.985, 'z_height': 0.5, 'E': -0.0098}
# {'X': 96.413, 'Y': 105.914, 'z_height': 0.5, 'E': -0.01697}
# {'X': 96.484, 'Y': 105.933, 'z_height': 0.5, 'E': -0.01697}
# {'X': 96.557, 'Y': 105.785, 'z_height': 0.5, 'E': -0.0381}
# {'X': 96.63, 'Y': 105.636, 'z_height': 0.5, 'E': -0.03831}
# {'X': 98.712, 'Y': 103.554, 'z_height': 0.5, 'E': -0.67985}
# {'X': 95.096, 'Y': 107.27, 'z_height': 0.5, 'E': 0}
# {'X': 95.025, 'Y': 107.251, 'z_height': 0.5, 'E': 0.00312}
# {'X': 95.044, 'Y': 107.322, 'z_height': 0.5, 'E': 0.00312}
# {'X': 95.085, 'Y': 107.311, 'z_height': 0.5, 'E': 0.0018}
# {'X': 95.124, 'Y': 107.515, 'z_height': 0.5, 'E': 0.01005}
# {'X': 95.164, 'Y': 107.719, 'z_height': 0.5, 'E': 0.01129}
# {'X': 117.01, 'Y': 85.873, 'z_height': 0.5, 'E': 1.67861}
# {'X': 117.738, 'Y': 85.761, 'z_height': 0.5, 'E': 0.04002}
# {'X': 95.237, 'Y': 108.261, 'z_height': 0.5, 'E': 1.7289}
# {'X': 95.311, 'Y': 108.804, 'z_height': 0.5, 'E': 0.02978}
# {'X': 118.466, 'Y': 85.649, 'z_height': 0.5, 'E': 1.77919}
# {'X': 119.194, 'Y': 85.537, 'z_height': 0.5, 'E': 0.04002}
# {'X': 95.375, 'Y': 109.356, 'z_height': 0.5, 'E': 1.83021}
# {'X': 95.438, 'Y': 109.908, 'z_height': 0.5, 'E': 0.03019}
# {'X': 119.922, 'Y': 85.425, 'z_height': 0.5, 'E': 1.88127}
# {'X': 120.65, 'Y': 85.313, 'z_height': 0.5, 'E': 0.04002}
# {'X': 95.502, 'Y': 110.461, 'z_height': 0.5, 'E': 1.93233}
# {'X': 95.566, 'Y': 111.013, 'z_height': 0.5, 'E': 0.03019}
# {'X': 121.357, 'Y': 85.222, 'z_height': 0.5, 'E': 1.98173}
# {'X': 122.05, 'Y': 85.144, 'z_height': 0.5, 'E': 0.03789}
# {'X': 95.647, 'Y': 111.548, 'z_height': 0.5, 'E': 2.0288}
# {'X': 95.729, 'Y': 112.082, 'z_height': 0.5, 'E': 0.02935}
# {'X': 122.744, 'Y': 85.067, 'z_height': 0.5, 'E': 2.07578}
# {'X': 123.444, 'Y': 84.983, 'z_height': 0.5, 'E': 0.03831}
# {'X': 95.811, 'Y': 112.616, 'z_height': 0.5, 'E': 2.12327}
# {'X': 95.893, 'Y': 113.15, 'z_height': 0.5, 'E': 0.02935}
# {'X': 124.154, 'Y': 84.889, 'z_height': 0.5, 'E': 2.17152}
# {'X': 124.865, 'Y': 84.794, 'z_height': 0.5, 'E': 0.03897}
# {'X': 95.975, 'Y': 113.684, 'z_height': 0.5, 'E': 2.21986}
# {'X': 96.057, 'Y': 114.218, 'z_height': 0.5, 'E': 0.02935}
# {'X': 125.575, 'Y': 84.7, 'z_height': 0.5, 'E': 2.26811}
# {'X': 126.286, 'Y': 84.606, 'z_height': 0.5, 'E': 0.03897}
# {'X': 96.139, 'Y': 114.752, 'z_height': 0.5, 'E': 2.3164}
# {'X': 96.221, 'Y': 115.286, 'z_height': 0.5, 'E': 0.02935}
# {'X': 126.978, 'Y': 84.529, 'z_height': 0.5, 'E': 2.36331}
# {'X': 127.622, 'Y': 84.502, 'z_height': 0.5, 'E': 0.03502}
# {'X': 96.303, 'Y': 115.82, 'z_height': 0.5, 'E': 2.40646}
# {'X': 96.385, 'Y': 116.354, 'z_height': 0.5, 'E': 0.02935}
# {'X': 128.056, 'Y': 84.684, 'z_height': 0.5, 'E': 2.4335}
# {'X': 128.09, 'Y': 84.541, 'z_height': 0.5, 'E': 0.00799}
# {'X': 128.124, 'Y': 84.398, 'z_height': 0.5, 'E': 0.00711}
# {'X': 128.083, 'Y': 84.409, 'z_height': 0.5, 'E': 0.0018}
# {'X': 128.064, 'Y': 84.338, 'z_height': 0.5, 'E': 0.00312}
# {'X': 128.135, 'Y': 84.357, 'z_height': 0.5, 'E': 0.00312}
# {'X': 128.258, 'Y': 85.097, 'z_height': 0.5, 'E': 0.04076}
# {'X': 96.467, 'Y': 116.888, 'z_height': 0.5, 'E': 2.44276}
# {'X': 96.55, 'Y': 117.422, 'z_height': 0.5, 'E': 0.02936}
# {'X': 128.542, 'Y': 85.43, 'z_height': 0.5, 'E': 2.45821}
# {'X': 128.86, 'Y': 85.728, 'z_height': 0.5, 'E': 0.02368}
# {'X': 96.632, 'Y': 117.956, 'z_height': 0.5, 'E': 2.47634}
# {'X': 96.714, 'Y': 118.49, 'z_height': 0.5, 'E': 0.02935}
# {'X': 129.247, 'Y': 85.956, 'z_height': 0.5, 'E': 2.49982}
# {'X': 129.714, 'Y': 86.106, 'z_height': 0.5, 'E': 0.02665}
# {'X': 96.796, 'Y': 119.024, 'z_height': 0.5, 'E': 2.52936}
# {'X': 96.878, 'Y': 119.558, 'z_height': 0.5, 'E': 0.02935}
# {'X': 130.306, 'Y': 86.13, 'z_height': 0.5, 'E': 2.56855}
# {'X': 130.92, 'Y': 86.132, 'z_height': 0.5, 'E': 0.03336}
# {'X': 96.96, 'Y': 120.092, 'z_height': 0.5, 'E': 2.60942}
# {'X': 97.042, 'Y': 120.626, 'z_height': 0.5, 'E': 0.02935}
# {'X': 131.533, 'Y': 86.135, 'z_height': 0.5, 'E': 2.65023}
# {'X': 132.147, 'Y': 86.137, 'z_height': 0.5, 'E': 0.03336}
# {'X': 97.124, 'Y': 121.16, 'z_height': 0.5, 'E': 2.6911}
# {'X': 97.206, 'Y': 121.694, 'z_height': 0.5, 'E': 0.02935}
# {'X': 132.76, 'Y': 86.14, 'z_height': 0.5, 'E': 2.7319}
# {'X': 133.374, 'Y': 86.143, 'z_height': 0.5, 'E': 0.03336}
# {'X': 97.288, 'Y': 122.228, 'z_height': 0.5, 'E': 2.77274}
# {'X': 97.37, 'Y': 122.762, 'z_height': 0.5, 'E': 0.02935}
# {'X': 133.987, 'Y': 86.145, 'z_height': 0.5, 'E': 2.81358}
# {'X': 134.601, 'Y': 86.148, 'z_height': 0.5, 'E': 0.03336}
# {'X': 97.452, 'Y': 123.296, 'z_height': 0.5, 'E': 2.85442}
# {'X': 97.534, 'Y': 123.83, 'z_height': 0.5, 'E': 0.02935}
# {'X': 135.214, 'Y': 86.15, 'z_height': 0.5, 'E': 2.89526}
# {'X': 135.828, 'Y': 86.153, 'z_height': 0.5, 'E': 0.03336}
# {'X': 97.616, 'Y': 124.364, 'z_height': 0.5, 'E': 2.9361}
# {'X': 97.698, 'Y': 124.898, 'z_height': 0.5, 'E': 0.02935}
# {'X': 136.441, 'Y': 86.155, 'z_height': 0.5, 'E': 2.97694}
# {'X': 137.012, 'Y': 86.2, 'z_height': 0.5, 'E': 0.03112}
# {'X': 97.78, 'Y': 125.432, 'z_height': 0.5, 'E': 3.01452}
# {'X': 97.862, 'Y': 125.966, 'z_height': 0.5, 'E': 0.02935}
# {'X': 137.582, 'Y': 86.246, 'z_height': 0.5, 'E': 3.05201}
# {'X': 138.153, 'Y': 86.292, 'z_height': 0.5, 'E': 0.03112}
# {'X': 97.944, 'Y': 126.5, 'z_height': 0.5, 'E': 3.08955}
# {'X': 98.026, 'Y': 127.034, 'z_height': 0.5, 'E': 0.02935}
# {'X': 138.782, 'Y': 86.279, 'z_height': 0.5, 'E': 3.13158}
# {'X': 139.543, 'Y': 86.134, 'z_height': 0.5, 'E': 0.04209}
# {'X': 98.108, 'Y': 127.568, 'z_height': 0.5, 'E': 3.18375}
# {'X': 98.19, 'Y': 128.102, 'z_height': 0.5, 'E': 0.02935}
# {'X': 142.605, 'Y': 83.688, 'z_height': 0.5, 'E': 3.41273}
# {'X': 142.897, 'Y': 84.061, 'z_height': 0.5, 'E': 0.02574}
# {'X': 142.826, 'Y': 84.042, 'z_height': 0.5, 'E': 0.00312}
# {'X': 142.845, 'Y': 84.113, 'z_height': 0.5, 'E': 0.00312}
# {'X': 142.886, 'Y': 84.102, 'z_height': 0.5, 'E': 0.0018}
# {'X': 142.783, 'Y': 84.165, 'z_height': 0.5, 'E': 0.00584}
# {'X': 142.68, 'Y': 84.229, 'z_height': 0.5, 'E': 0.00659}
# {'X': 98.206, 'Y': 128.71, 'z_height': 0.5, 'E': 3.41757}
# {'X': 98.14, 'Y': 128.783, 'z_height': 0.5, 'E': 0.00491}
# {'X': 98.064, 'Y': 128.762, 'z_height': 0.5, 'E': 0.00359}
# {'X': 98.084, 'Y': 128.839, 'z_height': 0.5, 'E': 0.00362}
# {'X': 98.128, 'Y': 128.827, 'z_height': 0.5, 'E': 0.00207}
# {'X': 98.35, 'Y': 129.175, 'z_height': 0.5, 'E': 0.02243}
# {'X': 142.756, 'Y': 84.769, 'z_height': 0.5, 'E': 3.41208}
# {'X': 142.835, 'Y': 85.306, 'z_height': 0.5, 'E': 0.02949}
# {'X': 98.428, 'Y': 129.713, 'z_height': 0.5, 'E': 3.41215}
# {'X': 98.506, 'Y': 130.251, 'z_height': 0.5, 'E': 0.02954}
# {'X': 142.915, 'Y': 85.842, 'z_height': 0.5, 'E': 3.41231}
# {'X': 142.994, 'Y': 86.379, 'z_height': 0.5, 'E': 0.02949}
# {'X': 98.584, 'Y': 130.789, 'z_height': 0.5, 'E': 3.41238}
# {'X': 98.662, 'Y': 131.327, 'z_height': 0.5, 'E': 0.02954}
# {'X': 143.074, 'Y': 86.916, 'z_height': 0.5, 'E': 3.4125}
# {'X': 143.153, 'Y': 87.452, 'z_height': 0.5, 'E': 0.02944}
# {'X': 98.741, 'Y': 131.865, 'z_height': 0.5, 'E': 3.41258}
# {'X': 98.819, 'Y': 132.403, 'z_height': 0.5, 'E': 0.02954}
# {'X': 143.232, 'Y': 87.989, 'z_height': 0.5, 'E': 3.41265}
# {'X': 143.312, 'Y': 88.526, 'z_height': 0.5, 'E': 0.0295}
# {'X': 98.897, 'Y': 132.94, 'z_height': 0.5, 'E': 3.41273}
# {'X': 98.975, 'Y': 133.478, 'z_height': 0.5, 'E': 0.02954}
# {'X': 143.391, 'Y': 89.062, 'z_height': 0.5, 'E': 3.41284}
# {'X': 143.471, 'Y': 89.599, 'z_height': 0.5, 'E': 0.0295}
# {'X': 99.053, 'Y': 134.016, 'z_height': 0.5, 'E': 3.41296}
# {'X': 99.131, 'Y': 134.554, 'z_height': 0.5, 'E': 0.02954}
# {'X': 143.55, 'Y': 90.136, 'z_height': 0.5, 'E': 3.41304}
# {'X': 143.629, 'Y': 90.672, 'z_height': 0.5, 'E': 0.02944}
# {'X': 99.21, 'Y': 135.092, 'z_height': 0.5, 'E': 3.41311}
# {'X': 99.288, 'Y': 135.63, 'z_height': 0.5, 'E': 0.02954}
# {'X': 143.709, 'Y': 91.209, 'z_height': 0.5, 'E': 3.41323}
# {'X': 143.788, 'Y': 91.745, 'z_height': 0.5, 'E': 0.02944}
# {'X': 99.366, 'Y': 136.168, 'z_height': 0.5, 'E': 3.41334}
# {'X': 99.444, 'Y': 136.705, 'z_height': 0.5, 'E': 0.02948}
# {'X': 143.868, 'Y': 92.282, 'z_height': 0.5, 'E': 3.41342}
# {'X': 143.947, 'Y': 92.819, 'z_height': 0.5, 'E': 0.02949}
# {'X': 102.759, 'Y': 134.007, 'z_height': 0.5, 'E': 3.16481}
# {'X': 102.605, 'Y': 134.116, 'z_height': 0.5, 'E': 0.01025}
# {'X': 102.451, 'Y': 134.225, 'z_height': 0.5, 'E': 0.00913}
# {'X': 101.588, 'Y': 134.942, 'z_height': 0.5, 'E': 0.04758}
# {'X': 102.275, 'Y': 134.358, 'z_height': 0.5, 'E': -0.2082}
# {'X': 102.451, 'Y': 134.225, 'z_height': 0.5, 'E': -0.05094}
# {'X': 102.605, 'Y': 134.116, 'z_height': 0.5, 'E': -0.04356}
# {'X': 102.759, 'Y': 134.007, 'z_height': 0.5, 'E': -0.04356}
# {'X': 104.149, 'Y': 132.617, 'z_height': 0.5, 'E': -0.45374}
# {'X': 100.819, 'Y': 135.846, 'z_height': 0.5, 'E': 0}
# {'X': 100.748, 'Y': 135.827, 'z_height': 0.5, 'E': 0.00312}
# {'X': 100.767, 'Y': 135.898, 'z_height': 0.5, 'E': 0.00312}
# {'X': 100.808, 'Y': 135.887, 'z_height': 0.5, 'E': 0.0018}
# {'X': 100.704, 'Y': 136.026, 'z_height': 0.5, 'E': 0.0084}
# {'X': 100.601, 'Y': 136.165, 'z_height': 0.5, 'E': 0.0094}
# {'X': 99.779, 'Y': 136.986, 'z_height': 0.5, 'E': 0.06312}
# {'X': 100.553, 'Y': 137.04, 'z_height': 0.5, 'E': 0.04216}
# {'X': 100.539, 'Y': 137.514, 'z_height': 0.5, 'E': 0.02576}
# {'X': 100.453, 'Y': 137.88, 'z_height': 0.5, 'E': 0.02043}
# {'X': 100.209, 'Y': 138.344, 'z_height': 0.5, 'E': 0.02848}
# {'X': 100.098, 'Y': 138.738, 'z_height': 0.5, 'E': 0.02224}
# {'X': 100.099, 'Y': 138.926, 'z_height': 0.5, 'E': 0.01021}
# {'X': 100.1, 'Y': 139.115, 'z_height': 0.5, 'E': 0.00943}
# {'X': 100.101, 'Y': 139.303, 'z_height': 0.5, 'E': 0.00855}
# {'X': 100.184, 'Y': 139.797, 'z_height': 0.5, 'E': 0.02085}
# {'X': 99.851, 'Y': 139.855, 'z_height': 0.5, 'E': 0.01407}
# {'X': 99.766, 'Y': 139.271, 'z_height': 0.5, 'E': 0.0246}
# {'X': 99.758, 'Y': 139.096, 'z_height': 0.5, 'E': 0.00804}
# {'X': 99.749, 'Y': 138.921, 'z_height': 0.5, 'E': 0.00878}
# {'X': 99.741, 'Y': 138.747, 'z_height': 0.5, 'E': 0.00946}
# {'X': 99.54, 'Y': 137.363, 'z_height': 0.5, 'E': 0.07599}
# {'X': 99.625, 'Y': 137.448, 'z_height': 0.5, 'E': 0.00653}
# {'X': 99.863, 'Y': 137.496, 'z_height': 0.5, 'E': 0.01319}
# {'X': 99.933, 'Y': 137.448, 'z_height': 0.5, 'E': 0.00461}
# {'X': 100.559, 'Y': 136.823, 'z_height': 0.5, 'E': 0.04806}
# {'X': 99.933, 'Y': 137.448, 'z_height': 0.5, 'E': -0.20425}
# {'X': 99.863, 'Y': 137.496, 'z_height': 0.5, 'E': -0.0196}
# {'X': 99.625, 'Y': 137.448, 'z_height': 0.5, 'E': -0.05606}
# {'X': 99.54, 'Y': 137.363, 'z_height': 0.5, 'E': -0.02776}
# {'X': 99.741, 'Y': 138.747, 'z_height': 0.5, 'E': -0.32292}
# {'X': 99.749, 'Y': 138.921, 'z_height': 0.5, 'E': -0.04022}
# {'X': 99.758, 'Y': 139.096, 'z_height': 0.5, 'E': -0.04046}
# {'X': 99.766, 'Y': 139.271, 'z_height': 0.5, 'E': -0.04045}
# {'X': 99.796, 'Y': 139.478, 'z_height': 0.5, 'E': -0.04828}
# {'X': 103.495, 'Y': 133.844, 'z_height': 0.5, 'E': 0}
# {'X': 103.454, 'Y': 133.855, 'z_height': 0.5, 'E': 0.0018}
# {'X': 103.435, 'Y': 133.784, 'z_height': 0.5, 'E': 0.00312}
# {'X': 103.506, 'Y': 133.803, 'z_height': 0.5, 'E': 0.00312}
# {'X': 103.638, 'Y': 133.707, 'z_height': 0.5, 'E': 0.00789}
# {'X': 103.77, 'Y': 133.612, 'z_height': 0.5, 'E': 0.00884}
# {'X': 144.026, 'Y': 93.355, 'z_height': 0.5, 'E': 3.09324}
# {'X': 144.106, 'Y': 93.892, 'z_height': 0.5, 'E': 0.0295}
# {'X': 104.828, 'Y': 133.17, 'z_height': 0.5, 'E': 3.01805}
# {'X': 104.696, 'Y': 133.273, 'z_height': 0.5, 'E': 0.0091}
# {'X': 104.564, 'Y': 133.377, 'z_height': 0.5, 'E': 0.00813}
# {'X': 104.493, 'Y': 133.358, 'z_height': 0.5, 'E': 0.00312}
# {'X': 104.512, 'Y': 133.429, 'z_height': 0.5, 'E': 0.00312}
# {'X': 104.553, 'Y': 133.418, 'z_height': 0.5, 'E': 0.0018}
# {'X': 104.512, 'Y': 133.429, 'z_height': 0.5, 'E': -0.0098}
# {'X': 104.493, 'Y': 133.358, 'z_height': 0.5, 'E': -0.01697}
# {'X': 104.564, 'Y': 133.377, 'z_height': 0.5, 'E': -0.01697}
# {'X': 104.696, 'Y': 133.273, 'z_height': 0.5, 'E': -0.0388}
# {'X': 104.828, 'Y': 133.17, 'z_height': 0.5, 'E': -0.03866}
# {'X': 106.907, 'Y': 131.091, 'z_height': 0.5, 'E': -0.6788}
# {'X': 106.652, 'Y': 132.246, 'z_height': 0.5, 'E': 0}
# {'X': 106.366, 'Y': 132.34, 'z_height': 0.5, 'E': 0.01277}
# {'X': 106.195, 'Y': 132.329, 'z_height': 0.5, 'E': 0.00727}
# {'X': 106.349, 'Y': 132.22, 'z_height': 0.5, 'E': 0.00913}
# {'X': 106.503, 'Y': 132.111, 'z_height': 0.5, 'E': 0.01025}
# {'X': 144.187, 'Y': 94.427, 'z_height': 0.5, 'E': 2.89557}
# {'X': 144.269, 'Y': 94.961, 'z_height': 0.5, 'E': 0.02935}
# {'X': 107.308, 'Y': 131.922, 'z_height': 0.5, 'E': 2.84002}
# {'X': 108.083, 'Y': 131.763, 'z_height': 0.5, 'E': 0.04298}
# {'X': 144.351, 'Y': 95.495, 'z_height': 0.5, 'E': 2.78677}
# {'X': 144.434, 'Y': 96.029, 'z_height': 0.5, 'E': 0.02936}
# {'X': 108.859, 'Y': 131.603, 'z_height': 0.5, 'E': 2.73348}
# {'X': 109.634, 'Y': 131.444, 'z_height': 0.5, 'E': 0.04298}
# {'X': 144.516, 'Y': 96.562, 'z_height': 0.5, 'E': 2.68027}
# {'X': 144.598, 'Y': 97.096, 'z_height': 0.5, 'E': 0.02935}
# {'X': 110.409, 'Y': 131.285, 'z_height': 0.5, 'E': 2.62702}
# {'X': 111.237, 'Y': 131.074, 'z_height': 0.5, 'E': 0.04643}
# {'X': 144.68, 'Y': 97.63, 'z_height': 0.5, 'E': 2.56974}
# {'X': 144.762, 'Y': 98.164, 'z_height': 0.5, 'E': 0.02935}
# {'X': 111.983, 'Y': 130.944, 'z_height': 0.5, 'E': 2.51872}
# {'X': 112.686, 'Y': 130.857, 'z_height': 0.5, 'E': 0.03849}
# {'X': 144.844, 'Y': 98.698, 'z_height': 0.5, 'E': 2.471}
# {'X': 144.926, 'Y': 99.232, 'z_height': 0.5, 'E': 0.02935}
# {'X': 113.389, 'Y': 130.77, 'z_height': 0.5, 'E': 2.42328}
# {'X': 114.092, 'Y': 130.683, 'z_height': 0.5, 'E': 0.03849}
# {'X': 145.008, 'Y': 99.766, 'z_height': 0.5, 'E': 2.37557}
# {'X': 145.091, 'Y': 100.3, 'z_height': 0.5, 'E': 0.02936}
# {'X': 114.795, 'Y': 130.596, 'z_height': 0.5, 'E': 2.32789}
# {'X': 115.498, 'Y': 130.509, 'z_height': 0.5, 'E': 0.03849}
# {'X': 145.173, 'Y': 100.834, 'z_height': 0.5, 'E': 2.28017}
# {'X': 145.255, 'Y': 101.368, 'z_height': 0.5, 'E': 0.02935}
# {'X': 116.201, 'Y': 130.422, 'z_height': 0.5, 'E': 2.23246}
# {'X': 116.928, 'Y': 130.311, 'z_height': 0.5, 'E': 0.03996}
# {'X': 145.337, 'Y': 101.902, 'z_height': 0.5, 'E': 2.1829}
# {'X': 145.419, 'Y': 102.436, 'z_height': 0.5, 'E': 0.02935}
# {'X': 117.631, 'Y': 130.224, 'z_height': 0.5, 'E': 2.13518}
# {'X': 118.333, 'Y': 130.138, 'z_height': 0.5, 'E': 0.03843}
# {'X': 145.501, 'Y': 102.97, 'z_height': 0.5, 'E': 2.08754}
# {'X': 145.583, 'Y': 103.504, 'z_height': 0.5, 'E': 0.02935}
# {'X': 119.035, 'Y': 130.051, 'z_height': 0.5, 'E': 2.03986}
# {'X': 119.738, 'Y': 129.965, 'z_height': 0.5, 'E': 0.03848}
# {'X': 145.665, 'Y': 104.038, 'z_height': 0.5, 'E': 1.99218}
# {'X': 145.747, 'Y': 104.572, 'z_height': 0.5, 'E': 0.02935}
# {'X': 120.44, 'Y': 129.879, 'z_height': 0.5, 'E': 1.94454}
# {'X': 121.143, 'Y': 129.792, 'z_height': 0.5, 'E': 0.03849}
# {'X': 145.83, 'Y': 105.106, 'z_height': 0.5, 'E': 1.89687}
# {'X': 145.912, 'Y': 105.64, 'z_height': 0.5, 'E': 0.02935}
# {'X': 121.848, 'Y': 129.703, 'z_height': 0.5, 'E': 1.849}
# {'X': 122.591, 'Y': 129.576, 'z_height': 0.5, 'E': 0.04095}
# {'X': 145.994, 'Y': 106.173, 'z_height': 0.5, 'E': 1.79824}
# {'X': 146.076, 'Y': 106.707, 'z_height': 0.5, 'E': 0.02935}
# {'X': 123.348, 'Y': 129.435, 'z_height': 0.5, 'E': 1.74638}
# {'X': 124.106, 'Y': 129.294, 'z_height': 0.5, 'E': 0.04189}
# {'X': 146.158, 'Y': 107.241, 'z_height': 0.5, 'E': 1.69447}
# {'X': 146.24, 'Y': 107.775, 'z_height': 0.5, 'E': 0.02935}
# {'X': 124.863, 'Y': 129.153, 'z_height': 0.5, 'E': 1.64261}
# {'X': 125.62, 'Y': 129.011, 'z_height': 0.5, 'E': 0.04185}
# {'X': 146.322, 'Y': 108.309, 'z_height': 0.5, 'E': 1.5907}
# {'X': 146.404, 'Y': 108.843, 'z_height': 0.5, 'E': 0.02935}
# {'X': 126.377, 'Y': 128.87, 'z_height': 0.5, 'E': 1.53884}
# {'X': 127.127, 'Y': 128.737, 'z_height': 0.5, 'E': 0.04139}
# {'X': 146.486, 'Y': 109.377, 'z_height': 0.5, 'E': 1.48755}
# {'X': 146.569, 'Y': 109.911, 'z_height': 0.5, 'E': 0.02936}
# {'X': 127.901, 'Y': 128.579, 'z_height': 0.5, 'E': 1.43442}
# {'X': 128.677, 'Y': 128.418, 'z_height': 0.5, 'E': 0.04306}
# {'X': 146.651, 'Y': 110.445, 'z_height': 0.5, 'E': 1.38105}
# {'X': 146.733, 'Y': 110.979, 'z_height': 0.5, 'E': 0.02935}
# {'X': 129.454, 'Y': 128.258, 'z_height': 0.5, 'E': 1.32769}
# {'X': 130.231, 'Y': 128.097, 'z_height': 0.5, 'E': 0.04311}
# {'X': 146.815, 'Y': 111.513, 'z_height': 0.5, 'E': 1.27428}
# {'X': 146.897, 'Y': 112.047, 'z_height': 0.5, 'E': 0.02935}
# {'X': 131.008, 'Y': 127.936, 'z_height': 0.5, 'E': 1.22088}
# {'X': 131.77, 'Y': 127.79, 'z_height': 0.5, 'E': 0.04215}
# {'X': 146.979, 'Y': 112.581, 'z_height': 0.5, 'E': 1.16863}
# {'X': 147.061, 'Y': 113.115, 'z_height': 0.5, 'E': 0.02935}
# {'X': 132.472, 'Y': 127.704, 'z_height': 0.5, 'E': 1.12099}
# {'X': 133.211, 'Y': 127.581, 'z_height': 0.5, 'E': 0.0407}
# {'X': 147.143, 'Y': 113.649, 'z_height': 0.5, 'E': 1.07051}
# {'X': 147.225, 'Y': 114.183, 'z_height': 0.5, 'E': 0.02935}
# {'X': 133.95, 'Y': 127.458, 'z_height': 0.5, 'E': 1.02003}
# {'X': 134.689, 'Y': 127.336, 'z_height': 0.5, 'E': 0.0407}
# {'X': 147.308, 'Y': 114.717, 'z_height': 0.5, 'E': 0.96962}
# {'X': 147.39, 'Y': 115.251, 'z_height': 0.5, 'E': 0.02935}
# {'X': 135.427, 'Y': 127.213, 'z_height': 0.5, 'E': 0.91918}
# {'X': 136.166, 'Y': 127.09, 'z_height': 0.5, 'E': 0.0407}
# {'X': 147.472, 'Y': 115.784, 'z_height': 0.5, 'E': 0.86873}
# {'X': 147.554, 'Y': 116.318, 'z_height': 0.5, 'E': 0.02935}
# {'X': 136.823, 'Y': 127.05, 'z_height': 0.5, 'E': 0.82459}
# {'X': 137.425, 'Y': 127.063, 'z_height': 0.5, 'E': 0.03272}
# {'X': 147.636, 'Y': 116.852, 'z_height': 0.5, 'E': 0.78459}
# {'X': 147.718, 'Y': 117.386, 'z_height': 0.5, 'E': 0.02935}
# {'X': 138.028, 'Y': 127.076, 'z_height': 0.5, 'E': 0.74456}
# {'X': 138.65, 'Y': 127.019, 'z_height': 0.5, 'E': 0.03394}
# {'X': 138.609, 'Y': 127.03, 'z_height': 0.5, 'E': 0.0018}
# {'X': 138.59, 'Y': 126.959, 'z_height': 0.5, 'E': 0.00312}
# {'X': 138.661, 'Y': 126.978, 'z_height': 0.5, 'E': 0.00312}
# {'X': 138.795, 'Y': 126.885, 'z_height': 0.5, 'E': 0.00789}
# {'X': 138.928, 'Y': 126.792, 'z_height': 0.5, 'E': 0.00882}
# {'X': 147.8, 'Y': 117.92, 'z_height': 0.5, 'E': 0.68171}
# {'X': 147.882, 'Y': 118.454, 'z_height': 0.5, 'E': 0.02935}
# {'X': 139.903, 'Y': 126.434, 'z_height': 0.5, 'E': 0.61313}
# {'X': 139.75, 'Y': 126.533, 'z_height': 0.5, 'E': 0.0099}
# {'X': 139.597, 'Y': 126.631, 'z_height': 0.5, 'E': 0.00879}
# {'X': 139.763, 'Y': 126.65, 'z_height': 0.5, 'E': 0.00709}
# {'X': 139.976, 'Y': 126.585, 'z_height': 0.5, 'E': 0.00944}
# {'X': 140.713, 'Y': 126.24, 'z_height': 0.5, 'E': 0.04421}
# {'X': 147.965, 'Y': 118.988, 'z_height': 0.5, 'E': 0.55723}
# {'X': 148.047, 'Y': 119.522, 'z_height': 0.5, 'E': 0.02935}
# {'X': 141.272, 'Y': 126.297, 'z_height': 0.5, 'E': 0.52058}
# {'X': 141.727, 'Y': 126.458, 'z_height': 0.5, 'E': 0.02622}
# {'X': 148.129, 'Y': 120.056, 'z_height': 0.5, 'E': 0.49192}
# {'X': 148.211, 'Y': 120.59, 'z_height': 0.5, 'E': 0.02935}
# {'X': 142.146, 'Y': 126.654, 'z_height': 0.5, 'E': 0.46599}
# {'X': 142.566, 'Y': 126.85, 'z_height': 0.5, 'E': 0.02518}
# {'X': 148.293, 'Y': 121.124, 'z_height': 0.5, 'E': 0.44001}
# {'X': 148.375, 'Y': 121.658, 'z_height': 0.5, 'E': 0.02935}
# {'X': 142.986, 'Y': 127.047, 'z_height': 0.5, 'E': 0.41408}
# {'X': 143.406, 'Y': 127.243, 'z_height': 0.5, 'E': 0.02518}
# {'X': 148.457, 'Y': 122.192, 'z_height': 0.5, 'E': 0.38811}
# {'X': 148.539, 'Y': 122.726, 'z_height': 0.5, 'E': 0.02935}
# {'X': 143.826, 'Y': 127.439, 'z_height': 0.5, 'E': 0.36214}
# {'X': 144.246, 'Y': 127.635, 'z_height': 0.5, 'E': 0.02518}
# {'X': 148.621, 'Y': 123.26, 'z_height': 0.5, 'E': 0.33617}
# {'X': 148.704, 'Y': 123.794, 'z_height': 0.5, 'E': 0.02936}
# {'X': 144.666, 'Y': 127.831, 'z_height': 0.5, 'E': 0.31023}
# {'X': 145.086, 'Y': 128.027, 'z_height': 0.5, 'E': 0.02518}
# {'X': 148.786, 'Y': 124.328, 'z_height': 0.5, 'E': 0.28426}
# {'X': 148.868, 'Y': 124.861, 'z_height': 0.5, 'E': 0.0293}
# {'X': 145.506, 'Y': 128.223, 'z_height': 0.5, 'E': 0.25833}
# {'X': 145.926, 'Y': 128.419, 'z_height': 0.5, 'E': 0.02518}
# {'X': 148.953, 'Y': 125.392, 'z_height': 0.5, 'E': 0.23259}
# {'X': 149.039, 'Y': 125.923, 'z_height': 0.5, 'E': 0.02923}
# {'X': 146.346, 'Y': 128.615, 'z_height': 0.5, 'E': 0.20689}
# {'X': 147.021, 'Y': 128.931, 'z_height': 0.5, 'E': 0.04049}
# {'X': 148.175, 'Y': 128.955, 'z_height': 0.5, 'E': 0.06271}
# {'X': 148.695, 'Y': 129.048, 'z_height': 0.5, 'E': 0.0287}
# {'X': 149.184, 'Y': 129.277, 'z_height': 0.5, 'E': 0.02934}
# {'X': 149.637, 'Y': 129.59, 'z_height': 0.5, 'E': 0.02992}
# {'X': 149.073, 'Y': 126.138, 'z_height': 0.5, 'E': 0.19004}
# {'X': 148.743, 'Y': 126.834, 'z_height': 0.5, 'E': 0.04185}
# {'X': 147.094, 'Y': 128.484, 'z_height': 0.5, 'E': 0.12674}
# {'X': 148.184, 'Y': 128.519, 'z_height': 0.5, 'E': 0.05925}
# {'X': 148.714, 'Y': 128.602, 'z_height': 0.5, 'E': 0.02915}
# {'X': 149.049, 'Y': 128.731, 'z_height': 0.5, 'E': 0.0195}
# {'X': 148.778, 'Y': 127.049, 'z_height': 0.5, 'E': 0.09257}
# {'X': 148.483, 'Y': 127.638, 'z_height': 0.5, 'E': 0.03579}
# {'X': 147.99, 'Y': 128.131, 'z_height': 0.5, 'E': 0.02892}
# {'X': 148.571, 'Y': 128.188, 'z_height': 0.5, 'E': 0.02422}
# {'X': 148.518, 'Y': 127.853, 'z_height': 0.5, 'E': 0.01407}
# {'X': 148.571, 'Y': 128.188, 'z_height': 0.5, 'E': -0.07831}
# {'X': 147.99, 'Y': 128.131, 'z_height': 0.5, 'E': -0.1348}
# {'X': 148.483, 'Y': 127.638, 'z_height': 0.5, 'E': -0.16099}
# {'X': 148.778, 'Y': 127.049, 'z_height': 0.5, 'E': -0.15211}
# {'X': 148.914, 'Y': 127.9, 'z_height': 0.5, 'E': -0.19899}
# {'X': 148.966, 'Y': 128.22, 'z_height': 0.5, 'E': -0.0748}
# {'X': 95.615, 'Y': 90.069, 'z_height': 0.5, 'E': 0}
# {'X': 95.557, 'Y': 90.085, 'z_height': 0.5, 'E': 0.00364}
# {'X': 95.514, 'Y': 90.042, 'z_height': 0.5, 'E': 0.00368}
# {'X': 95.529, 'Y': 89.983, 'z_height': 0.5, 'E': 0.00368}
# {'X': 95.588, 'Y': 89.968, 'z_height': 0.5, 'E': 0.00368}
# {'X': 95.631, 'Y': 90.01, 'z_height': 0.5, 'E': 0.00363}
# (745, 3)
# (726, 2)
# (726,)

# %%
# find edges that are related to fill

edges_fill=[]
for i in range(len(props)):
    if(props[i]=='fill'):
        edges_fill.append(edges[i])
print(edges_fill)


# find vertices relayed to fill
flat_list = [item for sublist in edges_fill for item in sublist]
flat_list = list(set(flat_list))

verts_fill = []
for i in range(len(flat_list)):
    verts_fill.append(verts[flat_list[i]])

print(verts_fill)
# Out:
# [[189, 190], [190, 191], [191, 192], [192, 193], [193, 194], [194, 195], [195, 196], [196, 197], [197, 198], [198, 199], [199, 200], [200, 201], [201, 202], [202, 203], [203, 204], [204, 205], [205, 206], [206, 207], [207, 208], [208, 209], [209, 210], [210, 211], [211, 212], [212, 213], [213, 214], [214, 215], [215, 216], [216, 217], [217, 218], [218, 219], [219, 220], [220, 221], [221, 222], [222, 223], [223, 224], [224, 225], [225, 226], [226, 227], [227, 228], [228, 229], [229, 230], [231, 232], [232, 233], [233, 234], [234, 235], [235, 236], [236, 237], [237, 238], [238, 239], [240, 241], [241, 242], [242, 243], [244, 245], [245, 246], [246, 247], [247, 248], [248, 249], [249, 250], [250, 251], [251, 252], [252, 253], [253, 254], [254, 255], [255, 256], [256, 257], [257, 258], [258, 259], [259, 260], [260, 261], [261, 262], [262, 263], [263, 264], [264, 265], [265, 266], [266, 267], [267, 268], [268, 269], [269, 270], [270, 271], [271, 272], [272, 273], [273, 274], [274, 275], [275, 276], [276, 277], [277, 278], [278, 279], [279, 280], [280, 281], [281, 282], [282, 283], [283, 284], [284, 285], [285, 286], [286, 287], [287, 288], [288, 289], [289, 290], [290, 291], [292, 293], [293, 294], [294, 295], [295, 296], [296, 297], [297, 298], [298, 299], [299, 300], [300, 301], [301, 302], [302, 303], [303, 304], [304, 305], [305, 306], [306, 307], [307, 308], [308, 309], [309, 310], [310, 311], [311, 312], [312, 313], [313, 314], [314, 315], [316, 317], [317, 318], [318, 319], [319, 320], [320, 321], [321, 322], [322, 323], [323, 324], [324, 325], [326, 327], [327, 328], [328, 329], [329, 330], [330, 331], [331, 332], [332, 333], [333, 334], [334, 335], [335, 336], [336, 337], [337, 338], [338, 339], [339, 340], [340, 341], [341, 342], [342, 343], [343, 344], [345, 346], [346, 347], [347, 348], [348, 349], [349, 350], [351, 352], [352, 353], [353, 354], [354, 355], [355, 356], [356, 357], [357, 358], [358, 359], [359, 360], [360, 361], [361, 362], [362, 363], [363, 364], [364, 365], [365, 366], [366, 367], [367, 368], [368, 369], [369, 370], [370, 371], [371, 372], [372, 373], [373, 374], [374, 375], [375, 376], [376, 377], [377, 378], [378, 379], [379, 380], [380, 381], [381, 382], [382, 383], [383, 384], [384, 385], [385, 386], [386, 387], [387, 388], [388, 389], [389, 390], [390, 391], [391, 392], [392, 393], [393, 394], [394, 395], [395, 396], [396, 397], [398, 399], [399, 400], [400, 401], [401, 402], [402, 403], [403, 404], [404, 405], [405, 406], [406, 407], [407, 408], [408, 409], [409, 410], [410, 411], [411, 412], [412, 413], [413, 414], [415, 416], [416, 417], [417, 418], [418, 419], [419, 420], [420, 421], [421, 422], [422, 423], [423, 424], [424, 425], [425, 426], [426, 427], [427, 428], [428, 429], [429, 430], [430, 431], [431, 432], [432, 433], [433, 434], [434, 435], [435, 436], [436, 437], [437, 438], [438, 439], [439, 440], [440, 441], [441, 442], [442, 443], [443, 444], [444, 445], [445, 446], [446, 447], [447, 448], [448, 449], [449, 450], [450, 451], [451, 452], [452, 453], [453, 454], [454, 455], [455, 456], [456, 457], [457, 458], [458, 459], [459, 460], [460, 461], [461, 462], [462, 463], [463, 464], [464, 465], [465, 466], [466, 467], [467, 468], [468, 469], [469, 470], [470, 471], [471, 472], [472, 473], [473, 474], [474, 475], [475, 476], [476, 477], [477, 478], [478, 479], [479, 480], [480, 481], [481, 482], [482, 483], [483, 484], [484, 485], [485, 486], [486, 487], [487, 488], [488, 489], [489, 490], [490, 491], [491, 492], [492, 493], [493, 494], [494, 495], [495, 496], [496, 497], [497, 498], [498, 499], [499, 500], [500, 501], [501, 502], [502, 503], [503, 504], [504, 505], [505, 506], [506, 507], [507, 508], [508, 509], [509, 510], [510, 511], [511, 512], [512, 513], [513, 514], [514, 515], [515, 516], [516, 517], [517, 518], [518, 519], [519, 520], [520, 521], [521, 522], [522, 523], [523, 524], [524, 525], [525, 526], [526, 527], [527, 528], [528, 529], [529, 530], [530, 531], [531, 532], [53 ...
# [[92.635, 89.959, 0.5], [92.691, 91.19, 0.5], [93.02, 91.918, 0.5], [93.168, 92.485, 0.5], [93.062, 90.166, 0.5], [93.484, 90.255, 0.5], [93.663, 94.197, 0.5], [93.737, 94.316, 0.5], [93.812, 94.499, 0.5], [93.849, 94.662, 0.5], [94.215, 97.148, 0.5], [93.907, 90.375, 0.5], [94.153, 90.5, 0.5], [94.336, 90.626, 0.5], [95.076, 106.909, 0.5], [95.32, 106.803, 0.5], [95.484, 106.694, 0.5], [94.782, 91.238, 0.5], [95.273, 92.856, 0.5], [95.883, 106.293, 0.5], [96.025, 106.092, 0.5], [96.162, 105.773, 0.5], [96.213, 105.558, 0.5], [96.224, 105.252, 0.5], [96.156, 104.434, 0.5], [96.11, 104.267, 0.5], [96.007, 104.029, 0.5], [96.182, 103.679, 0.5], [95.739, 93.912, 0.5], [95.866, 94.122, 0.5], [95.968, 94.358, 0.5], [96.029, 94.596, 0.5], [96.087, 95.012, 0.5], [96.09, 95.234, 0.5], [96.028, 96.081, 0.5], [96.343, 98.023, 0.5], [96.565, 102.914, 0.5], [96.819, 102.392, 0.5], [96.886, 102.182, 0.5], [96.923, 101.984, 0.5], [96.931, 101.769, 0.5], [96.85, 99.986, 0.5], [100.285, 139.289, 0.5], [101.708, 139.076, 0.5], [101.818, 139.017, 0.5], [103.383, 138.477, 0.5], [103.498, 138.37, 0.5], [100.516, 138.818, 0.5], [100.573, 138.574, 0.5], [100.672, 138.357, 0.5], [107.293, 137.364, 0.5], [148.22, 131.662, 0.5], [149.939, 131.404, 0.5], [149.869, 130.978, 0.5], [145.115, 131.691, 0.5], [149.995, 130.522, 0.5], [142.716, 131.614, 0.5], [136.598, 132.184, 0.5], [134.355, 132.533, 0.5], [130.7, 133.051, 0.5], [124.837, 134.007, 0.5], [122.484, 134.336, 0.5], [116.697, 135.204, 0.5], [113.177, 135.779, 0.5], [108.949, 136.679, 0.5], [100.889, 137.888, 0.5], [100.962, 137.604, 0.5], [100.966, 137.439, 0.5], [149.676, 130.133, 0.5], [149.16, 129.773, 0.5], [100.979, 137.0, 0.5], [100.992, 136.561, 0.5], [148.506, 129.434, 0.5], [148.166, 129.38, 0.5], [146.923, 129.353, 0.5], [146.73, 129.264, 0.5], [101.048, 136.116, 0.5], [101.138, 135.84, 0.5], [101.24, 135.65, 0.5], [146.022, 128.933, 0.5], [145.314, 128.602, 0.5], [101.752, 135.136, 0.5], [102.536, 134.582, 0.5], [144.605, 128.271, 0.5], [143.897, 127.941, 0.5], [104.22, 133.892, 0.5], [104.925, 133.617, 0.5], [105.435, 133.273, 0.5], [143.189, 127.61, 0.5], [142.481, 127.279, 0.5], [106.268, 132.711, 0.5], [106.552, 132.549, 0.5], [106.843, 132.452, 0.5], [110.842, 131.629, 0.5], [111.143, 131.543, 0.5], [113.697, 131.16, 0.5], [122.163, 130.088, 0.5], [127.613, 129.072, 0.5], [141.772, 126.948, 0.5], [141.306, 126.745, 0.5], [141.055, 126.683, 0.5], [140.86, 126.661, 0.5], [139.426, 126.863, 0.5], [140.172, 82.608, 0.5], [141.905, 82.35, 0.5], [141.907, 82.783, 0.5], [128.558, 84.766, 0.5], [128.699, 84.983, 0.5], [128.867, 85.152, 0.5], [141.788, 83.233, 0.5], [141.671, 83.45, 0.5], [141.47, 83.713, 0.5], [129.312, 85.519, 0.5], [129.621, 85.648, 0.5], [129.841, 85.697, 0.5], [130.953, 85.708, 0.5], [141.091, 84.202, 0.5], [140.874, 84.479, 0.5], [140.669, 84.697, 0.5], [133.785, 85.72, 0.5], [136.568, 85.739, 0.5], [140.188, 85.201, 0.5], [139.976, 85.411, 0.5], [139.786, 85.555, 0.5], [139.601, 85.659, 0.5], [139.359, 85.747, 0.5], [137.642, 86.012, 0.5], [142.301, 81.921, 0.5], [142.39, 82.596, 0.5], [142.53, 83.147, 0.5], [141.95, 83.75, 0.5], [141.818, 83.904, 0.5], [141.149, 84.663, 0.5], [140.29, 85.545, 0.5], [139.851, 85.92, 0.5], [139.765, 85.912, 0.5], [139.422, 85.981, 0.5], [95.183, 89.178, 0.5], [98.122, 88.743, 0.5], [95.325, 91.54, 0.5], [95.196, 91.13, 0.5], [94.916, 90.636, 0.5], [94.554, 90.259, 0.5], [94.12, 90.006, 0.5], [93.743, 89.875, 0.5], [93.484, 89.841, 0.5], [93.224, 89.807, 0.5], [92.965, 89.773, 0.5], [92.465, 89.802, 0.5], [92.131, 89.874, 0.5], [92.083, 89.549, 0.5], [92.438, 89.497, 0.5], [93.016, 89.44, 0.5], [93.388, 89.409, 0.5], [93.759, 89.378, 0.5], [94.967, 89.21, 0.5], [96.728, 89.521, 0.5], [95.49, 90.759, 0.5], [95.339, 90.481, 0.5], [94.909, 89.989, 0.5], [94.488, 89.716, 0.5], [96.882, 89.367, 0.5], [98.845, 88.636, 0.5], [95.467, 92.014, 0.5], [95.608, 92.49, 0.5], [99.568, 88.529, 0.5], [100.291, 88.422, 0.5], [95.748, 92.965, 0.5], [9 ...
